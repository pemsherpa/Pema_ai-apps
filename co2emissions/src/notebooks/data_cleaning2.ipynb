# %%
import pandas as pd
import requests
from datetime import datetime
import numpy as np
from IPython.display import display

# %% [markdown]
# ### Outline:
#
# Trying to predict the next 5 years of GHG emissions given 1 year of GHG emissions data (scope 1, scope 2, and scope 3) and business growth data. Here is the basic framework:
#
# 1. Input data:
#     - 2 years of revenue/sales or assets data if the company is pre-revenue (int)
#     - 1 years worth of GHG emissions data: total scope 1, total scope 2, and total scope 3. (float)
#     - Additional variables: number of employees (int), company industry (str), total assets (int), stock price (float)
# 2. Calculate the growth rate using the 2 years of revenue/sales data
# 3. Create a growth model and forecast the expected growth rate for the next 5 years
# 4. Create a tree ensemble model for each scope category and predict the expected scope emissions for each year based on the forecasted growth rate
#
# - How to incorporate target/expected growth rates?
# - How to incorporate additional variables such as number of employees, assets, etc.
# - How to incorporate macro/micro trends
# - How to incorporate AI/ML models

# %%
def basic_growth_model(value_year1, value_year2, num_years):
    value_growth_rate = (value_year2 - value_year1) / value_year1  # Calculate annual growth rate
    forecasted_values = [value_year2]

    for year in range(1, num_years + 1):
        adjusted_value_growth_rate = value_growth_rate * (1 - 0.1 * year)  # Calculate adjusted growth rate
        next_value = forecasted_values[-1] * (1 + adjusted_value_growth_rate)  # Forecast next year's value
        forecasted_values.append(next_value)

    return forecasted_values[1:]


def forecast_growth(num_years, financial_data):
    forecasted_sales = basic_growth_model(financial_data['sales_year1'], financial_data['sales_year2'], num_years)
    forecasted_revenue = basic_growth_model(financial_data['revenue_year1'], financial_data['revenue_year2'], num_years)
    return forecasted_sales, forecasted_revenue

# %%
# Example usage
example_financial_data = {
    'sales_year1': 1000,
    'sales_year2': 1200,
    'revenue_year1': 2000,
    'revenue_year2': 2400
}

forecasted_sales, forecasted_revenue = forecast_growth(5, example_financial_data)

print("Forecasted Sales for the next 5 years:", forecasted_sales)
print("Forecasted Revenue for the next 5 years:", forecasted_revenue)
# Out:
# Forecasted Sales for the next 5 years: [1416.0, 1642.5600000000002, 1872.5184, 2097.220608, 2306.9426688000003]
# Forecasted Revenue for the next 5 years: [2832.0, 3285.1200000000003, 3745.0368, 4194.441216, 4613.885337600001]

# %%
df_2022 = pd.read_csv('../external_datasets/top_250_emissions/original/Public profit and emission database - 2022.csv')

df_2022.columns

cols_2022 = ['Company Name','2022 Scope 1 emissions tons CO₂e', '2022 Scope 2 emissions tons CO₂e',
       '2022 Scope 3 emissions tons CO₂e','2022 Sales / Revenue (Millions USD)', '2022 Profit (Millions USD)',
       '2021-2022 Datasource emission data']

cols_mapping_2022 = {'Company Name': 'company_name',
                     '2022 Scope 1 emissions tons CO₂e': 'scope_1', 
                     '2022 Scope 2 emissions tons CO₂e': 'scope_2',
                     '2022 Scope 3 emissions tons CO₂e': 'scope_3',
                     '2022 Sales / Revenue (Millions USD)': 'sales_revenue', 
                     '2022 Profit (Millions USD)': 'profit',
                     '2021-2022 Datasource emission data': 'data_source'}

df_2022_clean = df_2022[cols_2022]
df_2022_clean = df_2022_clean.rename(columns=cols_mapping_2022)
df_2022_clean['year'] = 2022
df_2022_clean['company_name'] = df_2022_clean['company_name'].str.strip()
df_2022_clean
# Out:
#                                  company_name     scope_1     scope_2  \
# 0                              JPMorgan Chase      88 553     783 616
# 1    Saudi Arabian Oil Company (Saudi Aramco)  55 700 000  16 100 000
# 2                                        ICBC      97 400   1 923 900
# 3                     China Construction Bank      69 497   1 613 315
# 4                  Agricultural Bank of China     222 353   1 931 555
# ..                                        ...         ...         ...
# 203                                    NVIDIA       4 612     133 569
# 204                                        3M   2 420 000   1 460 000
# 205                             EOG Resources     510 000     400 000
# 206                     Takeda Pharmaceutical     277 000     291 000
# 207                        Sun Life Financial      15 046      18 819
#
#          scope_3 sales_revenue    profit  \
# 0        156 845      $179 930   $41 800
# 1            NaN      $589 470  $156 360
# 2            NaN      $216 770   $52 470
# 3            NaN      $203 080   $48 250
# 4            NaN      $186 140   $37 920
# ..           ...           ...       ...
# 203    2 701 477       $26 970    $4 370
# 204   11 636 000       $33 430    $5 450
# 205  110 300 000       $28 430    $9 390
# 206    5 166 000       $29 990    $2 090
# 207       25 792       $31 560    $2 400
#
#                                            data_source  year
# 0    page 1: https://www.jpmorganchase.com/content/...  2022
# 1    page 63, https://www.aramco.com/-/media/public...  2022
# 2    page 27, https://v.icbc.com.cn/userfiles/Resou...  2022
# 3    page 52, http://group.ccb.com/eng/attachDir/20...  2022
# 4    page 98, https://www.abchina.com/en/aboutus/cs...  2022
# ..                                                 ...   ...
# 203  page no. 51, CSR 2022, https://images.nvidia.c...  2022
# 204  page 149, https://multimedia.3m.com/mws/media/...  2022
# 205  page no. 4, https://eogresources-com.s3.us-wes...  2022
# 206                                                NaN  2022
# 207                                                NaN  2022
#
# [208 rows x 8 columns]

# %%
cik_list = []
for company_name in df_2022_clean['company_name']:
    formatted_company_name = company_name.strip(' ').replace(' ', '%20')

    response_obj = requests.get(f'https://financialmodelingprep.com/api/v3/cik-search/{formatted_company_name}?apikey=SWGIUgFhzgYfPKE5F9NsDyPX3SYTb72k')
    json_obj = response_obj.json()

    while type(json_obj) == list:
        if len(json_obj) > 0:
            json_obj = json_obj[0]
        else:
            break

    if type(json_obj) == dict:
        json_obj['original_name'] = company_name.strip(' ')

    cik_list.append(json_obj)
    print(json_obj)
# Out:
# {'cik': '0000019617', 'name': 'JPMORGAN CHASE & CO', 'original_name': 'JPMorgan Chase'}
# []
# {'cik': '0000917358', 'name': 'ICBC STANDARD SECURITIES INC.', 'original_name': 'ICBC'}
# []
# []
# {'cik': '0000070858', 'name': 'BANK OF AMERICA CORP /DE/', 'original_name': 'Bank of America'}
# {'cik': '0001413936', 'name': 'ALPHABET PARTNERS LP', 'original_name': 'Alphabet'}
# {'cik': '0001082970', 'name': 'EXXONMOBIL INVESTMENT MANAGEMENT INC /TX', 'original_name': 'ExxonMobil'}
# {'cik': '0000789019', 'name': 'MICROSOFT CORP', 'original_name': 'Microsoft'}
# {'cik': '0000320193', 'name': 'Apple Inc.', 'original_name': 'Apple'}
# {'cik': '0001095697', 'name': 'SHELL US GAS & POWER LLC', 'original_name': 'Shell'}
# {'cik': '0001289018', 'name': 'INDUSTRIAL AND COMMERCIAL BANK OF CHINA FINANCIAL SERVICES LLC', 'original_name': 'Bank of China'}
# {'cik': '0000834071', 'name': 'TOYOTA MOTOR CREDIT CORP', 'original_name': 'Toyota Motor'}
# {'cik': '0000879316', 'name': 'SAMSUNG ELECTRONICS CO LTD /FI', 'original_name': 'Samsung Electronics'}
# {'cik': '0000731766', 'name': 'UNITEDHEALTH GROUP INC', 'original_name': 'UnitedHealth Group'}
# []
# {'cik': '0000072971', 'name': 'WELLS FARGO & COMPANY/MN', 'original_name': 'Wells Fargo'}
# {'cik': '0000093410', 'name': 'CHEVRON CORP', 'original_name': 'Chevron'}
# {'cik': '0001108329', 'name': 'PETROCHINA CO LTD', 'original_name': 'PetroChina'}
# {'cik': '0000873630', 'name': 'HSBC HOLDINGS PLC', 'original_name': 'HSBC Holdings'}
# {'cik': '0000879764', 'name': 'TotalEnergies SE', 'original_name': 'TotalEnergies'}
# {'cik': '0000104169', 'name': 'Walmart Inc.', 'original_name': 'Walmart'}
# {'cik': '0000091154', 'name': 'CITIGROUP GLOBAL MARKETS INC.', 'original_name': 'Citigroup'}
# {'cik': '0001117795', 'name': 'CHINA MOBILE LTD /ADR/', 'original_name': 'China Mobile'}
# []
# []
# {'cik': '0000313807', 'name': 'BP PLC', 'original_name': 'BP'}
# {'cik': '0001834694', 'name': 'Volkswagen Group of America Investments, LLC', 'original_name': 'Volkswagen Group'}
# {'cik': '0000068136', 'name': 'MORGAN STANLEY & CO. LLC', 'original_name': 'Morgan Stanley'}
# {'cik': '0001326801', 'name': 'Meta Platforms, Inc.', 'original_name': 'Meta Platforms'}
# {'cik': '0000908732', 'name': 'SINOPEC SHANGHAI PETROCHEMICAL CO LTD', 'original_name': 'Sinopec'}
# {'cik': '0000886982', 'name': 'GOLDMAN SACHS GROUP INC', 'original_name': 'Goldman Sachs Group'}
# {'cik': '0001293451', 'name': 'Tencent Holdings Ltd', 'original_name': 'Tencent Holdings'}
# {'cik': '0001018724', 'name': 'AMAZON COM INC', 'original_name': 'Amazon'}
# {'cik': '0000069596', 'name': 'ALLIANZ LIFE FINANCIAL SERVICES, LLC', 'original_name': 'Allianz'}
# {'cik': '0000050916', 'name': 'RBC Capital Markets, LLC', 'original_name': 'RBC'}
# {'cik': '0000078003', 'name': 'PFIZER INC', 'original_name': 'Pfizer'}
# {'cik': '0000200406', 'name': 'JOHNSON & JOHNSON', 'original_name': 'Johnson & Johnson'}
# []
# []
# {'cik': '0001046179', 'name': 'TAIWAN SEMICONDUCTOR MANUFACTURING CO LTD', 'original_name': 'Taiwan Semiconductor'}
# []
# []
# []
# []
# {'cik': '0000811830', 'name': 'Santander Holdings USA, Inc.', 'original_name': 'Santander'}
# []
# {'cik': '0001166387', 'name': 'COMCAST CABLE COMMUNICATIONS HOLDINGS INC', 'original_name': 'Comcast'}
# {'cik': '0001140625', 'name': 'EQUINOR ASA', 'original_name': 'Equinor'}
# {'cik': '0001577552', 'name': 'Alibaba Group Holding Ltd', 'original_name': 'Alibaba Group'}
# {'cik': '0000080424', 'name': 'PROCTER & GAMBLE Co', 'original_name': 'Procter & Gamble'}
# []
# {'cik': '0000313838', 'name': 'Sony Group Corp', 'original_name': 'Sony'}
# {'cik': '0001119639', 'name': 'PETROBRAS - PETROLEO BRASILEIRO SA', 'original_name': 'Petrobras'}
# {'cik': '0001032383', 'name': 'GLENCORE INTERNATIONAL AG', 'original_name': 'Glencore International'}
# []
# {'cik': '0000948034', 'name': 'Stellantis Financial Services US Corp.', 'original_name': 'Stellantis'}
# {'cik': '0001268896', 'name': 'CHINA LIFE INSURANCE CO LTD', 'original_name': 'China Life Insurance'}
# {'cik': '0000004962', 'name': 'AMERICAN EXPRESS CO', 'original_name': 'American Express'}
# {'cik': '0000040545', 'name': 'GENERAL ELECTRIC CO', 'original_name': 'General Electric'}
# {'cik': '0000064803', 'name': 'CVS HEALTH Corp', 'original_name': 'CVS Health'}
# []
# {'cik': '0000354950', 'name': 'HOME DEPOT, INC.', 'original_name': 'The Home Depot'}
# {'cik': '0000049969', 'name': 'CIGNA INVESTMENTS INC /NEW', 'original_name': 'Cigna'}
# {'cik': '0001318605', 'name': 'Tesla, Inc.', 'original_name': 'Tesla'}
# {'cik': '0000804269', 'name': 'General Motors Financial Company, Inc.', 'original_name': 'General Motors'}
# {'cik': '0000310158', 'name': 'Merck & Co., Inc.', 'original_name': 'Merck & Co.'}
# {'cik': '0001551152', 'name': 'AbbVie Inc.', 'original_name': 'AbbVie'}
# {'cik': '0000067088', 'name': 'MITSUBISHI UFJ FINANCIAL GROUP INC', 'original_name': 'Mitsubishi'}
# {'cik': '0000889131', 'name': 'ROCHE HOLDING LTD', 'original_name': 'Roche Holding'}
# []
# {'cik': '0001156039', 'name': 'Elevance Health, Inc.', 'original_name': 'Elevance Health'}
# {'cik': '0000101829', 'name': 'RAYTHEON TECHNOLOGIES CORP', 'original_name': 'Raytheon Technologies'}
# {'cik': '0000924141', 'name': 'ORACLE INSTITUTIONAL PARTNERS L P', 'original_name': 'Oracle'}
# {'cik': '0000077476', 'name': 'PEPSICO INC', 'original_name': 'PepsiCo'}
# {'cik': '0000078214', 'name': 'CONOCOPHILLIPS CO', 'original_name': 'ConocoPhillips'}
# {'cik': '0000927971', 'name': 'BANK OF MONTREAL /CAN/', 'original_name': 'Bank of Montreal'}
# {'cik': '0001022837', 'name': 'SUMITOMO MITSUI FINANCIAL GROUP, INC.', 'original_name': 'Sumitomo Mitsui Financial'}
# {'cik': '0001095595', 'name': 'CNOOC LTD', 'original_name': 'CNOOC'}
# {'cik': '0001744489', 'name': 'Walt Disney Co', 'original_name': 'Walt Disney'}
# {'cik': '0001121404', 'name': 'Sanofi', 'original_name': 'Sanofi'}
# {'cik': '0000225732', 'name': 'UBS CASHFUND INC', 'original_name': 'UBS'}
# {'cik': '0000858877', 'name': 'CISCO SYSTEMS, INC.', 'original_name': 'Cisco Systems'}
# {'cik': '0001030617', 'name': 'NOVARTIS PHARMA AG', 'original_name': 'Novartis'}
# {'cik': '0001090727', 'name': 'UNITED PARCEL SERVICE INC', 'original_name': 'United Parcel Service'}
# {'cik': '0000317540', 'name': 'Coca-Cola Consolidated, Inc.', 'original_name': 'Coca-Cola'}
# {'cik': '0000940418', 'name': 'SIEMENS AG', 'original_name': 'Siemens'}
# []
# {'cik': '0000008565', 'name': 'COMMONWEALTH BANK OF AUSTRALIA', 'original_name': 'Commonwealth Bank'}
# {'cik': '0000863064', 'name': 'RIO TINTO PLC', 'original_name': 'Rio Tinto'}
# []
# []
# {'cik': '0000110390', 'name': 'UNILEVER N V', 'original_name': 'Unilever'}
# []
# {'cik': '0001127799', 'name': 'Zurich Insurance Group Ltd/FI', 'original_name': 'Zurich Insurance Group'}
# []
# {'cik': '0000067099', 'name': 'MITSUI & CO LTD', 'original_name': 'Mitsui'}
# {'cik': '0000715153', 'name': 'HONDA MOTOR CO LTD', 'original_name': 'Honda Motor'}
# {'cik': '0000014272', 'name': 'BRISTOL MYERS SQUIBB CO', 'original_name': 'Bristol Myers Squibb'}
# []
# []
# []
# {'cik': '0001510295', 'name': 'Marathon Petroleum Corp', 'original_name': 'Marathon Petroleum'}
# {'cik': '0000097745', 'name': 'THERMO FISHER SCIENTIFIC INC.', 'original_name': 'Thermo Fisher Scientific'}
# {'cik': '0000018230', 'name': 'CATERPILLAR INC', 'original_name': 'Caterpillar'}
# []
# {'cik': '0001403161', 'name': 'VISA INC.', 'original_name': 'Visa'}
# {'cik': '0000005272', 'name': 'AMERICAN INTERNATIONAL GROUP, INC.', 'original_name': 'American International Group'}
# {'cik': '0000037996', 'name': 'FORD MOTOR CO', 'original_name': 'Ford Motor'}
# {'cik': '0001725885', 'name': 'ITOCHU Techno-Solutions America, Inc.', 'original_name': 'Itochu'}
# {'cik': '0000901832', 'name': 'ASTRAZENECA PLC', 'original_name': 'AstraZeneca'}
# {'cik': '0001378580', 'name': 'Airbus SE/ADR', 'original_name': 'AIRBUS'}
# {'cik': '0001144967', 'name': 'HDFC BANK LTD', 'original_name': 'HDFC Bank'}
# []
# []
# {'cik': '0001054374', 'name': 'BROADCOM CORP', 'original_name': 'Broadcom'}
# {'cik': '0001534701', 'name': 'Phillips 66', 'original_name': 'Phillips 66'}
# {'cik': '0001022057', 'name': 'BAYER RICHARD A', 'original_name': 'Bayer'}
# {'cik': '0001091667', 'name': 'CHARTER COMMUNICATIONS, INC. /MO/', 'original_name': 'Charter Communications'}
# {'cik': '0000917851', 'name': 'Vale S.A.', 'original_name': 'Vale'}
# []
# {'cik': '0000047710', 'name': 'HITACHI LTD', 'original_name': 'Hitachi'}
# {'cik': '0000001800', 'name': 'ABBOTT LABORATORIES', 'original_name': 'Abbott Laboratories'}
# {'cik': '0001848380', 'name': 'Everest ANZ US LLC', 'original_name': 'ANZ'}
# {'cik': '0000313616', 'name': 'DANAHER CORP /DE/', 'original_name': 'Danaher'}
# {'cik': '0001191255', 'name': 'CHINA TELECOM CORP LTD', 'original_name': 'China Telecom'}
# {'cik': '0001160106', 'name': 'Lloyds Banking Group plc', 'original_name': 'Lloyds Banking Group'}
# {'cik': '0000047288', 'name': 'CAPITAL ONE, NATIONAL ASSOCIATION', 'original_name': 'Capital One'}
# {'cik': '0000713676', 'name': 'PNC FINANCIAL SERVICES GROUP, INC.', 'original_name': 'PNC Financial Services'}
# []
# []
# {'cik': '0001335730', 'name': 'MIZUHO FINANCIAL GROUP INC', 'original_name': 'Mizuho Financial'}
# []
# {'cik': '0000092230', 'name': 'TRUIST FINANCIAL CORP', 'original_name': 'Truist Financial'}
# []
# {'cik': '0000318154', 'name': 'AMGEN INC', 'original_name': 'Amgen'}
# []
# {'cik': '0000897599', 'name': 'LOCKHEED MARTIN INVESTMENT MANAGEMENT CO', 'original_name': 'Lockheed Martin'}
# {'cik': '0001467373', 'name': 'Accenture plc', 'original_name': 'Accenture'}
# {'cik': '0000022657', 'name': 'LOWE BROCKENBROUGH & CO INC', 'original_name': "Lowe's"}
# {'cik': '0001106184', 'name': 'LINDE EDWARD H', 'original_name': 'Linde'}
# {'cik': '0001103838', 'name': 'ICICI BANK LTD', 'original_name': 'ICICI Bank'}
# {'cik': '0000312069', 'name': 'BARCLAYS PLC', 'original_name': 'Barclays'}
# {'cik': '0001413329', 'name': 'Philip Morris International Inc.', 'original_name': 'Philip Morris International'}
# {'cik': '0000890157', 'name': 'METLIFE INVESTORS VARIABLE ANNUITY ACCOUNT FIVE', 'original_name': 'MetLife'}
# {'cik': '0001048911', 'name': 'FEDEX CORP', 'original_name': 'FedEx'}
# []
# {'cik': '0001301207', 'name': 'BANCO DO BRASIL SECURITIES LLC', 'original_name': 'Banco do Brasil'}
# {'cik': '0000064670', 'name': 'MEDTRONIC INC', 'original_name': 'Medtronic'}
# []
# []
# {'cik': '0001018825', 'name': 'IBM Retirement Fund', 'original_name': 'IBM'}
# {'cik': '0000276683', 'name': 'UNICREDIT CAPITAL MARKETS LLC', 'original_name': 'UniCredit'}
# []
# {'cik': '0000912505', 'name': 'ENEL AMERICAS S.A.', 'original_name': 'Enel'}
# []
# {'cik': '0000804328', 'name': 'QUALCOMM INC/DE', 'original_name': 'Qualcomm'}
# {'cik': '0001291318', 'name': 'OVERSEA-CHINESE BANKING Corp Ltd', 'original_name': 'Oversea-Chinese Banking'}
# {'cik': '0001045520', 'name': 'CANADIAN IMPERIAL BANK OF COMMERCE /CAN/', 'original_name': 'Canadian Imperial Bank'}
# {'cik': '0000773840', 'name': 'HONEYWELL INTERNATIONAL INC', 'original_name': 'Honeywell International'}
# {'cik': '0001131399', 'name': 'GSK PLC', 'original_name': 'GSK'}
# {'cik': '0000058056', 'name': 'DEUTSCHE BANK SECURITIES INC.', 'original_name': 'Deutsche Bank'}
# {'cik': '0000927653', 'name': 'MCKESSON CORP', 'original_name': 'McKesson'}
# {'cik': '0000917379', 'name': 'DBS VICKERS SECURITIES (USA) INC.', 'original_name': 'DBS'}
# {'cik': '0001103982', 'name': 'Mondelez International, Inc.', 'original_name': 'Mondelez International'}
# {'cik': '0001169486', 'name': 'TOKIO MARINE HOLDINGS, INC.', 'original_name': 'Tokio Marine Holdings'}
# {'cik': '0000100885', 'name': 'UNION PACIFIC CORP', 'original_name': 'Union Pacific'}
# {'cik': '0001450346', 'name': 'Porsche Automobil Holding SE / ADR', 'original_name': 'Porsche Automobil Holding'}
# {'cik': '0000880285', 'name': 'ENBRIDGE ENERGY PARTNERS LP', 'original_name': 'Enbridge'}
# []
# []
# {'cik': '0000049071', 'name': 'HUMANA INC', 'original_name': 'Humana'}
# {'cik': '0000059478', 'name': 'ELI LILLY & Co', 'original_name': 'Eli Lilly'}
# {'cik': '0001642293', 'name': 'FIAM Target Date Russell 1000 Growth Index Fund, LP', 'original_name': 'Target'}
# {'cik': '0000007084', 'name': 'Archer-Daniels-Midland Co', 'original_name': 'Archer Daniels Midland'}
# []
# {'cik': '0001004315', 'name': 'NATIONAL GRID PLC', 'original_name': 'National Grid'}
# []
# []
# {'cik': '0000320187', 'name': 'NIKE, Inc.', 'original_name': 'Nike'}
# []
# {'cik': '0000311337', 'name': 'SUNCOR ENERGY INC', 'original_name': 'Suncor Energy'}
# {'cik': '0001017413', 'name': 'CANADIAN NATURAL RESOURCES LTD', 'original_name': 'Canadian Natural Resources'}
# []
# {'cik': '0001000184', 'name': 'SAP SE', 'original_name': 'SAP'}
# {'cik': '0000086312', 'name': 'TRAVELERS COMPANIES, INC.', 'original_name': 'Travelers'}
# {'cik': '0001065280', 'name': 'NETFLIX INC', 'original_name': 'Netflix'}
# {'cik': '0001549802', 'name': 'JD.com, Inc.', 'original_name': 'JD.com'}
# {'cik': '0001571996', 'name': 'Dell Technologies Inc.', 'original_name': 'Dell Technologies'}
# {'cik': '0001687722', 'name': 'ALTAVISTA OIL & NATURAL GAS VENTURES FUND, LP', 'original_name': 'Oil & Natural Gas'}
# {'cik': '0001637120', 'name': 'CK Hutchison Holdings Limited/ADR', 'original_name': 'CK Hutchison'}
# {'cik': '0000839923', 'name': 'VODAFONE GROUP PUBLIC LTD CO', 'original_name': 'Vodafone'}
# []
# []
# {'cik': '0001144967', 'name': 'HDFC BANK LTD', 'original_name': 'HDFC'}
# {'cik': '0000813905', 'name': 'BANK OF NEW YORK MELLON', 'original_name': 'Bank of New York Mellon'}
# []
# {'cik': '0001141391', 'name': 'Mastercard Inc', 'original_name': 'Mastercard'}
# {'cik': '0000353278', 'name': 'NOVO NORDISK A S', 'original_name': 'Novo Nordisk'}
# {'cik': '0000866121', 'name': 'Northrop Grumman Innovation Systems, Inc.', 'original_name': 'Northrop Grumman'}
# {'cik': '0001628809', 'name': 'PTT Distributed Energy Systems, LLC', 'original_name': 'PTT'}
# {'cik': '0001088143', 'name': 'PAYPAL FUNDS', 'original_name': 'PayPal'}
# {'cik': '0000937966', 'name': 'ASML HOLDING NV', 'original_name': 'ASML Holding'}
# {'cik': '0001045810', 'name': 'NVIDIA CORP', 'original_name': 'NVIDIA'}
# {'cik': '0000066740', 'name': '3M CO', 'original_name': '3M'}
# {'cik': '0000821189', 'name': 'EOG RESOURCES INC', 'original_name': 'EOG Resources'}
# {'cik': '0001395064', 'name': 'TAKEDA PHARMACEUTICAL CO LTD', 'original_name': 'Takeda Pharmaceutical'}
# {'cik': '0001097362', 'name': 'SUN LIFE FINANCIAL INC', 'original_name': 'Sun Life Financial'}

# %%
filtered_cik_list = []
for item in cik_list:
    if type(item) == dict:
        filtered_cik_list.append(item)

# %%
cik_df = pd.DataFrame.from_records(filtered_cik_list)
cik_df = cik_df.rename(columns={"original_name": "company_name"})
cik_df["company_name"] = cik_df["company_name"].astype(str)
cik_df
# Out:
#             cik                                      name  \
# 0    0000019617                       JPMORGAN CHASE & CO
# 1    0000917358             ICBC STANDARD SECURITIES INC.
# 2    0000070858                 BANK OF AMERICA CORP /DE/
# 3    0001413936                      ALPHABET PARTNERS LP
# 4    0001082970  EXXONMOBIL INVESTMENT MANAGEMENT INC /TX
# ..          ...                                       ...
# 154  0001045810                               NVIDIA CORP
# 155  0000066740                                     3M CO
# 156  0000821189                         EOG RESOURCES INC
# 157  0001395064              TAKEDA PHARMACEUTICAL CO LTD
# 158  0001097362                    SUN LIFE FINANCIAL INC
#
#               company_name
# 0           JPMorgan Chase
# 1                     ICBC
# 2          Bank of America
# 3                 Alphabet
# 4               ExxonMobil
# ..                     ...
# 154                 NVIDIA
# 155                     3M
# 156          EOG Resources
# 157  Takeda Pharmaceutical
# 158     Sun Life Financial
#
# [159 rows x 3 columns]

# %%
merged_cik_df = pd.merge(df_2022_clean, cik_df, on="company_name", how="left")
merged_cik_df
# Out:
#                                  company_name     scope_1     scope_2  \
# 0                              JPMorgan Chase      88 553     783 616
# 1    Saudi Arabian Oil Company (Saudi Aramco)  55 700 000  16 100 000
# 2                                        ICBC      97 400   1 923 900
# 3                     China Construction Bank      69 497   1 613 315
# 4                  Agricultural Bank of China     222 353   1 931 555
# ..                                        ...         ...         ...
# 203                                    NVIDIA       4 612     133 569
# 204                                        3M   2 420 000   1 460 000
# 205                             EOG Resources     510 000     400 000
# 206                     Takeda Pharmaceutical     277 000     291 000
# 207                        Sun Life Financial      15 046      18 819
#
#          scope_3 sales_revenue    profit  \
# 0        156 845      $179 930   $41 800
# 1            NaN      $589 470  $156 360
# 2            NaN      $216 770   $52 470
# 3            NaN      $203 080   $48 250
# 4            NaN      $186 140   $37 920
# ..           ...           ...       ...
# 203    2 701 477       $26 970    $4 370
# 204   11 636 000       $33 430    $5 450
# 205  110 300 000       $28 430    $9 390
# 206    5 166 000       $29 990    $2 090
# 207       25 792       $31 560    $2 400
#
#                                            data_source  year         cik  \
# 0    page 1: https://www.jpmorganchase.com/content/...  2022  0000019617
# 1    page 63, https://www.aramco.com/-/media/public...  2022         NaN
# 2    page 27, https://v.icbc.com.cn/userfiles/Resou...  2022  0000917358
# 3    page 52, http://group.ccb.com/eng/attachDir/20...  2022         NaN
# 4    page 98, https://www.abchina.com/en/aboutus/cs...  2022         NaN
# ..                                                 ...   ...         ...
# 203  page no. 51, CSR 2022, https://images.nvidia.c...  2022  0001045810
# 204  page 149, https://multimedia.3m.com/mws/media/...  2022  0000066740
# 205  page no. 4, https://eogresources-com.s3.us-wes...  2022  0000821189
# 206                                                NaN  2022  0001395064
# 207                                                NaN  2022  0001097362
#
#                               name
# 0              JPMORGAN CHASE & CO
# 1                              NaN
# 2    ICBC STANDARD SECURITIES INC.
# 3                              NaN
# 4                              NaN
# ..                             ...
# 203                    NVIDIA CORP
# 204                          3M CO
# 205              EOG RESOURCES INC
# 206   TAKEDA PHARMACEUTICAL CO LTD
# 207         SUN LIFE FINANCIAL INC
#
# [208 rows x 10 columns]

# %%
merged_cik_df[~merged_cik_df['cik'].isna()].reset_index(drop=True)
# Out:
#               company_name     scope_1    scope_2      scope_3 sales_revenue  \
# 0           JPMorgan Chase      88 553    783 616      156 845      $179 930
# 1                     ICBC      97 400  1 923 900          NaN      $216 770
# 2          Bank of America      66 775    634 510    3 023 784      $133 840
# 3                 Alphabet      91 200  8 045 400    7 600 000      $282 850
# 4               ExxonMobil  96 000 000  7 000 000  540 000 000      $393 160
# ..                     ...         ...        ...          ...           ...
# 154                 NVIDIA       4 612    133 569    2 701 477       $26 970
# 155                     3M   2 420 000  1 460 000   11 636 000       $33 430
# 156          EOG Resources     510 000    400 000  110 300 000       $28 430
# 157  Takeda Pharmaceutical     277 000    291 000    5 166 000       $29 990
# 158     Sun Life Financial      15 046     18 819       25 792       $31 560
#
#       profit                                        data_source  year  \
# 0    $41 800  page 1: https://www.jpmorganchase.com/content/...  2022
# 1    $52 470  page 27, https://v.icbc.com.cn/userfiles/Resou...  2022
# 2    $28 620  page 17, https://about.bankofamerica.com/conte...  2022
# 3    $58 590  page 90 https://www.gstatic.com/gumdrop/sustai...  2022
# 4    $61 690  page 3:, https://corporate.exxonmobil.com/-/me...  2022
# ..       ...                                                ...   ...
# 154   $4 370  page no. 51, CSR 2022, https://images.nvidia.c...  2022
# 155   $5 450  page 149, https://multimedia.3m.com/mws/media/...  2022
# 156   $9 390  page no. 4, https://eogresources-com.s3.us-wes...  2022
# 157   $2 090                                                NaN  2022
# 158   $2 400                                                NaN  2022
#
#             cik                                      name
# 0    0000019617                       JPMORGAN CHASE & CO
# 1    0000917358             ICBC STANDARD SECURITIES INC.
# 2    0000070858                 BANK OF AMERICA CORP /DE/
# 3    0001413936                      ALPHABET PARTNERS LP
# 4    0001082970  EXXONMOBIL INVESTMENT MANAGEMENT INC /TX
# ..          ...                                       ...
# 154  0001045810                               NVIDIA CORP
# 155  0000066740                                     3M CO
# 156  0000821189                         EOG RESOURCES INC
# 157  0001395064              TAKEDA PHARMACEUTICAL CO LTD
# 158  0001097362                    SUN LIFE FINANCIAL INC
#
# [159 rows x 10 columns]

# %%
ticker_list = []
for company_name in df_2022_clean['company_name']:
    formatted_company_name = company_name.strip(' ').replace(' ', '%20')

    response_obj = requests.get(f'https://financialmodelingprep.com/api/v3/search?query={formatted_company_name}&apikey=SWGIUgFhzgYfPKE5F9NsDyPX3SYTb72k')
    json_obj = response_obj.json()

    while type(json_obj) == list:
        if len(json_obj) > 0:
            json_obj = json_obj[0]
        else:
            break

    if type(json_obj) == dict:
        json_obj['original_name'] = company_name.strip(' ')

    ticker_list.append(json_obj)
    print(json_obj)
# Out:
# {'symbol': 'JPM-PM', 'name': 'JPMorgan Chase & Co.', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'JPMorgan Chase'}
# []
# {'symbol': '9011.HK', 'name': 'ICBC CICC USD Money Market ETF', 'currency': 'USD', 'stockExchange': 'HKSE', 'exchangeShortName': 'HKSE', 'original_name': 'ICBC'}
# {'symbol': 'CNCB.VI', 'name': 'China Construction Bank Corporation', 'currency': 'EUR', 'stockExchange': 'Vienna', 'exchangeShortName': 'VIE', 'original_name': 'China Construction Bank'}
# {'symbol': 'EK7.VI', 'name': 'Agricultural Bank of China Limited', 'currency': 'EUR', 'stockExchange': 'Vienna', 'exchangeShortName': 'VIE', 'original_name': 'Agricultural Bank of China'}
# {'symbol': 'BAC.BA', 'name': 'Bank of America Corp', 'currency': 'USD', 'stockExchange': 'Buenos Aires', 'exchangeShortName': 'BUE', 'original_name': 'Bank of America'}
# {'symbol': 'GOOG.NE', 'name': 'Alphabet Inc.', 'currency': 'CAD', 'stockExchange': 'NEO', 'exchangeShortName': 'NEO', 'original_name': 'Alphabet'}
# []
# {'symbol': 'MSFT.NE', 'name': 'Microsoft Corporation', 'currency': 'CAD', 'stockExchange': 'NEO', 'exchangeShortName': 'NEO', 'original_name': 'Microsoft'}
# {'symbol': 'APC.F', 'name': 'Apple Inc.', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'Apple'}
# {'symbol': 'SHELL.AS', 'name': 'Shell plc', 'currency': 'EUR', 'stockExchange': 'Amsterdam', 'exchangeShortName': 'EURONEXT', 'original_name': 'Shell'}
# {'symbol': 'BOCN.VI', 'name': 'Bank of China Limited', 'currency': 'EUR', 'stockExchange': 'Vienna', 'exchangeShortName': 'VIE', 'original_name': 'Bank of China'}
# {'symbol': 'TOM.SG', 'name': 'Toyota Motor Corp', 'currency': 'EUR', 'stockExchange': 'Stuttgart', 'exchangeShortName': 'STU', 'original_name': 'Toyota Motor'}
# {'symbol': 'SSU.VI', 'name': 'Samsung Electronics Co., Ltd.', 'currency': 'EUR', 'stockExchange': 'Vienna', 'exchangeShortName': 'VIE', 'original_name': 'Samsung Electronics'}
# {'symbol': 'UNH.NE', 'name': 'UnitedHealth Group Inc', 'currency': 'CAD', 'stockExchange': 'NEO', 'exchangeShortName': 'NEO', 'original_name': 'UnitedHealth Group'}
# []
# {'symbol': 'WFC.SW', 'name': 'Wells Fargo & Company', 'currency': 'USD', 'stockExchange': 'Swiss Exchange', 'exchangeShortName': 'SIX', 'original_name': 'Wells Fargo'}
# {'symbol': 'CVX', 'name': 'Chevron Corporation', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'Chevron'}
# {'symbol': 'PTR', 'name': 'PetroChina Company Limited', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'PetroChina'}
# {'symbol': 'HSBC', 'name': 'HSBC Holdings plc', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'HSBC Holdings'}
# {'symbol': 'TTFNF', 'name': 'TotalEnergies SE', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'TotalEnergies'}
# {'symbol': 'WMT.SW', 'name': 'Walmart Inc.', 'currency': 'USD', 'stockExchange': 'Swiss Exchange', 'exchangeShortName': 'SIX', 'original_name': 'Walmart'}
# {'symbol': 'TRVC.DE', 'name': 'Citigroup Inc.', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'Citigroup'}
# {'symbol': 'CTM.F', 'name': 'China Mobile Limited', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'China Mobile'}
# {'symbol': 'CIHKY', 'name': 'China Merchants Bank Co., Ltd.', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'China Merchants Bank'}
# []
# {'symbol': 'BP', 'name': 'BP p.l.c.', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'BP'}
# []
# {'symbol': 'MS-PP', 'name': 'Morgan Stanley', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'Morgan Stanley'}
# {'symbol': 'MVRS.NE', 'name': 'Meta Platforms, Inc.', 'currency': 'CAD', 'stockExchange': 'NEO', 'exchangeShortName': 'NEO', 'original_name': 'Meta Platforms'}
# {'symbol': 'SPKOY', 'name': 'Sinopec Kantons Holdings Limited', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Sinopec'}
# {'symbol': 'GS.SW', 'name': 'The Goldman Sachs Group, Inc.', 'currency': 'USD', 'stockExchange': 'Swiss Exchange', 'exchangeShortName': 'SIX', 'original_name': 'Goldman Sachs Group'}
# {'symbol': 'TCTZF', 'name': 'Tencent Holdings Limited', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Tencent Holdings'}
# {'symbol': '0R1O.IL', 'name': 'Amazon.com Inc', 'currency': 'USD', 'stockExchange': 'IOB', 'exchangeShortName': 'IOB', 'original_name': 'Amazon'}
# {'symbol': 'ALV.WA', 'name': 'Allianz SE', 'currency': 'PLN', 'stockExchange': 'Warsaw Stock Exchange', 'exchangeShortName': 'WSE', 'original_name': 'Allianz'}
# {'symbol': 'RBC', 'name': 'RBC Bearings Incorporated', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'RBC'}
# {'symbol': 'PFIZER.NS', 'name': 'Pfizer Limited', 'currency': 'INR', 'stockExchange': 'National Stock Exchange of India', 'exchangeShortName': 'NSE', 'original_name': 'Pfizer'}
# {'symbol': 'JNJ.SW', 'name': 'Johnson & Johnson', 'currency': 'CHF', 'stockExchange': 'Swiss Exchange', 'exchangeShortName': 'SIX', 'original_name': 'Johnson & Johnson'}
# {'symbol': 'MBGYY', 'name': 'Mercedes-Benz Group AG', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Mercedes-Benz Group'}
# []
# {'symbol': '5425.TWO', 'name': 'Taiwan Semiconductor Co., Ltd.', 'currency': 'TWD', 'stockExchange': 'Taipei Exchange', 'exchangeShortName': 'TWO', 'original_name': 'Taiwan Semiconductor'}
# {'symbol': 'RLI.VI', 'name': 'Reliance Industries Limited', 'currency': 'EUR', 'stockExchange': 'Vienna', 'exchangeShortName': 'VIE', 'original_name': 'Reliance Industries'}
# []
# []
# []
# {'symbol': 'STNDF', 'name': 'Santander UK plc', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Santander'}
# {'symbol': 'NSRGY', 'name': 'Nestlé S.A.', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Nestlé'}
# {'symbol': 'CTP2.DE', 'name': 'Comcast Corporation', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'Comcast'}
# {'symbol': 'STOHF', 'name': 'Equinor ASA', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Equinor'}
# {'symbol': 'BABA.SW', 'name': 'Alibaba Group Holding Limited', 'currency': 'CHF', 'stockExchange': 'Swiss Exchange', 'exchangeShortName': 'SIX', 'original_name': 'Alibaba Group'}
# {'symbol': 'PGHL.NS', 'name': 'Procter & Gamble Health Limited', 'currency': 'INR', 'stockExchange': 'National Stock Exchange of India', 'exchangeShortName': 'NSE', 'original_name': 'Procter & Gamble'}
# {'symbol': 'NTTYY', 'name': 'Nippon Telegraph and Telephone Corporation', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Nippon Telegraph & Tel'}
# {'symbol': 'SONY', 'name': 'Sony Group Corporation', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'Sony'}
# {'symbol': 'PETR4.SA', 'name': 'Petróleo Brasileiro S.A. - Petrobras', 'currency': 'BRL', 'stockExchange': 'São Paulo', 'exchangeShortName': 'SAO', 'original_name': 'Petrobras'}
# []
# {'symbol': '024110.KS', 'name': 'Industrial Bank of Korea', 'currency': 'KRW', 'stockExchange': 'KSE', 'exchangeShortName': 'KSC', 'original_name': 'Industrial Bank'}
# {'symbol': '8TI.DE', 'name': 'Stellantis NV', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'Stellantis'}
# {'symbol': '2823.TW', 'name': 'China Life Insurance Co., Ltd.', 'currency': 'TWD', 'stockExchange': 'Taiwan', 'exchangeShortName': 'TAI', 'original_name': 'China Life Insurance'}
# {'symbol': 'AXP.BA', 'name': 'American Express Company', 'currency': 'ARS', 'stockExchange': 'Buenos Aires', 'exchangeShortName': 'BUE', 'original_name': 'American Express'}
# {'symbol': 'GNE.PA', 'name': 'General Electric Company', 'currency': 'EUR', 'stockExchange': 'Paris', 'exchangeShortName': 'EURONEXT', 'original_name': 'General Electric'}
# {'symbol': 'CVS.DE', 'name': 'CVS Health Corporation', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'CVS Health'}
# {'symbol': '601668.SS', 'name': 'China State Construction Engineering Corporation Limited', 'currency': 'CNY', 'stockExchange': 'Shanghai', 'exchangeShortName': 'SHH', 'original_name': 'China State Construction Engineering'}
# {'symbol': 'HD.SW', 'name': 'The Home Depot, Inc.', 'currency': 'CHF', 'stockExchange': 'Swiss Exchange', 'exchangeShortName': 'SIX', 'original_name': 'The Home Depot'}
# {'symbol': 'CI', 'name': 'Cigna Corporation', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'Cigna'}
# {'symbol': 'TSLA.NE', 'name': 'Tesla, Inc.', 'currency': 'CAD', 'stockExchange': 'NEO', 'exchangeShortName': 'NEO', 'original_name': 'Tesla'}
# {'symbol': 'GM.SW', 'name': 'General Motors Company', 'currency': 'USD', 'stockExchange': 'Swiss Exchange', 'exchangeShortName': 'SIX', 'original_name': 'General Motors'}
# {'symbol': 'MRK.PA', 'name': 'Merck & Co., Inc.', 'currency': 'EUR', 'stockExchange': 'Paris', 'exchangeShortName': 'EURONEXT', 'original_name': 'Merck & Co.'}
# {'symbol': '4AB.DU', 'name': 'AbbVie Inc', 'currency': 'EUR', 'stockExchange': 'Dusseldorf', 'exchangeShortName': 'DUS', 'original_name': 'AbbVie'}
# {'symbol': 'MSBHF', 'name': 'Mitsubishi Corporation', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Mitsubishi'}
# {'symbol': 'RO.SW', 'name': 'Roche Holding AG', 'currency': 'CHF', 'stockExchange': 'Swiss Exchange', 'exchangeShortName': 'SIX', 'original_name': 'Roche Holding'}
# {'symbol': 'SBKFF', 'name': 'State Bank of India', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'State Bank of India'}
# {'symbol': 'ELV', 'name': 'Elevance Health Inc.', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'Elevance Health'}
# {'symbol': '5UR.DE', 'name': 'Raytheon Technologies Corp', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'Raytheon Technologies'}
# {'symbol': 'ORCP.L', 'name': 'Oracle Power plc', 'currency': 'GBp', 'stockExchange': 'London Stock Exchange', 'exchangeShortName': 'LSE', 'original_name': 'Oracle'}
# {'symbol': 'PEP.SW', 'name': 'PepsiCo, Inc.', 'currency': 'CHF', 'stockExchange': 'Swiss Exchange', 'exchangeShortName': 'SIX', 'original_name': 'PepsiCo'}
# {'symbol': 'YCP.DE', 'name': 'ConocoPhillips', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'ConocoPhillips'}
# {'symbol': 'XXXX', 'name': 'Bank of Montreal', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange Arca', 'exchangeShortName': 'AMEX', 'original_name': 'Bank of Montreal'}
# {'symbol': 'SMFNF', 'name': 'Sumitomo Mitsui Financial Group, Inc.', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Sumitomo Mitsui Financial'}
# {'symbol': 'CNU.TO', 'name': 'CNOOC Limited', 'currency': 'CAD', 'stockExchange': 'Toronto Stock Exchange', 'exchangeShortName': 'TSX', 'original_name': 'CNOOC'}
# {'symbol': '0QZO.L', 'name': 'Walt Disney Co', 'currency': 'USD', 'stockExchange': 'London Stock Exchange', 'exchangeShortName': 'LSE', 'original_name': 'Walt Disney'}
# {'symbol': 'SANOFI.NS', 'name': 'Sanofi India Limited', 'currency': 'INR', 'stockExchange': 'National Stock Exchange of India', 'exchangeShortName': 'NSE', 'original_name': 'Sanofi'}
# {'symbol': 'UBS', 'name': 'UBS Group AG', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'UBS'}
# {'symbol': 'CSCO.NE', 'name': 'Cisco Systems Inc', 'currency': 'CAD', 'stockExchange': 'NEO', 'exchangeShortName': 'NEO', 'original_name': 'Cisco Systems'}
# {'symbol': 'NVSEF', 'name': 'Novartis AG', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Novartis'}
# {'symbol': 'UPS.MX', 'name': 'United Parcel Service, Inc.', 'currency': 'MXN', 'stockExchange': 'Mexico', 'exchangeShortName': 'MEX', 'original_name': 'United Parcel Service'}
# {'symbol': 'COLA.NE', 'name': 'Coca-Cola Co', 'currency': 'CAD', 'stockExchange': 'NEO', 'exchangeShortName': 'NEO', 'original_name': 'Coca-Cola'}
# {'symbol': 'SIEMENS.NS', 'name': 'Siemens Limited', 'currency': 'INR', 'stockExchange': 'National Stock Exchange of India', 'exchangeShortName': 'NSE', 'original_name': 'Siemens'}
# {'symbol': 'ITUB4.SA', 'name': 'Itaú Unibanco Holding S.A.', 'currency': 'BRL', 'stockExchange': 'São Paulo', 'exchangeShortName': 'SAO', 'original_name': 'Itaú Unibanco Holding'}
# {'symbol': 'CMWAY', 'name': 'Commonwealth Bank of Australia', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Commonwealth Bank'}
# {'symbol': 'RTPPF', 'name': 'Rio Tinto Group', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Rio Tinto'}
# {'symbol': 'IBE1.BE', 'name': 'Iberdrola SA', 'currency': 'EUR', 'stockExchange': 'Berlin', 'exchangeShortName': 'BER', 'original_name': 'Iberdrola'}
# []
# {'symbol': 'UNVB.DE', 'name': 'Unilever PLC', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'Unilever'}
# {'symbol': 'HYUD.L', 'name': 'Hyundai Motor Company', 'currency': 'USD', 'stockExchange': 'London Stock Exchange', 'exchangeShortName': 'LSE', 'original_name': 'Hyundai Motor'}
# {'symbol': 'ZURVY', 'name': 'Zurich Insurance Group AG', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Zurich Insurance Group'}
# {'symbol': 'DE', 'name': 'Deere & Company', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'Deere & Company'}
# {'symbol': 'MITSY', 'name': 'Mitsui & Co., Ltd.', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Mitsui'}
# {'symbol': 'HNDAF', 'name': 'Honda Motor Co., Ltd.', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Honda Motor'}
# []
# {'symbol': 'ISP.MI', 'name': 'Intesa Sanpaolo S.p.A.', 'currency': 'EUR', 'stockExchange': 'Milan', 'exchangeShortName': 'MIL', 'original_name': 'Intesa Sanpaolo'}
# []
# {'symbol': 'HNHPF', 'name': 'Hon Hai Precision Industry Co., Ltd.', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Hon Hai Precision'}
# {'symbol': 'MPN.DE', 'name': 'Marathon Petroleum Corporation', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'Marathon Petroleum'}
# {'symbol': 'TN8.DE', 'name': 'Thermo Fisher Scientific Inc.', 'currency': 'EUR', 'stockExchange': 'XETRA', 'exchangeShortName': 'XETRA', 'original_name': 'Thermo Fisher Scientific'}
# {'symbol': 'CAT.SW', 'name': 'Caterpillar Inc.', 'currency': 'CHF', 'stockExchange': 'Swiss Exchange', 'exchangeShortName': 'SIX', 'original_name': 'Caterpillar'}
# {'symbol': '300750.SZ', 'name': 'Contemporary Amperex Technology Co., Limited', 'currency': 'CNY', 'stockExchange': 'Shenzhen', 'exchangeShortName': 'SHZ', 'original_name': 'Contemporary Amperex Technology'}
# {'symbol': 'VISAX', 'name': 'Virtus KAR International Small-Mid Cap Fund - Class A', 'currency': 'USD', 'stockExchange': 'NASDAQ', 'exchangeShortName': 'NASDAQ', 'original_name': 'Visa'}
# {'symbol': 'AINN.DE', 'name': 'American International Group, Inc.', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'American International Group'}
# {'symbol': 'FMC1.DE', 'name': 'Ford Motor Company', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'Ford Motor'}
# {'symbol': 'ITOCY', 'name': 'ITOCHU Corporation', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Itochu'}
# {'symbol': 'ZEG.DE', 'name': 'AstraZeneca PLC', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'AstraZeneca'}
# {'symbol': 'EADSY', 'name': 'Airbus SE', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'AIRBUS'}
# {'symbol': 'HDFCBANK.NS', 'name': 'HDFC Bank Limited', 'currency': 'INR', 'stockExchange': 'National Stock Exchange of India', 'exchangeShortName': 'NSE', 'original_name': 'HDFC Bank'}
# {'symbol': 'CUAEF', 'name': 'China Shenhua Energy Company Limited', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'China Shenhua Energy'}
# {'symbol': 'CHCJY', 'name': 'China CITIC Bank Corporation Limited', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'China Citic Bank'}
# {'symbol': '1YD.DE', 'name': 'Broadcom Inc', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'Broadcom'}
# {'symbol': 'R66.DE', 'name': 'Phillips 66', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'Phillips 66'}
# {'symbol': 'BAYERCROP.NS', 'name': 'Bayer CropScience Limited', 'currency': 'INR', 'stockExchange': 'National Stock Exchange of India', 'exchangeShortName': 'NSE', 'original_name': 'Bayer'}
# {'symbol': 'CQD.DE', 'name': 'Charter Communications Inc', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'Charter Communications'}
# {'symbol': 'VALE', 'name': 'Vale S.A.', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'Vale'}
# []
# {'symbol': 'HTHIY', 'name': 'Hitachi, Ltd.', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Hitachi'}
# {'symbol': 'ABT.SW', 'name': 'Abbott Laboratories', 'currency': 'CHF', 'stockExchange': 'Swiss Exchange', 'exchangeShortName': 'SIX', 'original_name': 'Abbott Laboratories'}
# {'symbol': 'ANZU', 'name': 'Anzu Special Acquisition Corp I', 'currency': 'USD', 'stockExchange': 'NASDAQ Capital Market', 'exchangeShortName': 'NASDAQ', 'original_name': 'ANZ'}
# {'symbol': 'DHR-PB', 'name': 'Danaher Corporation', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'Danaher'}
# {'symbol': '601728.SS', 'name': 'China Telecom Corporation Limited', 'currency': 'CNY', 'stockExchange': 'Shanghai', 'exchangeShortName': 'SHH', 'original_name': 'China Telecom'}
# {'symbol': 'LYG', 'name': 'Lloyds Banking Group plc', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'Lloyds Banking Group'}
# {'symbol': 'COF-PN', 'name': 'Capital One Financial Corporation', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'Capital One'}
# {'symbol': 'PNC-PP', 'name': 'The PNC Financial Services Group, Inc.', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'PNC Financial Services'}
# {'symbol': 'BN.TO', 'name': 'Brookfield Corporation', 'currency': 'CAD', 'stockExchange': 'Toronto Stock Exchange', 'exchangeShortName': 'TSX', 'original_name': 'Brookfield Corporation'}
# []
# {'symbol': 'MZHOF', 'name': 'Mizuho Financial Group, Inc.', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Mizuho Financial'}
# {'symbol': 'DPW.SW', 'name': 'Deutsche Post AG', 'currency': 'CHF', 'stockExchange': 'Swiss Exchange', 'exchangeShortName': 'SIX', 'original_name': 'Deutsche Post'}
# {'symbol': 'TFC-PR', 'name': 'Truist Financial Corporation', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'Truist Financial'}
# {'symbol': 'CHPXF', 'name': 'China Pacific Insurance (Group) Co., Ltd.', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'China Pacific Insurance'}
# {'symbol': 'AMGN', 'name': 'Amgen Inc.', 'currency': 'USD', 'stockExchange': 'NASDAQ Global Select', 'exchangeShortName': 'NASDAQ', 'original_name': 'Amgen'}
# {'symbol': 'KDDIY', 'name': 'KDDI Corporation', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'KDDI'}
# {'symbol': 'LOM.DE', 'name': 'Lockheed Martin Corporation', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'Lockheed Martin'}
# {'symbol': 'ACN', 'name': 'Accenture plc', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'Accenture'}
# {'symbol': 'LOW', 'name': "Lowe's Companies, Inc.", 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': "Lowe's"}
# {'symbol': 'LINDEINDIA.NS', 'name': 'Linde India Limited', 'currency': 'INR', 'stockExchange': 'National Stock Exchange of India', 'exchangeShortName': 'NSE', 'original_name': 'Linde'}
# {'symbol': 'ICICIBANK.NS', 'name': 'ICICI Bank Limited', 'currency': 'INR', 'stockExchange': 'National Stock Exchange of India', 'exchangeShortName': 'NSE', 'original_name': 'ICICI Bank'}
# {'symbol': 'BCY.DE', 'name': 'Barclays PLC', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'Barclays'}
# {'symbol': 'PMI.SW', 'name': 'Philip Morris International Inc.', 'currency': 'CHF', 'stockExchange': 'Swiss Exchange', 'exchangeShortName': 'SIX', 'original_name': 'Philip Morris International'}
# {'symbol': 'MET-PF', 'name': 'MetLife, Inc.', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'MetLife'}
# {'symbol': 'FDX.SW', 'name': 'FedEx Corporation', 'currency': 'USD', 'stockExchange': 'Swiss Exchange', 'exchangeShortName': 'SIX', 'original_name': 'FedEx'}
# {'symbol': 'BYD', 'name': 'Boyd Gaming Corporation', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'BYD'}
# {'symbol': 'BDORY', 'name': 'Banco do Brasil S.A.', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Banco do Brasil'}
# {'symbol': 'MDT', 'name': 'Medtronic plc', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'Medtronic'}
# {'symbol': 'BBDO', 'name': 'Banco Bradesco S.A.', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'Banco Bradesco'}
# []
# {'symbol': 'IBM', 'name': 'International Business Machines Corporation', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'IBM'}
# {'symbol': 'CRIN.DE', 'name': 'UniCredit SpA', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'UniCredit'}
# {'symbol': 'AMXVF', 'name': 'América Móvil, S.A.B. de C.V.', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'América Móvil'}
# {'symbol': 'ENEL.MI', 'name': 'Enel SpA', 'currency': 'EUR', 'stockExchange': 'Milan', 'exchangeShortName': 'MIL', 'original_name': 'Enel'}
# {'symbol': 'SOT.DE', 'name': 'Southern Company', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'Southern Company'}
# {'symbol': '0QZ3.L', 'name': 'Qualcomm Inc', 'currency': 'USD', 'stockExchange': 'London Stock Exchange', 'exchangeShortName': 'LSE', 'original_name': 'Qualcomm'}
# {'symbol': 'OVCHY', 'name': 'Oversea-Chinese Banking Corporation Limited', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Oversea-Chinese Banking'}
# {'symbol': 'CM.TO', 'name': 'Canadian Imperial Bank of Commerce', 'currency': 'CAD', 'stockExchange': 'Toronto Stock Exchange', 'exchangeShortName': 'TSX', 'original_name': 'Canadian Imperial Bank'}
# {'symbol': 'HON.L', 'name': 'Honeywell International Inc.', 'currency': 'USD', 'stockExchange': 'London Stock Exchange', 'exchangeShortName': 'LSE', 'original_name': 'Honeywell International'}
# {'symbol': 'GSK', 'name': 'GSK plc', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'GSK'}
# {'symbol': 'WMWXF', 'name': 'DEUTSCHE BANK AG LONDON', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Deutsche Bank'}
# {'symbol': 'CAKFY', 'name': 'McKesson Europe AG', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'McKesson'}
# {'symbol': 'DBS', 'name': 'Invesco DB Silver Fund', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange Arca', 'exchangeShortName': 'AMEX', 'original_name': 'DBS'}
# {'symbol': 'KTF.DE', 'name': 'Mondelez International Inc', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'Mondelez International'}
# {'symbol': 'TKOMY', 'name': 'Tokio Marine Holdings, Inc.', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Tokio Marine Holdings'}
# {'symbol': 'UNP.DE', 'name': 'Union Pacific Corporation', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'Union Pacific'}
# {'symbol': 'PSHE.WA', 'name': 'Porsche Automobil Holding SE', 'currency': 'PLN', 'stockExchange': 'Warsaw Stock Exchange', 'exchangeShortName': 'WSE', 'original_name': 'Porsche Automobil Holding'}
# {'symbol': 'ENNPF', 'name': 'Enbridge Inc', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Enbridge'}
# []
# {'symbol': '8285.HK', 'name': 'Sling Group Holdings Limited', 'currency': 'HKD', 'stockExchange': 'HKSE', 'exchangeShortName': 'HKSE', 'original_name': 'ING Group'}
# {'symbol': 'HUM', 'name': 'Humana Inc.', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'Humana'}
# {'symbol': 'LLY.SW', 'name': 'Eli Lilly and Company', 'currency': 'CHF', 'stockExchange': 'Swiss Exchange', 'exchangeShortName': 'SIX', 'original_name': 'Eli Lilly'}
# {'symbol': 'CBDY', 'name': 'Target Group Inc.', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Target'}
# []
# {'symbol': 'SU.PA', 'name': 'Schneider Electric S.E.', 'currency': 'EUR', 'stockExchange': 'Paris', 'exchangeShortName': 'EURONEXT', 'original_name': 'Schneider Electric'}
# {'symbol': 'NNGF.DE', 'name': 'National Grid plc', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'National Grid'}
# {'symbol': 'EONGY', 'name': 'E.ON SE', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'E.ON'}
# {'symbol': 'CMAKY', 'name': 'China Minsheng Banking Corp., Ltd.', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'China Minsheng Bank'}
# {'symbol': 'NKE.NE', 'name': 'NIKE, Inc.', 'currency': 'CAD', 'stockExchange': 'NEO', 'exchangeShortName': 'NEO', 'original_name': 'Nike'}
# []
# {'symbol': 'SU.TO', 'name': 'Suncor Energy Inc.', 'currency': 'CAD', 'stockExchange': 'Toronto Stock Exchange', 'exchangeShortName': 'TSX', 'original_name': 'Suncor Energy'}
# {'symbol': 'CNQ.TO', 'name': 'Canadian Natural Resources Limited', 'currency': 'CAD', 'stockExchange': 'Toronto Stock Exchange', 'exchangeShortName': 'TSX', 'original_name': 'Canadian Natural Resources'}
# {'symbol': 'NRDBY', 'name': 'Nordea Bank Abp', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Nordea Bank'}
# {'symbol': 'SAP', 'name': 'SAP SE', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'SAP'}
# {'symbol': 'TRV', 'name': 'The Travelers Companies, Inc.', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'Travelers'}
# {'symbol': 'NFLX.NE', 'name': 'Netflix, Inc.', 'currency': 'CAD', 'stockExchange': 'NEO', 'exchangeShortName': 'NEO', 'original_name': 'Netflix'}
# {'symbol': 'JDCMF', 'name': 'JD.com, Inc.', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'JD.com'}
# {'symbol': '12DA.DE', 'name': 'Dell Technologies Inc', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'Dell Technologies'}
# {'symbol': 'OIL.NS', 'name': 'Oil India Limited', 'currency': 'INR', 'stockExchange': 'National Stock Exchange of India', 'exchangeShortName': 'NSE', 'original_name': 'Oil & Natural Gas'}
# {'symbol': 'CKHUY', 'name': 'CK Hutchison Holdings Limited', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'CK Hutchison'}
# {'symbol': 'VODI.DE', 'name': 'Vodafone Group Plc', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'Vodafone'}
# []
# {'symbol': 'SVNBY', 'name': 'Seven Bank, Ltd.', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Seven & I Holdings'}
# {'symbol': 'HDFC.NS', 'name': 'Housing Development Finance Corporation Limited', 'currency': 'INR', 'stockExchange': 'National Stock Exchange of India', 'exchangeShortName': 'NSE', 'original_name': 'HDFC'}
# {'symbol': 'BK', 'name': 'The Bank of New York Mellon Corporation', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'Bank of New York Mellon'}
# {'symbol': 'NGLOY', 'name': 'Anglo American plc', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Anglo American'}
# {'symbol': 'MA.NE', 'name': 'Mastercard Incorporated', 'currency': 'CAD', 'stockExchange': 'NEO', 'exchangeShortName': 'NEO', 'original_name': 'Mastercard'}
# {'symbol': 'NVO', 'name': 'Novo Nordisk A/S', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'Novo Nordisk'}
# {'symbol': 'NTH.DE', 'name': 'Northrop Grumman Corporation', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'Northrop Grumman'}
# {'symbol': 'PTTN', 'name': 'Patten Energy Solutions Group, Inc.', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'PTT'}
# {'symbol': 'PYPL.NE', 'name': 'PayPal Holdings, Inc.', 'currency': 'CAD', 'stockExchange': 'NEO', 'exchangeShortName': 'NEO', 'original_name': 'PayPal'}
# {'symbol': 'ASML.WA', 'name': 'ASML Holding N.V.', 'currency': 'PLN', 'stockExchange': 'Warsaw Stock Exchange', 'exchangeShortName': 'WSE', 'original_name': 'ASML Holding'}
# {'symbol': 'NVD.F', 'name': 'NVIDIA Corporation', 'currency': 'EUR', 'stockExchange': 'Frankfurt Stock Exchange', 'exchangeShortName': 'XETRA', 'original_name': 'NVIDIA'}
# {'symbol': '3MSF.L', 'name': 'Leverage Shares 3x Microsoft ETC', 'currency': 'GBp', 'stockExchange': 'London Stock Exchange', 'exchangeShortName': 'LSE', 'original_name': '3M'}
# {'symbol': 'EOG', 'name': 'EOG Resources, Inc.', 'currency': 'USD', 'stockExchange': 'New York Stock Exchange', 'exchangeShortName': 'NYSE', 'original_name': 'EOG Resources'}
# {'symbol': 'TKPHF', 'name': 'Takeda Pharmaceutical Company Limited', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Takeda Pharmaceutical'}
# {'symbol': 'SUNFF', 'name': 'Sun Life Financial Inc.', 'currency': 'USD', 'stockExchange': 'Other OTC', 'exchangeShortName': 'PNK', 'original_name': 'Sun Life Financial'}

# %%
filtered_ticker_list = []
for item in cik_list:
    if type(item) == dict:
        filtered_ticker_list.append(item)

# %%
ticker_df = pd.DataFrame.from_records(filtered_ticker_list)
ticker_df = ticker_df.rename(columns={"original_name": "company_name"})
ticker_df["company_name"] = ticker_df["company_name"].astype(str)
ticker_df
# Out:
#       symbol                                   name currency  \
# 0     JPM-PM                   JPMorgan Chase & Co.      USD
# 1    9011.HK         ICBC CICC USD Money Market ETF      USD
# 2    CNCB.VI    China Construction Bank Corporation      EUR
# 3     EK7.VI     Agricultural Bank of China Limited      EUR
# 4     BAC.BA                   Bank of America Corp      USD
# ..       ...                                    ...      ...
# 183    NVD.F                     NVIDIA Corporation      EUR
# 184   3MSF.L       Leverage Shares 3x Microsoft ETC      GBp
# 185      EOG                    EOG Resources, Inc.      USD
# 186    TKPHF  Takeda Pharmaceutical Company Limited      USD
# 187    SUNFF                Sun Life Financial Inc.      USD
#
#                 stockExchange exchangeShortName                company_name
# 0     New York Stock Exchange              NYSE              JPMorgan Chase
# 1                        HKSE              HKSE                        ICBC
# 2                      Vienna               VIE     China Construction Bank
# 3                      Vienna               VIE  Agricultural Bank of China
# 4                Buenos Aires               BUE             Bank of America
# ..                        ...               ...                         ...
# 183  Frankfurt Stock Exchange             XETRA                      NVIDIA
# 184     London Stock Exchange               LSE                          3M
# 185   New York Stock Exchange              NYSE               EOG Resources
# 186                 Other OTC               PNK       Takeda Pharmaceutical
# 187                 Other OTC               PNK          Sun Life Financial
#
# [188 rows x 6 columns]

# %%
merged_ticker_df = pd.merge(merged_cik_df, ticker_df, on="company_name", how="left")
merged_ticker_df
# Out:
#                                  company_name     scope_1     scope_2  \
# 0                              JPMorgan Chase      88 553     783 616
# 1    Saudi Arabian Oil Company (Saudi Aramco)  55 700 000  16 100 000
# 2                                        ICBC      97 400   1 923 900
# 3                     China Construction Bank      69 497   1 613 315
# 4                  Agricultural Bank of China     222 353   1 931 555
# ..                                        ...         ...         ...
# 203                                    NVIDIA       4 612     133 569
# 204                                        3M   2 420 000   1 460 000
# 205                             EOG Resources     510 000     400 000
# 206                     Takeda Pharmaceutical     277 000     291 000
# 207                        Sun Life Financial      15 046      18 819
#
#          scope_3 sales_revenue    profit  \
# 0        156 845      $179 930   $41 800
# 1            NaN      $589 470  $156 360
# 2            NaN      $216 770   $52 470
# 3            NaN      $203 080   $48 250
# 4            NaN      $186 140   $37 920
# ..           ...           ...       ...
# 203    2 701 477       $26 970    $4 370
# 204   11 636 000       $33 430    $5 450
# 205  110 300 000       $28 430    $9 390
# 206    5 166 000       $29 990    $2 090
# 207       25 792       $31 560    $2 400
#
#                                            data_source  year         cik  \
# 0    page 1: https://www.jpmorganchase.com/content/...  2022  0000019617
# 1    page 63, https://www.aramco.com/-/media/public...  2022         NaN
# 2    page 27, https://v.icbc.com.cn/userfiles/Resou...  2022  0000917358
# 3    page 52, http://group.ccb.com/eng/attachDir/20...  2022         NaN
# 4    page 98, https://www.abchina.com/en/aboutus/cs...  2022         NaN
# ..                                                 ...   ...         ...
# 203  page no. 51, CSR 2022, https://images.nvidia.c...  2022  0001045810
# 204  page 149, https://multimedia.3m.com/mws/media/...  2022  0000066740
# 205  page no. 4, https://eogresources-com.s3.us-wes...  2022  0000821189
# 206                                                NaN  2022  0001395064
# 207                                                NaN  2022  0001097362
#
#                             name_x   symbol  \
# 0              JPMORGAN CHASE & CO   JPM-PM
# 1                              NaN      NaN
# 2    ICBC STANDARD SECURITIES INC.  9011.HK
# 3                              NaN  CNCB.VI
# 4                              NaN   EK7.VI
# ..                             ...      ...
# 203                    NVIDIA CORP    NVD.F
# 204                          3M CO   3MSF.L
# 205              EOG RESOURCES INC      EOG
# 206   TAKEDA PHARMACEUTICAL CO LTD    TKPHF
# 207         SUN LIFE FINANCIAL INC    SUNFF
#
#                                     name_y currency             stockExchange  \
# 0                     JPMorgan Chase & Co.      USD   New York Stock Exchange
# 1                                      NaN      NaN                       NaN
# 2           ICBC CICC USD Money Market ETF      USD                      HKSE
# 3      China Construction Bank Corporation      EUR                    Vienna
# 4       Agricultural Bank of China Limited      EUR                    Vienna
# ..                                     ...      ...                       ...
# 203                     NVIDIA Corporation      EUR  Frankfurt Stock Exchange
# 204       Leverage Shares 3x Microsoft ETC      GBp     London Stock Exchange
# 205                    EOG Resources, Inc.      USD   New York Stock Exchange
# 206  Takeda Pharmaceutical Company Limited      USD                 Other OTC
# 207                Sun Life Financial Inc.      USD                 Other OTC
#
#     exchangeShortName
# 0                NYSE
# 1                 NaN
# 2                HKSE
# 3                 VIE
# 4                 VIE
# ..                ...
# 203             XETRA
# 204               LSE
# 205              NYSE
# 206               PNK
# 207               PNK
#
# [208 rows x 15 columns]

# %%
ticker_list = []
for company_name in df_2022_clean['company_name']:
    df_2022

    response_obj = requests.get(f'https://financialmodelingprep.com/api/v3/search?query={formatted_company_name}&apikey=SWGIUgFhzgYfPKE5F9NsDyPX3SYTb72k')
    json_obj = response_obj.json()

    while type(json_obj) == list:
        if len(json_obj) > 0:
            json_obj = json_obj[0]
        else:
            break

    if type(json_obj) == dict:
        json_obj['original_name'] = company_name.strip(' ')

    ticker_list.append(json_obj)
    print(json_obj)

# %%
merged_ticker_df
# Out:
#                                  company_name     scope_1     scope_2  \
# 0                              JPMorgan Chase      88 553     783 616
# 1    Saudi Arabian Oil Company (Saudi Aramco)  55 700 000  16 100 000
# 2                                        ICBC      97 400   1 923 900
# 3                     China Construction Bank      69 497   1 613 315
# 4                  Agricultural Bank of China     222 353   1 931 555
# ..                                        ...         ...         ...
# 203                                    NVIDIA       4 612     133 569
# 204                                        3M   2 420 000   1 460 000
# 205                             EOG Resources     510 000     400 000
# 206                     Takeda Pharmaceutical     277 000     291 000
# 207                        Sun Life Financial      15 046      18 819
#
#          scope_3 sales_revenue    profit  \
# 0        156 845      $179 930   $41 800
# 1            NaN      $589 470  $156 360
# 2            NaN      $216 770   $52 470
# 3            NaN      $203 080   $48 250
# 4            NaN      $186 140   $37 920
# ..           ...           ...       ...
# 203    2 701 477       $26 970    $4 370
# 204   11 636 000       $33 430    $5 450
# 205  110 300 000       $28 430    $9 390
# 206    5 166 000       $29 990    $2 090
# 207       25 792       $31 560    $2 400
#
#                                            data_source  year         cik  \
# 0    page 1: https://www.jpmorganchase.com/content/...  2022  0000019617
# 1    page 63, https://www.aramco.com/-/media/public...  2022         NaN
# 2    page 27, https://v.icbc.com.cn/userfiles/Resou...  2022  0000917358
# 3    page 52, http://group.ccb.com/eng/attachDir/20...  2022         NaN
# 4    page 98, https://www.abchina.com/en/aboutus/cs...  2022         NaN
# ..                                                 ...   ...         ...
# 203  page no. 51, CSR 2022, https://images.nvidia.c...  2022  0001045810
# 204  page 149, https://multimedia.3m.com/mws/media/...  2022  0000066740
# 205  page no. 4, https://eogresources-com.s3.us-wes...  2022  0000821189
# 206                                                NaN  2022  0001395064
# 207                                                NaN  2022  0001097362
#
#                             name_x   symbol  \
# 0              JPMORGAN CHASE & CO   JPM-PM
# 1                              NaN      NaN
# 2    ICBC STANDARD SECURITIES INC.  9011.HK
# 3                              NaN  CNCB.VI
# 4                              NaN   EK7.VI
# ..                             ...      ...
# 203                    NVIDIA CORP    NVD.F
# 204                          3M CO   3MSF.L
# 205              EOG RESOURCES INC      EOG
# 206   TAKEDA PHARMACEUTICAL CO LTD    TKPHF
# 207         SUN LIFE FINANCIAL INC    SUNFF
#
#                                     name_y currency             stockExchange  \
# 0                     JPMorgan Chase & Co.      USD   New York Stock Exchange
# 1                                      NaN      NaN                       NaN
# 2           ICBC CICC USD Money Market ETF      USD                      HKSE
# 3      China Construction Bank Corporation      EUR                    Vienna
# 4       Agricultural Bank of China Limited      EUR                    Vienna
# ..                                     ...      ...                       ...
# 203                     NVIDIA Corporation      EUR  Frankfurt Stock Exchange
# 204       Leverage Shares 3x Microsoft ETC      GBp     London Stock Exchange
# 205                    EOG Resources, Inc.      USD   New York Stock Exchange
# 206  Takeda Pharmaceutical Company Limited      USD                 Other OTC
# 207                Sun Life Financial Inc.      USD                 Other OTC
#
#     exchangeShortName
# 0                NYSE
# 1                 NaN
# 2                HKSE
# 3                 VIE
# 4                 VIE
# ..                ...
# 203             XETRA
# 204               LSE
# 205              NYSE
# 206               PNK
# 207               PNK
#
# [208 rows x 15 columns]

# %%
income_list = []
for index, row in merged_ticker_df.iterrows():
    if (type(row['cik']) == str):
        response_obj = requests.get(f"https://financialmodelingprep.com/api/v3/income-statement/{row['cik']}?period=annual&apikey=SWGIUgFhzgYfPKE5F9NsDyPX3SYTb72k")
        json_obj = response_obj.json()
    elif (type(row['symbol']) == str):
        response_obj = requests.get(f"https://financialmodelingprep.com/api/v3/income-statement/{row['symbol']}?period=annual&apikey=SWGIUgFhzgYfPKE5F9NsDyPX3SYTb72k")
        json_obj = response_obj.json()
    else:
        continue

    if type(json_obj) == list:
        for item in json_obj:
            if item['calendarYear'] == '2022':
                json_obj = item
                break

    if type(json_obj) == dict:
        json_obj['original_name'] = row['company_name']

    income_list.append(json_obj)
    print(f"symbol: {row['cik']}")
    print(f"cik: {row['cik']}")
    print(f"JSON: {json_obj}")
    print()
    
income_list
# Out:
# symbol: 0000019617
# cik: 0000019617
# JSON: {'date': '2022-12-31', 'symbol': 'JPM-PJ', 'reportedCurrency': 'USD', 'cik': '0000019617', 'fillingDate': '2023-02-21', 'acceptedDate': '2023-02-21 16:13:55', 'calendarYear': '2022', 'period': 'FY', 'revenue': 128695000000, 'costOfRevenue': 0, 'grossProfit': 128695000000, 'grossProfitRatio': 1, 'researchAndDevelopmentExpenses': 0, 'generalAndAdministrativeExpenses': 41636000000, 'sellingAndMarketingExpenses': 3911000000, 'sellingGeneralAndAdministrativeExpenses': 45547000000, 'otherExpenses': -109030000000, 'operatingExpenses': -63483000000, 'costAndExpenses': -63483000000, 'interestIncome': 92807000000, 'interestExpense': 26097000000, 'depreciationAndAmortization': 7051000000, 'ebitda': 72263000000, 'ebitdaratio': 0.561505886, 'operatingIncome': 65212000000, 'operatingIncomeRatio': 0.5067174327, 'totalOtherIncomeExpensesNet': -19046000000, 'incomeBeforeTax': 46166000000, 'incomeBeforeTaxRatio': 0.3587241152, 'incomeTaxExpense': 8490000000, 'netIncome': 37676000000, 'netIncomeRatio': 0.2927541863, 'eps': 12.47, 'epsdiluted': 12.47, 'weightedAverageShsOut': 2968734491, 'weightedAverageShsOutDil': 3021000000, 'link': 'https://www.sec.gov/Archives/edgar/data/19617/000001961723000231/0000019617-23-000231-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000001961723000231/jpm-20221231.htm', 'original_name': 'JPMorgan Chase'}
#
# symbol: 0000917358
# cik: 0000917358
# JSON: []
#
# symbol: nan
# cik: nan
# JSON: {'date': '2022-12-31', 'symbol': 'CNCB.VI', 'reportedCurrency': 'CNY', 'cik': '0000000000', 'fillingDate': '2022-12-31', 'acceptedDate': '2022-12-30 19:00:00', 'calendarYear': '2022', 'period': 'FY', 'revenue': 821279000000, 'costOfRevenue': 0, 'grossProfit': 821279000000, 'grossProfitRatio': 1, 'researchAndDevelopmentExpenses': 0, 'generalAndAdministrativeExpenses': 213219000000, 'sellingAndMarketingExpenses': 0, 'sellingGeneralAndAdministrativeExpenses': 213219000000, 'otherExpenses': 74000000, 'operatingExpenses': 285512000000, 'costAndExpenses': 285512000000, 'interestIncome': 1169900000000, 'interestExpense': 526836000000, 'depreciationAndAmortization': -398082000000, 'ebitda': 382712000000, 'ebitdaratio': 0.4659951125, 'operatingIncome': 382712000000, 'operatingIncomeRatio': 0.4659951125, 'totalOtherIncomeExpensesNet': -695000000, 'incomeBeforeTax': 382017000000, 'incomeBeforeTaxRatio': 0.4651488715, 'incomeTaxExpense': 58851000000, 'netIncome': 324727000000, 'netIncomeRatio': 0.3953918218, 'eps': 1.28, 'epsdiluted': 1.28, 'weightedAverageShsOut': 253016406250, 'weightedAverageShsOutDil': 253016406250, 'link': '', 'finalLink': '', 'original_name': 'China Construction Bank'}
#
# symbol: nan
# cik: nan
# JSON: {'date': '2022-12-31', 'symbol': 'EK7.VI', 'reportedCurrency': 'CNY', 'cik': '0000000000', 'fillingDate': '2022-12-31', 'acceptedDate': '2022-12-30 19:00:00', 'calendarYear': '2022', 'period': 'FY', 'revenue': 724868000000, 'costOfRevenue': 0, 'grossProfit': 724868000000, 'grossProfitRatio': 1, 'researchAndDevelopmentExpenses': 0, 'generalAndAdministrativeExpenses': 229273000000, 'sellingAndMarketingExpenses': 0, 'sellingGeneralAndAdministrativeExpenses': 229273000000, 'otherExpenses': 42521000000, 'operatingExpenses': 271794000000, 'costAndExpenses': 271794000000, 'interestIncome': 1108547000000, 'interestExpense': 518581000000, 'depreciationAndAmortization': 20331000000, 'ebitda': 845580000000, 'ebitdaratio': 1.1665296302, 'operatingIncome': 825249000000, 'operatingIncomeRatio': 1.138481765, 'totalOtherIncomeExpensesNet': -519033000000, 'incomeBeforeTax': 306216000000, 'incomeBeforeTaxRatio': 0.4224438105, 'incomeTaxExpense': 47528000000, 'netIncome': 259232000000, 'netIncomeRatio': 0.357626492, 'eps': 0.69, 'epsdiluted': 0.69, 'weightedAverageShsOut': 349983033873, 'weightedAverageShsOutDil': 349983033873, 'link': '', 'finalLink': '', 'original_name': 'Agricultural Bank of China'}
#
# symbol: 0000070858
# cik: 0000070858
# JSON: {'date': '2022-12-31', 'symbol': 'BAC-PM', 'reportedCurrency': 'USD', 'cik': '0000070858', 'fillingDate': '2023-02-22', 'acceptedDate': '2023-02-22 16:33:50', 'calendarYear': '2022', 'period': 'FY', 'revenue': 94950000000, 'costOfRevenue': 0, 'grossProfit': 94950000000, 'grossProfitRatio': 1, 'researchAndDevelopmentExpenses': 0, 'generalAndAdministrativeExpenses': 40468000000, 'sellingAndMarketingExpenses': 5478000000, 'sellingGeneralAndAdministrativeExpenses': 45946000000, 'otherExpenses': -89824000000, 'operatingExpenses': -43878000000, 'costAndExpenses': -43878000000, 'interestIncome': 72565000000, 'interestExpense': 20103000000, 'depreciationAndAmortization': 1978000000, 'ebitda': 53050000000, 'ebitdaratio': 0.5587151132, 'operatingIncome': 51072000000, 'operatingIncomeRatio': 0.5378830964, 'totalOtherIncomeExpensesNet': -20103000000, 'incomeBeforeTax': 30969000000, 'incomeBeforeTaxRatio': 0.3261611374, 'incomeTaxExpense': 3441000000, 'netIncome': 27528000000, 'netIncomeRatio': 0.2899210111, 'eps': 0, 'epsdiluted': 0, 'weightedAverageShsOut': 0, 'weightedAverageShsOutDil': 0, 'link': 'https://www.sec.gov/Archives/edgar/data/70858/000007085823000092/0000070858-23-000092-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/70858/000007085823000092/bac-20221231.htm', 'original_name': 'Bank of America'}
#
# symbol: 0001413936
# cik: 0001413936
# JSON: []
#
# symbol: 0001082970
# cik: 0001082970
# JSON: []
#
# symbol: 0000789019
# cik: 0000789019
# JSON: {'date': '2022-06-30', 'symbol': 'MSFT', 'reportedCurrency': 'USD', 'cik': '0000789019', 'fillingDate': '2022-07-28', 'acceptedDate': '2022-07-28 16:06:19', 'calendarYear': '2022', 'period': 'FY', 'revenue': 198270000000, 'costOfRevenue': 62650000000, 'grossProfit': 135620000000, 'grossProfitRatio': 0.6840167448, 'researchAndDevelopmentExpenses': 24512000000, 'generalAndAdministrativeExpenses': 5900000000, 'sellingAndMarketingExpenses': 21825000000, 'sellingGeneralAndAdministrativeExpenses': 27725000000, 'otherExpenses': -32000000, 'operatingExpenses': 52237000000, 'costAndExpenses': 114887000000, 'interestIncome': 2094000000, 'interestExpense': 2063000000, 'depreciationAndAmortization': 14460000000, 'ebitda': 99905000000, 'ebitdaratio': 0.5038835931, 'operatingIncome': 83383000000, 'operatingIncomeRatio': 0.4205527816, 'totalOtherIncomeExpensesNet': 302000000, 'incomeBeforeTax': 83716000000, 'incomeBeforeTaxRatio': 0.4222323095, 'incomeTaxExpense': 10978000000, 'netIncome': 72738000000, 'netIncomeRatio': 0.3668633681, 'eps': 9.7, 'epsdiluted': 9.65, 'weightedAverageShsOut': 7496000000, 'weightedAverageShsOutDil': 7540000000, 'link': 'https://www.sec.gov/Archives/edgar/data/789019/000156459022026876/0001564590-22-026876-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/789019/000156459022026876/msft-10k_20220630.htm', 'original_name': 'Microsoft'}
#
# symbol: 0000320193
# cik: 0000320193
# JSON: {'date': '2022-09-24', 'symbol': 'AAPL', 'reportedCurrency': 'USD', 'cik': '0000320193', 'fillingDate': '2022-10-28', 'acceptedDate': '2022-10-27 18:01:14', 'calendarYear': '2022', 'period': 'FY', 'revenue': 394328000000, 'costOfRevenue': 223546000000, 'grossProfit': 170782000000, 'grossProfitRatio': 0.4330963056, 'researchAndDevelopmentExpenses': 26251000000, 'generalAndAdministrativeExpenses': 0, 'sellingAndMarketingExpenses': 0, 'sellingGeneralAndAdministrativeExpenses': 25094000000, 'otherExpenses': -334000000, 'operatingExpenses': 51345000000, 'costAndExpenses': 274891000000, 'interestIncome': 2825000000, 'interestExpense': 2931000000, 'depreciationAndAmortization': 11104000000, 'ebitda': 130541000000, 'ebitdaratio': 0.3310467428, 'operatingIncome': 119437000000, 'operatingIncomeRatio': 0.302887444, 'totalOtherIncomeExpensesNet': -334000000, 'incomeBeforeTax': 119103000000, 'incomeBeforeTaxRatio': 0.3020404333, 'incomeTaxExpense': 19300000000, 'netIncome': 99803000000, 'netIncomeRatio': 0.2530964071, 'eps': 6.15, 'epsdiluted': 6.11, 'weightedAverageShsOut': 16215963000, 'weightedAverageShsOutDil': 16325819000, 'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/0000320193-22-000108-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924.htm', 'original_name': 'Apple'}
#
# symbol: 0001095697
# cik: 0001095697
# JSON: []
#
# symbol: 0001289018
# cik: 0001289018
# JSON: []
#
# symbol: 0000834071
# cik: 0000834071
# JSON: []
#
# symbol: 0000879316
# cik: 0000879316
# JSON: []
#
# symbol: 0000731766
# cik: 0000731766
# JSON: {'date': '2022-12-31', 'symbol': 'UNH', 'reportedCurrency': 'USD', 'cik': '0000731766', 'fillingDate': '2023-02-24', 'acceptedDate': '2023-02-24 17:28:40', 'calendarYear': '2022', 'period': 'FY', 'revenue': 322132000000, 'costOfRevenue': 244545000000, 'grossProfit': 77587000000, 'grossProfitRatio': 0.2408546807, 'researchAndDevelopmentExpenses': 0, 'generalAndAdministrativeExpenses': 0, 'sellingAndMarketingExpenses': 0, 'sellingGeneralAndAdministrativeExpenses': 47782000000, 'otherExpenses': 51182000000, 'operatingExpenses': 51182000000, 'costAndExpenses': 295727000000, 'interestIncome': 2092000000, 'interestExpense': 2092000000, 'depreciationAndAmortization': 1370000000, 'ebitda': 29805000000, 'ebitdaratio': 0.0925241826, 'operatingIncome': 28435000000, 'operatingIncomeRatio': 0.0882712677, 'totalOtherIncomeExpensesNet': -2092000000, 'incomeBeforeTax': 26343000000, 'incomeBeforeTaxRatio': 0.0817770355, 'incomeTaxExpense': 5704000000, 'netIncome': 20120000000, 'netIncomeRatio': 0.0624588678, 'eps': 21.47, 'epsdiluted': 21.18, 'weightedAverageShsOut': 937000000, 'weightedAverageShsOutDil': 950000000, 'link': 'https://www.sec.gov/Archives/edgar/data/731766/000073176623000008/0000731766-23-000008-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data
index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/313807/000031380723000009/bp-20221231.htm', 'original_name': 'BP'}
#
# symbol: 0001834694
# cik: 0001834694
# JSON: []
#
# symbol: 0000068136
# cik: 0000068136
# JSON: []
#
# symbol: 0001326801
# cik: 0001326801
# JSON: {'date': '2022-12-31', 'symbol': 'META', 'reportedCurrency': 'USD', 'cik': '0001326801', 'fillingDate': '2023-02-02', 'acceptedDate': '2023-02-01 20:26:31', 'calendarYear': '2022', 'period': 'FY', 'revenue': 116609000000, 'costOfRevenue': 25249000000, 'grossProfit': 91360000000, 'grossProfitRatio': 0.7834729738, 'researchAndDevelopmentExpenses': 35338000000, 'generalAndAdministrativeExpenses': 11816000000, 'sellingAndMarketingExpenses': 15262000000, 'sellingGeneralAndAdministrativeExpenses': 27078000000, 'otherExpenses': -320000000, 'operatingExpenses': 62416000000, 'costAndExpenses': 87665000000, 'interestIncome': 276000000, 'interestExpense': 276000000, 'depreciationAndAmortization': 8686000000, 'ebitda': 37630000000, 'ebitdaratio': 0.3227023643, 'operatingIncome': 28944000000, 'operatingIncomeRatio': 0.2482141173, 'totalOtherIncomeExpensesNet': -401000000, 'incomeBeforeTax': 28819000000, 'incomeBeforeTaxRatio': 0.2471421588, 'incomeTaxExpense': 5619000000, 'netIncome': 23200000000, 'netIncomeRatio': 0.1989554837, 'eps': 8.63, 'epsdiluted': 8.59, 'weightedAverageShsOut': 2687000000, 'weightedAverageShsOutDil': 2702000000, 'link': 'https://www.sec.gov/Archives/edgar/data/1326801/000132680123000013/0001326801-23-000013-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/1326801/000132680123000013/meta-20221231.htm', 'original_name': 'Meta Platforms'}
#
# symbol: 0000908732
# cik: 0000908732
# JSON: {'date': '2022-12-31', 'symbol': 'SPTJF', 'reportedCurrency': 'CNY', 'cik': '0000908732', 'fillingDate': '2023-04-26', 'acceptedDate': '2023-04-26 06:40:16', 'calendarYear': '2022', 'period': 'FY', 'revenue': 72654563000, 'costOfRevenue': 76265940000, 'grossProfit': -3611377000, 'grossProfitRatio': -0.0497061279, 'researchAndDevelopmentExpenses': 127072000, 'generalAndAdministrativeExpenses': 12037000, 'sellingAndMarketingExpenses': 288701000, 'sellingGeneralAndAdministrativeExpenses': 288701000, 'otherExpenses': -84866000, 'operatingExpenses': 203835000, 'costAndExpenses': 76469775000, 'interestIncome': 535120000, 'interestExpense': 98502000, 'depreciationAndAmortization': 373580000, 'ebitda': -3469786000, 'ebitdaratio': -0.0477573033, 'operatingIncome': -3843366000, 'operatingIncomeRatio': -0.0528991689, 'totalOtherIncomeExpensesNet': 269712000, 'incomeBeforeTax': -3573654000, 'incomeBeforeTaxRatio': -0.0491869176, 'incomeTaxExpense': -731354000, 'netIncome': -2842300000, 'netIncomeRatio': -0.0391207363, 'eps': -0.26, 'epsdiluted': -0.26, 'weightedAverageShsOut': 10819622000, 'weightedAverageShsOutDil': 10819622000, 'link': 'https://www.sec.gov/Archives/edgar/data/908732/000119312523116597/0001193125-23-116597-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data
enses': 42238000000, 'sellingGeneralAndAdministrativeExpenses': 138428000000, 'otherExpenses': -16806000000, 'operatingExpenses': 229713000000, 'costAndExpenses': 518544000000, 'interestIncome': 989000000, 'interestExpense': 2367000000, 'depreciationAndAmortization': 41921000000, 'ebitda': 54618000000, 'ebitdaratio': 0.106264215, 'operatingIncome': 12248000000, 'operatingIncomeRatio': 0.0238295819, 'totalOtherIncomeExpensesNet': -16806000000, 'incomeBeforeTax': -5936000000, 'incomeBeforeTaxRatio': -0.0115490201, 'incomeTaxExpense': -3217000000, 'netIncome': -2722000000, 'netIncomeRatio': -0.005295895, 'eps': -0.27, 'epsdiluted': -0.27, 'weightedAverageShsOut': 10189000000, 'weightedAverageShsOutDil': 10189000000, 'link': 'https://www.sec.gov/Archives/edgar/data/1018724/000101872423000004/0001018724-23-000004-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/1018724/000101872423000004/amzn-20221231.htm', 'original_name': 'Amazon'}
#
# symbol: 0000069596
# cik: 0000069596
# JSON: []
#
# symbol: 0000050916
# cik: 0000050916
# JSON: []
#
# symbol: 0000078003
# cik: 0000078003
# JSON: {'date': '2022-12-31', 'symbol': 'PFE', 'reportedCurrency': 'USD', 'cik': '0000078003', 'fillingDate': '2023-02-23', 'acceptedDate': '2023-02-23 14:12:53', 'calendarYear': '2022', 'period': 'FY', 'revenue': 100330000000, 'costOfRevenue': 34344000000, 'grossProfit': 65986000000, 'grossProfitRatio': 0.6576896242, 'researchAndDevelopmentExpenses': 11428000000, 'generalAndAdministrativeExpenses': 10877000000, 'sellingAndMarketingExpenses': 2800000000, 'sellingGeneralAndAdministrativeExpenses': 13677000000, 'otherExpenses': 3609000000, 'operatingExpenses': 28714000000, 'costAndExpenses': 63058000000, 'interestIncome': 251000000, 'interestExpense': 1238000000, 'depreciationAndAmortization': 3609000000, 'ebitda': 43639000000, 'ebitdaratio': 0.4349546497, 'operatingIncome': 40030000000, 'operatingIncomeRatio': 0.3989833549, 'totalOtherIncomeExpensesNet': -5301000000, 'incomeBeforeTax': 34729000000, 'incomeBeforeTaxRatio': 0.3461477125, 'incomeTaxExpense': 3328000000, 'netIncome': 31372000000, 'netIncomeRatio': 0.3126881292, 'eps': 5.59, 'epsdiluted': 5.47, 'weightedAverageShsOut': 5608000000, 'weightedAverageShsOutDil': 5733000000, 'link': 'https://www.sec.gov/Archives/edgar/data/78003/000007800323000024/0000078003-23-000024-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/78003/000007800323000024/pfe-20221231.htm', 'original_name': 'Pfizer'}
#
# symbol: 0000200406
# cik: 0000200406
# JSON: {'date': '2023-01-01', 'symbol': 'JNJ.SW', 'reportedCurrency': 'USD', 'cik': '0000200406', 'fillingDate': '2023-02-16', 'acceptedDate': '2023-02-16 16:01:53', 'calendarYear': '2022', 'period': 'FY', 'revenue': 94943000000, 'costOfRevenue': 31089000000, 'grossProfit': 63854000000, 'grossProfitRatio': 0.672550899, 'researchAndDevelopmentExpenses': 15386000000, 'generalAndAdministrativeExpenses': 22665000000, 'sellingAndMarketingExpenses': 2100000000, 'sellingGeneralAndAdministrativeExpenses': 24765000000, '
index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/1119639/000129281423001253/pbrform20f_2022.htm', 'original_name': 'Petrobras'}
#
# symbol: 0001032383
# cik: 0001032383
# JSON: []
#
# symbol: nan
# cik: nan
# JSON: {'date': '2022-12-31', 'symbol': '024110.KS', 'reportedCurrency': 'KRW', 'cik': '0000000000', 'fillingDate': '2022-12-31', 'acceptedDate': '2022-12-30 19:00:00', 'calendarYear': '2022', 'period': 'FY', 'revenue': 9188512000000, 'costOfRevenue': 0, 'grossProfit': 9188512000000, 'grossProfitRatio': 1, 'researchAndDevelopmentExpenses': 0, 'generalAndAdministrativeExpenses': 0, 'sellingAndMarketingExpenses': 157955000000, 'sellingGeneralAndAdministrativeExpenses': 157955000000, 'otherExpenses': 3810216000000, 'operatingExpenses': 3968171000000, 'costAndExpenses': 3968171000000, 'interestIncome': 12532949000000, 'interestExpense': 4916438000000, 'depreciationAndAmortization': 271388000000, 'ebitda': 8921562000000, 'ebitdaratio': 0.9709474178, 'operatingIncome': 8650174000000, 'operatingIncomeRatio': 0.9414118412, 'totalOtherIncomeExpensesNet': -4909404000000, 'incomeBeforeTax': 3740770000000, 'incomeBeforeTaxRatio': 0.407113796, 'incomeTaxExpense': 959966000000, 'netIncome': 2667696000000, 'netIncomeRatio': 0.2903294897, 'eps': 3179.81, 'epsdiluted': 3179.81, 'weightedAverageShsOut': 746047000, 'weightedAverageShsOutDil': 746047000, 'link': '', 'finalLink': '', 'original_name': 'Industrial Bank'}
#
# symbol: 0000948034
# cik: 0000948034
# JSON: []
#
# symbol: 0001268896
# cik: 0001268896
# JSON: {'date': '2022-12-31', 'symbol': 'CILJF', 'reportedCurrency': 'CNY', 'cik': '0001268896', 'fillingDate': '2023-04-21', 'acceptedDate': '2023-04-21 07:05:30', 'calendarYear': '2022', 'period': 'FY', 'revenue': 803975000000, 'costOfRevenue': 0, 'grossProfit': 803975000000, 'grossProfitRatio': 1, 'researchAndDevelopmentExpenses': 0, 'generalAndAdministrativeExpenses': 39874000000, 'sellingAndMarketingExpenses': 2893000000, 'sellingGeneralAndAdministrativeExpenses': 39874000000, 'otherExpenses': -830617000000, 'operatingExpenses': -790743000000, 'costAndExpenses': 779928000000, 'interestIncome': 0, 'interestExpense': 4863000000, 'depreciationAndAmortization': 5291000000, 'ebitda': 18523000000, 'ebitdaratio': 0.0230392736, 'operatingIncome': 13232000000, 'operatingIncomeRatio': 0.0164582232, 'totalOtherIncomeExpensesNet': 9383000000, 'incomeBeforeTax': 24047000000, 'incomeBeforeTaxRatio': 0.029910134, 'incomeTaxExpense': -9467000000, 'netIncome': 32082000000, 'netIncomeRatio': 0.0399042259, 'eps': 1.14, 'epsdiluted': 1.14, 'weightedAverageShsOut': 28265000000, 'weightedAverageShsOutDil': 28265000000, 'link': 'https://www.sec.gov/Archives/edgar/data/1268896/000119312523109212/0001193125-23-109212-index.htm', 'finalLink': 'https://www.sec.gov/Archives/edgar/data/1268896/000119312523109212/d389085d20f.htm', 'original_name': 'China Life Insurance'}
#
# symbol: 0000004962
# cik: 0000004962
# ...
#   'operatingIncome': 5664000000,
#   'operatingIncomeRatio': 0.1242650285,
#   'totalOtherIncomeExpensesNet': -1710000000,
#   'incomeBeforeTax': 3954000000,
#   'incomeBeforeTaxRatio': 0.0867485739,
#   'incomeTaxExpense': 1330000000,
#   'netIncome': 2237000000,
#   'netIncomeRatio': 0.0490785432,
#   'eps': 0.0783,
#   'epsdiluted': 0.078,
#   'weightedAverageShsOut': 28564423478,
#   'weightedAverageShsOutDil': 28661423478,
#   'link': 'https://www.sec.gov/Archives/edgar/data/839923/000110465922071759/0001104659-22-071759-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/839923/000110465922071759/vod-20220331x20f.htm',
#   'original_name': 'Vodafone'},
#  {'date': '2022-03-31',
#   'symbol': 'SVNBY',
#   'reportedCurrency': 'JPY',
#   'cik': '0000000000',
#   'fillingDate': '2022-03-31',
#   'acceptedDate': '2022-03-30 20:00:00',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 135742000000,
#   'costOfRevenue': 0,
#   'grossProfit': 135742000000,
#   'grossProfitRatio': 1,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 70371000000,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 70371000000,
#   'otherExpenses': -80951000000,
#   'operatingExpenses': 80951000000,
#   'costAndExpenses': 106663000000,
#   'interestIncome': 4032000000,
#   'interestExpense': 560000000,
#   'depreciationAndAmortization': 16388000000,
#   'ebitda': 16531000000,
#   'ebitdaratio': 0.1217824992,
#   'operatingIncome': 143000000,
#   'operatingIncomeRatio': 0.0010534691,
#   'totalOtherIncomeExpensesNet': 27154000000,
#   'incomeBeforeTax': 27154000000,
#   'incomeBeforeTaxRatio': 0.2000412547,
#   'incomeTaxExpense': 6471000000,
#   'netIncome': 20827000000,
#   'netIncomeRatio': 0.1534307731,
#   'eps': 17.72,
#   'epsdiluted': 17.72,
#   'weightedAverageShsOut': 1175596000,
#   'weightedAverageShsOutDil': 1175596000,
#   'link': None,
#   'finalLink': None,
#   'original_name': 'Seven & I Holdings'},
#  {'date': '2022-03-31',
#   'symbol': 'HDB',
#   'reportedCurrency': 'INR',
#   'cik': '0001144967',
#   'fillingDate': '2022-07-29',
#   'acceptedDate': '2022-07-29 16:12:09',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 1019413700000,
#   'costOfRevenue': 0,
#   'grossProfit': 1019413700000,
#   'grossProfitRatio': 1,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 320219100000,
#   'sellingAndMarketingExpenses': 2625400000,
#   'sellingGeneralAndAdministrativeExpenses': 320219100000,
#   'otherExpenses': -821073200000,
#   'operatingExpenses': -500854100000,
#   'costAndExpenses': -500854100000,
#   'interestIncome': 1333137000000,
#   'interestExpense': 584297500000,
#   'depreciationAndAmortization': 16816900000,
#   'ebitda': 535376500000,
#   'ebitdaratio': 0.5251807976,
#   'operatingIncome': 518559600000,
#   'operatingIncomeRatio': 0.5086841584,
#   'totalOtherIncomeExpensesNet': 602600000,
#   'incomeBeforeTax': 519162200000,
#   'incomeBeforeTaxRatio': 0.5092752824,
#   'incomeTaxExpense': 132559200000,
#   'netIncome': 386000400000,
#   'netIncomeRatio': 0.3786494139,
#   'eps': 209.28,
#   'epsdiluted': 208.14,
#   'weightedAverageShsOut': 1856865790,
#   'weightedAverageShsOutDil': 1856978000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/1144967/000119312522206623/0001193125-22-206623-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/1144967/000119312522206623/d249746d20f.htm',
#   'original_name': 'HDFC'},
#  [],
#  {'date': '2022-12-31',
#   'symbol': 'NGLOY',
#   'reportedCurrency': 'USD',
#   'cik': '0000000000',
#   'fillingDate': '2022-12-31',
#   'acceptedDate': '2022-12-31 00:00:00',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 35118000000,
#   'costOfRevenue': 15526000000,
#   'grossProfit': 19592000000,
#   'grossProfitRatio': 0.5578905405,
#   'researchAndDevelopmentExpenses': 167000000,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 2898000000,
#   'sellingGeneralAndAdministrativeExpenses': 2898000000,
#   'otherExpenses': 21395000000,
#   'operatingExpenses': 24293000000,
#   'costAndExpenses': 24293000000,
#   'interestIncome': 215000000,
#   'interestExpense': 516000000,
#   'depreciationAndAmortization': 4989000000,
#   'ebitda': 14232000000,
#   'ebitdaratio': 0.4052622587,
#   'operatingIncome': 9243000000,
#   'operatingIncomeRatio': 0.2631983598,
#   'totalOtherIncomeExpensesNet': 237000000,
#   'incomeBeforeTax': 9480000000,
#   'incomeBeforeTaxRatio': 0.2699470357,
#   'incomeTaxExpense': 3456000000,
#   'netIncome': 6024000000,
#   'netIncomeRatio': 0.1715359645,
#   'eps': 2.48,
#   'epsdiluted': 2.46,
#   'weightedAverageShsOut': 2430000000,
#   'weightedAverageShsOutDil': 2452000000,
#   'link': None,
#   'finalLink': None,
#   'original_name': 'Anglo American'},
#  {'date': '2022-12-31',
#   'symbol': 'MA',
#   'reportedCurrency': 'USD',
#   'cik': '0001141391',
#   'fillingDate': '2023-02-14',
#   'acceptedDate': '2023-02-14 16:48:22',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 22237000000,
#   'costOfRevenue': 5263000000,
#   'grossProfit': 16974000000,
#   'grossProfitRatio': 0.7633223906,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 8078000000,
#   'sellingAndMarketingExpenses': 789000000,
#   'sellingGeneralAndAdministrativeExpenses': 8867000000,
#   'otherExpenses': 750000000,
#   'operatingExpenses': 9617000000,
#   'costAndExpenses': 9617000000,
#   'interestIncome': 61000000,
#   'interestExpense': 471000000,
#   'depreciationAndAmortization': 1129000000,
#   'ebitda': 13393000000,
#   'ebitdaratio': 0.6022844808,
#   'operatingIncome': 12264000000,
#   'operatingIncomeRatio': 0.5515132437,
#   'totalOtherIncomeExpensesNet': -532000000,
#   'incomeBeforeTax': 11732000000,
#   'incomeBeforeTaxRatio': 0.5275891532,
#   'incomeTaxExpense': 1802000000,
#   'netIncome': 9930000000,
#   'netIncomeRatio': 0.4465530422,
#   'eps': 10.26,
#   'epsdiluted': 10.23,
#   'weightedAverageShsOut': 968000000,
#   'weightedAverageShsOutDil': 971000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/1141391/000114139123000020/0001141391-23-000020-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/1141391/000114139123000020/ma-20221231.htm',
#   'original_name': 'Mastercard'},
#  {'date': '2022-12-31',
#   'symbol': 'NVO',
#   'reportedCurrency': 'DKK',
#   'cik': '0000353278',
#   'fillingDate': '2023-02-01',
#   'acceptedDate': '2023-02-01 07:53:07',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 176954000000,
#   'costOfRevenue': 28448000000,
#   'grossProfit': 148506000000,
#   'grossProfitRatio': 0.8392350554,
#   'researchAndDevelopmentExpenses': 24047000000,
#   'generalAndAdministrativeExpenses': 4467000000,
#   'sellingAndMarketingExpenses': 46217000000,
#   'sellingGeneralAndAdministrativeExpenses': 50684000000,
#   'otherExpenses': -1034000000,
#   'operatingExpenses': 73697000000,
#   'costAndExpenses': 102145000000,
#   'interestIncome': 239000000,
#   'interestExpense': 378000000,
#   'depreciationAndAmortization': 7231000000,
#   'ebitda': 82040000000,
#   'ebitdaratio': 0.4636233145,
#   'operatingIncome': 74809000000,
#   'operatingIncomeRatio': 0.4227595872,
#   'totalOtherIncomeExpensesNet': -5747000000,
#   'incomeBeforeTax': 69062000000,
#   'incomeBeforeTaxRatio': 0.3902822202,
#   'incomeTaxExpense': 13537000000,
#   'netIncome': 55525000000,
#   'netIncomeRatio': 0.3137821129,
#   'eps': 12.26,
#   'epsdiluted': 12.22,
#   'weightedAverageShsOut': 4530600000,
#   'weightedAverageShsOutDil': 4544600000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/353278/000162828023001868/0001628280-23-001868-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/353278/000162828023001868/nvo-20221231.htm',
#   'original_name': 'Novo Nordisk'},
#  [],
#  [],
#  [],
#  {'date': '2022-12-31',
#   'symbol': 'ASML',
#   'reportedCurrency': 'EUR',
#   'cik': '0000937966',
#   'fillingDate': '2023-02-15',
#   'acceptedDate': '2023-02-15 06:05:47',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 21173400000,
#   'costOfRevenue': 10660700000,
#   'grossProfit': 10512700000,
#   'grossProfitRatio': 0.4965050488,
#   'researchAndDevelopmentExpenses': 2282100000,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 909600000,
#   'otherExpenses': 0,
#   'operatingExpenses': 3191700000,
#   'costAndExpenses': 13852400000,
#   'interestIncome': 16200000,
#   'interestExpense': 60800000,
#   'depreciationAndAmortization': 892100000,
#   'ebitda': 8213100000,
#   'ebitdaratio': 0.3878970784,
#   'operatingIncome': 7321000000,
#   'operatingIncomeRatio': 0.3457640247,
#   'totalOtherIncomeExpensesNet': -44600000,
#   'incomeBeforeTax': 7276400000,
#   'incomeBeforeTaxRatio': 0.3436576081,
#   'incomeTaxExpense': 1018600000,
#   'netIncome': 5624200000,
#   'netIncomeRatio': 0.265625738,
#   'eps': 14.14,
#   'epsdiluted': 14.13,
#   'weightedAverageShsOut': 397700000,
#   'weightedAverageShsOutDil': 398000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/937966/000093796623000014/0000937966-23-000014-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/937966/000093796623000014/asml-20221231.htm',
#   'original_name': 'ASML Holding'},
#  {'date': '2022-01-30',
#   'symbol': 'NVDA',
#   'reportedCurrency': 'USD',
#   'cik': '0001045810',
#   'fillingDate': '2022-03-18',
#   'acceptedDate': '2022-03-17 20:33:34',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 26914000000,
#   'costOfRevenue': 9439000000,
#   'grossProfit': 17475000000,
#   'grossProfitRatio': 0.6492903322,
#   'researchAndDevelopmentExpenses': 5268000000,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 2166000000,
#   'otherExpenses': 107000000,
#   'operatingExpenses': 7434000000,
#   'costAndExpenses': 16873000000,
#   'interestIncome': 29000000,
#   'interestExpense': 236000000,
#   'depreciationAndAmortization': 1310000000,
#   'ebitda': 11351000000,
#   'ebitdaratio': 0.4217507617,
#   'operatingIncome': 10041000000,
#   'operatingIncomeRatio': 0.3730772089,
#   'totalOtherIncomeExpensesNet': -100000000,
#   'incomeBeforeTax': 9941000000,
#   'incomeBeforeTaxRatio': 0.3693616705,
#   'incomeTaxExpense': 189000000,
#   'netIncome': 9752000000,
#   'netIncomeRatio': 0.362339303,
#   'eps': 0.39,
#   'epsdiluted': 0.39,
#   'weightedAverageShsOut': 24960000000,
#   'weightedAverageShsOutDil': 25350000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581022000036/0001045810-22-000036-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581022000036/nvda-20220130.htm',
#   'original_name': 'NVIDIA'},
#  {'date': '2022-12-31',
#   'symbol': 'MMM',
#   'reportedCurrency': 'USD',
#   'cik': '0000066740',
#   'fillingDate': '2023-02-08',
#   'acceptedDate': '2023-02-08 12:59:49',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 34229000000,
#   'costOfRevenue': 19232000000,
#   'grossProfit': 14997000000,
#   'grossProfitRatio': 0.438137252,
#   'researchAndDevelopmentExpenses': 1862000000,
#   'generalAndAdministrativeExpenses': 8801000000,
#   'sellingAndMarketingExpenses': 248000000,
#   'sellingGeneralAndAdministrativeExpenses': 9049000000,
#   'otherExpenses': -147000000,
#   'operatingExpenses': 10911000000,
#   'costAndExpenses': 30143000000,
#   'interestIncome': 67000000,
#   'interestExpense': 462000000,
#   'depreciationAndAmortization': 1831000000,
#   'ebitda': 8370000000,
#   'ebitdaratio': 0.2445294925,
#   'operatingIncome': 6539000000,
#   'operatingIncomeRatio': 0.1910368401,
#   'totalOtherIncomeExpensesNet': -147000000,
#   'incomeBeforeTax': 6392000000,
#   'incomeBeforeTaxRatio': 0.1867422361,
#   'incomeTaxExpense': 612000000,
#   'netIncome': 5777000000,
#   'netIncomeRatio': 0.1687750153,
#   'eps': 10.21,
#   'epsdiluted': 10.18,
#   'weightedAverageShsOut': 566000000,
#   'weightedAverageShsOutDil': 567600000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/66740/000006674023000014/0000066740-23-000014-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/66740/000006674023000014/mmm-20221231.htm',
#   'original_name': '3M'},
#  {'date': '2022-12-31',
#   'symbol': 'EOG',
#   'reportedCurrency': 'USD',
#   'cik': '0000821189',
#   'fillingDate': '2023-02-23',
#   'acceptedDate': '2023-02-23 16:23:25',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 29492000000,
#   'costOfRevenue': 5494000000,
#   'grossProfit': 23998000000,
#   'grossProfitRatio': 0.8137121931,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 570000000,
#   'sellingAndMarketingExpenses': 6535000000,
#   'sellingGeneralAndAdministrativeExpenses': 7105000000,
#   'otherExpenses': 2637000000,
#   'operatingExpenses': 9742000000,
#   'costAndExpenses': 15236000000,
#   'interestIncome': 85000000,
#   'interestExpense': 179000000,
#   'depreciationAndAmortization': 910000000,
#   'ebitda': 15280000000,
#   'ebitdaratio': 0.5181066052,
#   'operatingIncome': 14370000000,
#   'operatingIncomeRatio': 0.4872507799,
#   'totalOtherIncomeExpensesNet': -4469000000,
#   'incomeBeforeTax': 9901000000,
#   'incomeBeforeTaxRatio': 0.3357181609,
#   'incomeTaxExpense': 2142000000,
#   'netIncome': 7759000000,
#   'netIncomeRatio': 0.2630882951,
#   'eps': 13.31,
#   'epsdiluted': 13.22,
#   'weightedAverageShsOut': 583000000,
#   'weightedAverageShsOutDil': 587000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/821189/000082118923000015/0000821189-23-000015-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/821189/000082118923000015/eog-20221231.htm',
#   'original_name': 'EOG Resources'},
#  {'date': '2022-03-31',
#   'symbol': 'TKPHF',
#   'reportedCurrency': 'JPY',
#   'cik': '0001395064',
#   'fillingDate': '2022-06-29',
#   'acceptedDate': '2022-06-29 06:05:31',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 3569006000000,
#   'costOfRevenue': 1106846000000,
#   'grossProfit': 2462160000000,
#   'grossProfitRatio': 0.6898727545,
#   'researchAndDevelopmentExpenses': 526087000000,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 886361000000,
#   'otherExpenses': -20723000000,
#   'operatingExpenses': 2001315000000,
#   'costAndExpenses': 3108161000000,
#   'interestIncome': 23700000000,
#   'interestExpense': 166607000000,
#   'depreciationAndAmortization': 583151000000,
#   'ebitda': 1052329000000,
#   'ebitdaratio': 0.2948521241,
#   'operatingIncome': 460844000000,
#   'operatingIncomeRatio': 0.1291239073,
#   'totalOtherIncomeExpensesNet': -15367000000,
#   'incomeBeforeTax': 302571000000,
#   'incomeBeforeTaxRatio': 0.0847773862,
#   'incomeTaxExpense': 72405000000,
#   'netIncome': 230059000000,
#   'netIncomeRatio': 0.0644602447,
#   'eps': 147.14,
#   'epsdiluted': 145.87,
#   'weightedAverageShsOut': 1563501000,
#   'weightedAverageShsOutDil': 1577169000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/1395064/000139506422000107/0001395064-22-000107-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/1395064/000139506422000107/tak-20220331.htm',
#   'original_name': 'Takeda Pharmaceutical'},
#  {'date': '2022-12-31',
#   'symbol': 'SLF',
#   'reportedCurrency': 'CAD',
#   'cik': '0001097362',
#   'fillingDate': '2022-12-31',
#   'acceptedDate': '2022-12-30 19:00:00',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 23207000000,
#   'costOfRevenue': 0,
#   'grossProfit': 23207000000,
#   'grossProfitRatio': 1,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 5107000000,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 5107000000,
#   'otherExpenses': -24002000000,
#   'operatingExpenses': -18895000000,
#   'costAndExpenses': 19284000000,
#   'interestIncome': 5863000000,
#   'interestExpense': 445000000,
#   'depreciationAndAmortization': 528000000,
#   'ebitda': 4840000000,
#   'ebitdaratio': 0.2085577627,
#   'operatingIncome': 4312000000,
#   'operatingIncomeRatio': 0.1858060068,
#   'totalOtherIncomeExpensesNet': -389000000,
#   'incomeBeforeTax': 3923000000,
#   'incomeBeforeTaxRatio': 0.169043823,
#   'incomeTaxExpense': 621000000,
#   'netIncome': 3024000000,
#   'netIncomeRatio': 0.1303055113,
#   'eps': 4.9,
#   'epsdiluted': 4.89,
#   'weightedAverageShsOut': 586000000,
#   'weightedAverageShsOutDil': 589000000,
#   'link': '',
#   'finalLink': '',
#   'original_name': 'Sun Life Financial'}]

# %%
filtered_income_list = []
for item in income_list:
    if type(item) == dict:
        filtered_income_list.append(item)

filtered_income_list
# Out:
# [{'date': '2022-12-31',
#   'symbol': 'JPM-PJ',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2023-02-21',
#   'acceptedDate': '2023-02-21 16:13:55',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 128695000000,
#   'costOfRevenue': 0,
#   'grossProfit': 128695000000,
#   'grossProfitRatio': 1,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 41636000000,
#   'sellingAndMarketingExpenses': 3911000000,
#   'sellingGeneralAndAdministrativeExpenses': 45547000000,
#   'otherExpenses': -109030000000,
#   'operatingExpenses': -63483000000,
#   'costAndExpenses': -63483000000,
#   'interestIncome': 92807000000,
#   'interestExpense': 26097000000,
#   'depreciationAndAmortization': 7051000000,
#   'ebitda': 72263000000,
#   'ebitdaratio': 0.561505886,
#   'operatingIncome': 65212000000,
#   'operatingIncomeRatio': 0.5067174327,
#   'totalOtherIncomeExpensesNet': -19046000000,
#   'incomeBeforeTax': 46166000000,
#   'incomeBeforeTaxRatio': 0.3587241152,
#   'incomeTaxExpense': 8490000000,
#   'netIncome': 37676000000,
#   'netIncomeRatio': 0.2927541863,
#   'eps': 12.47,
#   'epsdiluted': 12.47,
#   'weightedAverageShsOut': 2968734491,
#   'weightedAverageShsOutDil': 3021000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000001961723000231/0000019617-23-000231-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000001961723000231/jpm-20221231.htm',
#   'original_name': 'JPMorgan Chase'},
#  {'date': '2022-12-31',
#   'symbol': 'CNCB.VI',
#   'reportedCurrency': 'CNY',
#   'cik': '0000000000',
#   'fillingDate': '2022-12-31',
#   'acceptedDate': '2022-12-30 19:00:00',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 821279000000,
#   'costOfRevenue': 0,
#   'grossProfit': 821279000000,
#   'grossProfitRatio': 1,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 213219000000,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 213219000000,
#   'otherExpenses': 74000000,
#   'operatingExpenses': 285512000000,
#   'costAndExpenses': 285512000000,
#   'interestIncome': 1169900000000,
#   'interestExpense': 526836000000,
#   'depreciationAndAmortization': -398082000000,
#   'ebitda': 382712000000,
#   'ebitdaratio': 0.4659951125,
#   'operatingIncome': 382712000000,
#   'operatingIncomeRatio': 0.4659951125,
#   'totalOtherIncomeExpensesNet': -695000000,
#   'incomeBeforeTax': 382017000000,
#   'incomeBeforeTaxRatio': 0.4651488715,
#   'incomeTaxExpense': 58851000000,
#   'netIncome': 324727000000,
#   'netIncomeRatio': 0.3953918218,
#   'eps': 1.28,
#   'epsdiluted': 1.28,
#   'weightedAverageShsOut': 253016406250,
#   'weightedAverageShsOutDil': 253016406250,
#   'link': '',
#   'finalLink': '',
#   'original_name': 'China Construction Bank'},
#  {'date': '2022-12-31',
#   'symbol': 'EK7.VI',
#   'reportedCurrency': 'CNY',
#   'cik': '0000000000',
#   'fillingDate': '2022-12-31',
#   'acceptedDate': '2022-12-30 19:00:00',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 724868000000,
#   'costOfRevenue': 0,
#   'grossProfit': 724868000000,
#   'grossProfitRatio': 1,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 229273000000,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 229273000000,
#   'otherExpenses': 42521000000,
#   'operatingExpenses': 271794000000,
#   'costAndExpenses': 271794000000,
#   'interestIncome': 1108547000000,
#   'interestExpense': 518581000000,
#   'depreciationAndAmortization': 20331000000,
#   'ebitda': 845580000000,
#   'ebitdaratio': 1.1665296302,
#   'operatingIncome': 825249000000,
#   'operatingIncomeRatio': 1.138481765,
#   'totalOtherIncomeExpensesNet': -519033000000,
#   'incomeBeforeTax': 306216000000,
#   'incomeBeforeTaxRatio': 0.4224438105,
#   'incomeTaxExpense': 47528000000,
#   'netIncome': 259232000000,
#   'netIncomeRatio': 0.357626492,
#   'eps': 0.69,
#   'epsdiluted': 0.69,
#   'weightedAverageShsOut': 349983033873,
#   'weightedAverageShsOutDil': 349983033873,
#   'link': '',
#   'finalLink': '',
#   'original_name': 'Agricultural Bank of China'},
#  {'date': '2022-12-31',
#   'symbol': 'BAC-PM',
#   'reportedCurrency': 'USD',
#   'cik': '0000070858',
#   'fillingDate': '2023-02-22',
#   'acceptedDate': '2023-02-22 16:33:50',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 94950000000,
#   'costOfRevenue': 0,
#   'grossProfit': 94950000000,
#   'grossProfitRatio': 1,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 40468000000,
#   'sellingAndMarketingExpenses': 5478000000,
#   'sellingGeneralAndAdministrativeExpenses': 45946000000,
#   'otherExpenses': -89824000000,
#   'operatingExpenses': -43878000000,
#   'costAndExpenses': -43878000000,
#   'interestIncome': 72565000000,
#   'interestExpense': 20103000000,
#   'depreciationAndAmortization': 1978000000,
#   'ebitda': 53050000000,
#   'ebitdaratio': 0.5587151132,
#   'operatingIncome': 51072000000,
#   'operatingIncomeRatio': 0.5378830964,
#   'totalOtherIncomeExpensesNet': -20103000000,
#   'incomeBeforeTax': 30969000000,
#   'incomeBeforeTaxRatio': 0.3261611374,
#   'incomeTaxExpense': 3441000000,
#   'netIncome': 27528000000,
#   'netIncomeRatio': 0.2899210111,
#   'eps': 0,
#   'epsdiluted': 0,
#   'weightedAverageShsOut': 0,
#   'weightedAverageShsOutDil': 0,
#   'link': 'https://www.sec.gov/Archives/edgar/data/70858/000007085823000092/0000070858-23-000092-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/70858/000007085823000092/bac-20221231.htm',
#   'original_name': 'Bank of America'},
#  {'date': '2022-06-30',
#   'symbol': 'MSFT',
#   'reportedCurrency': 'USD',
#   'cik': '0000789019',
#   'fillingDate': '2022-07-28',
#   'acceptedDate': '2022-07-28 16:06:19',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 198270000000,
#   'costOfRevenue': 62650000000,
#   'grossProfit': 135620000000,
#   'grossProfitRatio': 0.6840167448,
#   'researchAndDevelopmentExpenses': 24512000000,
#   'generalAndAdministrativeExpenses': 5900000000,
#   'sellingAndMarketingExpenses': 21825000000,
#   'sellingGeneralAndAdministrativeExpenses': 27725000000,
#   'otherExpenses': -32000000,
#   'operatingExpenses': 52237000000,
#   'costAndExpenses': 114887000000,
#   'interestIncome': 2094000000,
#   'interestExpense': 2063000000,
#   'depreciationAndAmortization': 14460000000,
#   'ebitda': 99905000000,
#   'ebitdaratio': 0.5038835931,
#   'operatingIncome': 83383000000,
#   'operatingIncomeRatio': 0.4205527816,
#   'totalOtherIncomeExpensesNet': 302000000,
#   'incomeBeforeTax': 83716000000,
#   'incomeBeforeTaxRatio': 0.4222323095,
#   'incomeTaxExpense': 10978000000,
#   'netIncome': 72738000000,
#   'netIncomeRatio': 0.3668633681,
#   'eps': 9.7,
#   'epsdiluted': 9.65,
#   'weightedAverageShsOut': 7496000000,
#   'weightedAverageShsOutDil': 7540000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/789019/000156459022026876/0001564590-22-026876-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/789019/000156459022026876/msft-10k_20220630.htm',
#   'original_name': 'Microsoft'},
#  {'date': '2022-09-24',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2022-10-28',
#   'acceptedDate': '2022-10-27 18:01:14',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 394328000000,
#   'costOfRevenue': 223546000000,
#   'grossProfit': 170782000000,
#   'grossProfitRatio': 0.4330963056,
#   'researchAndDevelopmentExpenses': 26251000000,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 25094000000,
#   'otherExpenses': -334000000,
#   'operatingExpenses': 51345000000,
#   'costAndExpenses': 274891000000,
#   'interestIncome': 2825000000,
#   'interestExpense': 2931000000,
#   'depreciationAndAmortization': 11104000000,
#   'ebitda': 130541000000,
#   'ebitdaratio': 0.3310467428,
#   'operatingIncome': 119437000000,
#   'operatingIncomeRatio': 0.302887444,
#   'totalOtherIncomeExpensesNet': -334000000,
#   'incomeBeforeTax': 119103000000,
#   'incomeBeforeTaxRatio': 0.3020404333,
#   'incomeTaxExpense': 19300000000,
#   'netIncome': 99803000000,
#   'netIncomeRatio': 0.2530964071,
#   'eps': 6.15,
#   'epsdiluted': 6.11,
#   'weightedAverageShsOut': 16215963000,
#   'weightedAverageShsOutDil': 16325819000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/0000320193-22-000108-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019322000108/aapl-20220924.htm',
#   'original_name': 'Apple'},
#  {'date': '2022-12-31',
#   'symbol': 'UNH',
#   'reportedCurrency': 'USD',
#   'cik': '0000731766',
#   'fillingDate': '2023-02-24',
#   'acceptedDate': '2023-02-24 17:28:40',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 322132000000,
#   'costOfRevenue': 244545000000,
#   'grossProfit': 77587000000,
#   'grossProfitRatio': 0.2408546807,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 47782000000,
#   'otherExpenses': 51182000000,
#   'operatingExpenses': 51182000000,
#   'costAndExpenses': 295727000000,
#   'interestIncome': 2092000000,
#   'interestExpense': 2092000000,
#   'depreciationAndAmortization': 1370000000,
#   'ebitda': 29805000000,
#   'ebitdaratio': 0.0925241826,
#   'operatingIncome': 28435000000,
#   'operatingIncomeRatio': 0.0882712677,
#   'totalOtherIncomeExpensesNet': -2092000000,
#   'incomeBeforeTax': 26343000000,
#   'incomeBeforeTaxRatio': 0.0817770355,
#   'incomeTaxExpense': 5704000000,
#   'netIncome': 20120000000,
#   'netIncomeRatio': 0.0624588678,
#   'eps': 21.47,
#   'epsdiluted': 21.18,
#   'weightedAverageShsOut': 937000000,
#   'weightedAverageShsOutDil': 950000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/731766/000073176623000008/0000731766-23-000008-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/731766/000073176623000008/unh-20221231.htm',
#   'original_name': 'UnitedHealth Group'},
#  {'date': '2022-12-31',
#   'symbol': 'WFC-PY',
#   'reportedCurrency': 'USD',
#   'cik': '0000072971',
#   'fillingDate': '2023-02-21',
#   'acceptedDate': '2023-02-21 17:13:29',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 73785000000,
#   'costOfRevenue': 0,
#   'grossProfit': 73785000000,
#   'grossProfitRatio': 1,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 35090000000,
#   'sellingAndMarketingExpenses': 505000000,
#   'sellingGeneralAndAdministrativeExpenses': 35595000000,
#   'otherExpenses': -85037000000,
#   'operatingExpenses': -49442000000,
#   'costAndExpenses': -49442000000,
#   'interestIncome': 54024000000,
#   'interestExpense': 9074000000,
#   'depreciationAndAmortization': 6832000000,
#   'ebitda': 31175000000,
#   'ebitdaratio': 0.4225113505,
#   'operatingIncome': 24343000000,
#   'operatingIncomeRatio': 0.329918005,
#   'totalOtherIncomeExpensesNet': -9374000000,
#   'incomeBeforeTax': 14969000000,
#   'incomeBeforeTaxRatio': 0.2028732127,
#   'incomeTaxExpense': 2087000000,
#   'netIncome': 13677000000,
#   'netIncomeRatio': 0.1853628786,
#   'eps': 1.61,
#   'epsdiluted': 1.61,
#   'weightedAverageShsOut': 8165359956,
#   'weightedAverageShsOutDil': 8165359956,
#   'link': 'https://www.sec.gov/Archives/edgar/data/72971/000007297123000071/0000072971-23-000071-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/72971/000007297123000071/wfc-20221231.htm',
#   'original_name': 'Wells Fargo'},
#  {'date': '2022-12-31',
#   'symbol': 'CVX',
#   'reportedCurrency': 'USD',
#   'cik': '0000093410',
#   'fillingDate': '2023-02-23',
#   'acceptedDate': '2023-02-23 11:51:02',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 235717000000,
#   'costOfRevenue': 161735000000,
#   'grossProfit': 73982000000,
#   'grossProfitRatio': 0.3138594162,
#   'researchAndDevelopmentExpenses': 268000000,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 4312000000,
#   'otherExpenses': 30015000000,
#   'operatingExpenses': 34327000000,
#   'costAndExpenses': 196062000000,
#   'interestIncome': 516000000,
#   'interestExpense': 516000000,
#   'depreciationAndAmortization': 16300000000,
#   'ebitda': 66490000000,
#   'ebitdaratio': 0.2820755397,
#   'operatingIncome': 50190000000,
#   'operatingIncomeRatio': 0.2129248209,
#   'totalOtherIncomeExpensesNet': -516000000,
#   'incomeBeforeTax': 49674000000,
#   'incomeBeforeTaxRatio': 0.2107357552,
#   'incomeTaxExpense': 14066000000,
#   'netIncome': 35465000000,
#   'netIncomeRatio': 0.1504558432,
#   'eps': 18.37,
#   'epsdiluted': 18.28,
#   'weightedAverageShsOut': 1931000000,
#   'weightedAverageShsOutDil': 1940000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/93410/000009341023000009/0000093410-23-000009-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/93410/000009341023000009/cvx-20221231.htm',
#   'original_name': 'Chevron'},
#  {'date': '2022-12-31',
#   'symbol': 'PCCYF',
#   'reportedCurrency': 'CNY',
#   'cik': '0001108329',
#   'fillingDate': '2023-04-28',
#   'acceptedDate': '2023-04-28 07:30:14',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 3239167000000,
#   'costOfRevenue': 2451116000000,
#   'grossProfit': 788051000000,
#   'grossProfitRatio': 0.2432881664,
#   'researchAndDevelopmentExpenses': 18556000000,
#   'generalAndAdministrativeExpenses': 222602000000,
#   'sellingAndMarketingExpenses': 68352000000,
#   'sellingGeneralAndAdministrativeExpenses': 222602000000,
#   'otherExpenses': 4713000000,
#   'operatingExpenses': 571391000000,
#   'costAndExpenses': 3022507000000,
#   'interestIncome': 4738000000,
#   'interestExpense': 21554000000,
#   'depreciationAndAmortization': 238036000000,
#   'ebitda': 236649000000,
#   'ebitdaratio': 0.0730585981,
#   'operatingIncome': 216660000000,
#   'operatingIncomeRatio': 0.0668875671,
#   'totalOtherIncomeExpensesNet': 13433000000,
#   'incomeBeforeTax': 213277000000,
#   'incomeBeforeTaxRatio': 0.0658431628,
#   'incomeTaxExpense': 49295000000,
#   'netIncome': 148738000000,
#   'netIncomeRatio': 0.0459185957,
#   'eps': 0.81,
#   'epsdiluted': 0.81,
#   'weightedAverageShsOut': 183020977818,
#   'weightedAverageShsOutDil': 183020977818,
#   'link': 'https://www.sec.gov/Archives/edgar/data/1108329/000119312523124228/0001193125-23-124228-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/1108329/000119312523124228/d456049d20f.htm',
#   'original_name': 'PetroChina'},
#  {'date': '2022-12-31',
#   'symbol': 'TTFNF',
#   'reportedCurrency': 'USD',
#   'cik': '0000879764',
#   'fillingDate': '2023-03-24',
#   'acceptedDate': '2023-03-24 12:13:13',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 263310000000,
#   'costOfRevenue': 181669000000,
#   'grossProfit': 81641000000,
#   'grossProfitRatio': 0.3100565873,
#   'researchAndDevelopmentExpenses': 762000000,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 1299000000,
#   'otherExpenses': -4495000000,
#   'operatingExpenses': 31088000000,
#   'costAndExpenses': 212757000000,
#   'interestIncome': 1143000000,
#   'interestExpense': 2386000000,
#   'depreciationAndAmortization': 13680000000,
#   'ebitda': 59352000000,
#   'ebitdaratio': 0.2254073146,
#   'operatingIncome': 45672000000,
#   'operatingIncomeRatio': 0.173453344,
#   'totalOtherIncomeExpensesNet': -6387000000,
#   'incomeBeforeTax': 43286000000,
#   'incomeBeforeTaxRatio': 0.1643917816,
#   'incomeTaxExpense': 22242000000,
#   'netIncome': 20526000000,
#   'netIncomeRatio': 0.0779537427,
#   'eps': 8.18,
#   'epsdiluted': 8.13,
#   'weightedAverageShsOut': 2554707397,
#   'weightedAverageShsOutDil': 2572182025,
#   'link': 'https://www.sec.gov/Archives/edgar/data/879764/000110465923036495/0001104659-23-036495-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/879764/000110465923036495/tot-20221231x20f.htm',
#   'original_name': 'TotalEnergies'},
#  {'date': '2022-01-31',
#   'symbol': 'WMT',
#   'reportedCurrency': 'USD',
#   'cik': '0000104169',
#   'fillingDate': '2022-03-18',
#   'acceptedDate': '2022-03-18 17:03:00',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 572754000000,
#   'costOfRevenue': 429000000000,
#   'grossProfit': 143754000000,
#   'grossProfitRatio': 0.2509873349,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 113912000000,
#   'sellingAndMarketingExpenses': 3900000000,
#   'sellingGeneralAndAdministrativeExpenses': 117812000000,
#   'otherExpenses': -3000000000,
#   'operatingExpenses': 117812000000,
#   'costAndExpenses': 546812000000,
#   'interestIncome': 158000000,
#   'interestExpense': 1994000000,
#   'depreciationAndAmortization': 7816000000,
#   'ebitda': 33758000000,
#   'ebitdaratio': 0.0589397892,
#   'operatingIncome': 25942000000,
#   'operatingIncomeRatio': 0.0452934419,
#   'totalOtherIncomeExpensesNet': -7246000000,
#   'incomeBeforeTax': 18696000000,
#   'incomeBeforeTaxRatio': 0.0326422862,
#   'incomeTaxExpense': 4756000000,
#   'netIncome': 13673000000,
#   'netIncomeRatio': 0.023872378,
#   'eps': 1.63,
#   'epsdiluted': 1.62,
#   'weightedAverageShsOut': 8375999832,
#   'weightedAverageShsOutDil': 8414999831,
#   'link': 'https://www.sec.gov/Archives/edgar/data/104169/000010416922000012/0000104169-22-000012-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/104169/000010416922000012/wmt-20220131.htm',
#   'original_name': 'Walmart'},
#  {'date': '2022-12-31',
#   'symbol': 'CIHKY',
#   'reportedCurrency': 'CNY',
#   'cik': '0000000000',
#   'fillingDate': '2022-12-31',
#   'acceptedDate': '2022-12-31 00:00:00',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 342258000000,
#   'costOfRevenue': 0,
#   'grossProfit': 342258000000,
#   'grossProfitRatio': 1,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 113375000000,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 113375000000,
#   'otherExpenses': 8686000000,
#   'operatingExpenses': 122061000000,
#   'costAndExpenses': 122061000000,
#   'interestIncome': 353380000000,
#   'interestExpense': 135145000000,
#   'depreciationAndAmortization': 14606000000,
#   'ebitda': 313582000000,
#   'ebitdaratio': 0.9162152528,
#   'operatingIncome': 298976000000,
#   'operatingIncomeRatio': 0.8735398442,
#   'totalOtherIncomeExpensesNet': -133863000000,
#   'incomeBeforeTax': 165113000000,
#   'incomeBeforeTaxRatio': 0.4824226169,
#   'incomeTaxExpense': 25819000000,
#   'netIncome': 138012000000,
#   'netIncomeRatio': 0.4032396613,
#   'eps': 5.26,
#   'epsdiluted': 5.26,
#   'weightedAverageShsOut': 25219845601,
#   'weightedAverageShsOutDil': 25219845601,
#   'link': None,
#   'finalLink': None,
#   'original_name': 'China Merchants Bank'},
#  {'date': '2022-12-31',
#   'symbol': 'BP',
#   'reportedCurrency': 'USD',
#   'cik': '0000313807',
#   'fillingDate': '2023-03-10',
#   'acceptedDate': '2023-03-10 06:06:30',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 241392000000,
#   'costOfRevenue': 186296000000,
#   'grossProfit': 55096000000,
#   'grossProfitRatio': 0.2282428581,
#   'researchAndDevelopmentExpenses': 274000000,
#   'generalAndAdministrativeExpenses': 13449000000,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 13449000000,
#   'otherExpenses': 585000000,
#   'operatingExpenses': 14034000000,
#   'costAndExpenses': 200330000000,
#   'interestIncome': 1103000000,
#   'interestExpense': 2703000000,
#   'depreciationAndAmortization': 14703000000,
#   'ebitda': 59467000000,
#   'ebitdaratio': 0.2463503347,
#   'operatingIncome': 44764000000,
#   'operatingIncomeRatio': 0.1854411082,
#   'totalOtherIncomeExpensesNet': -29359000000,
#   'incomeBeforeTax': 15405000000,
#   'incomeBeforeTaxRatio': 0.0638173593,
#   'incomeTaxExpense': 16762000000,
#   'netIncome': -1357000000,
#   'netIncomeRatio': -0.0056215616,
#   'eps': -0.43,
#   'epsdiluted': -0.43,
#   'weightedAverageShsOut': 3164656000,
#   'weightedAverageShsOutDil': 3164656000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/313807/000031380723000009/0000313807-23-000009-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/313807/000031380723000009/bp-20221231.htm',
#   'original_name': 'BP'},
#  {'date': '2022-12-31',
#   'symbol': 'META',
#   'reportedCurrency': 'USD',
#   'cik': '0001326801',
#   'fillingDate': '2023-02-02',
#   'acceptedDate': '2023-02-01 20:26:31',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 116609000000,
#   'costOfRevenue': 25249000000,
#   'grossProfit': 91360000000,
#   'grossProfitRatio': 0.7834729738,
#   'researchAndDevelopmentExpenses': 35338000000,
#   'generalAndAdministrativeExpenses': 11816000000,
#   'sellingAndMarketingExpenses': 15262000000,
#   'sellingGeneralAndAdministrativeExpenses': 27078000000,
#   'otherExpenses': -320000000,
#   'operatingExpenses': 62416000000,
#   'costAndExpenses': 87665000000,
#   'interestIncome': 276000000,
#   'interestExpense': 276000000,
#   'depreciationAndAmortization': 8686000000,
#   'ebitda': 37630000000,
#   'ebitdaratio': 0.3227023643,
#   'operatingIncome': 28944000000,
#   'operatingIncomeRatio': 0.2482141173,
#   'totalOtherIncomeExpensesNet': -401000000,
#   'incomeBeforeTax': 28819000000,
#   'incomeBeforeTaxRatio': 0.2471421588,
#   'incomeTaxExpense': 5619000000,
#   'netIncome': 23200000000,
#   'netIncomeRatio': 0.1989554837,
#   'eps': 8.63,
#   'epsdiluted': 8.59,
#   'weightedAverageShsOut': 2687000000,
#   'weightedAverageShsOutDil': 2702000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/1326801/000132680123000013/0001326801-23-000013-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/1326801/000132680123000013/meta-20221231.htm',
#   'original_name': 'Meta Platforms'},
#  {'date': '2022-12-31',
#   'symbol': 'SPTJF',
#   'reportedCurrency': 'CNY',
#   'cik': '0000908732',
#   'fillingDate': '2023-04-26',
#   'acceptedDate': '2023-04-26 06:40:16',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 72654563000,
#   'costOfRevenue': 76265940000,
#   'grossProfit': -3611377000,
#   'grossProfitRatio': -0.0497061279,
#   'researchAndDevelopmentExpenses': 127072000,
#   'generalAndAdministrativeExpenses': 12037000,
#   'sellingAndMarketingExpenses': 288701000,
#   'sellingGeneralAndAdministrativeExpenses': 288701000,
#   'otherExpenses': -84866000,
#   'operatingExpenses': 203835000,
#   'costAndExpenses': 76469775000,
#   'interestIncome': 535120000,
#   'interestExpense': 98502000,
#   'depreciationAndAmortization': 373580000,
#   'ebitda': -3469786000,
#   'ebitdaratio': -0.0477573033,
#   'operatingIncome': -3843366000,
#   'operatingIncomeRatio': -0.0528991689,
#   'totalOtherIncomeExpensesNet': 269712000,
#   'incomeBeforeTax': -3573654000,
#   'incomeBeforeTaxRatio': -0.0491869176,
#   'incomeTaxExpense': -731354000,
#   'netIncome': -2842300000,
#   'netIncomeRatio': -0.0391207363,
#   'eps': -0.26,
#   'epsdiluted': -0.26,
#   'weightedAverageShsOut': 10819622000,
#   'weightedAverageShsOutDil': 10819622000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/908732/000119312523116597/0001193125-23-116597-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/908732/000119312523116597/d474415d20f.htm',
#   'original_name': 'Sinopec'},
#  {'date': '2022-12-31',
#   'symbol': 'GS-PK',
#   'reportedCurrency': 'USD',
#   'cik': '0000886982',
#   'fillingDate': '2023-02-24',
#   'acceptedDate': '2023-02-23 19:58:16',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 47365000000,
#   'costOfRevenue': 16174000000,
#   'grossProfit': 31191000000,
#   'grossProfitRatio': 0.6585242267,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 15148000000,
#   'sellingAndMarketingExpenses': 812000000,
#   'sellingGeneralAndAdministrativeExpenses': 15960000000,
#   'otherExpenses': -970000000,
#   'operatingExpenses': 14990000000,
#   'costAndExpenses': 31164000000,
#   'interestIncome': 29024000000,
#   'interestExpense': 21346000000,
#   'depreciationAndAmortization': 2455000000,
#   'ebitda': 37287000000,
#   'ebitdaratio': 0.7872268553,
#   'operatingIncome': 34832000000,
#   'operatingIncomeRatio': 0.7353953341,
#   'totalOtherIncomeExpensesNet': -21346000000,
#   'incomeBeforeTax': 13486000000,
#   'incomeBeforeTaxRatio': 0.2847250079,
#   'incomeTaxExpense': 2225000000,
#   'netIncome': 11261000000,
#   'netIncomeRatio': 0.237749393,
#   'eps': 4.35,
#   'epsdiluted': 4.35,
#   'weightedAverageShsOut': 2586880058,
#   'weightedAverageShsOutDil': 2586880058,
#   'link': 'https://www.sec.gov/Archives/edgar/data/886982/000088698223000003/0000886982-23-000003-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/886982/000088698223000003/gs-20221231.htm',
#   'original_name': 'Goldman Sachs Group'},
#  {'date': '2022-12-31',
#   'symbol': 'TCEHY',
#   'reportedCurrency': 'CNY',
#   'cik': '0001293451',
#   'fillingDate': '2022-12-31',
#   'acceptedDate': '2022-12-31 00:00:00',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 554552000000,
#   'costOfRevenue': 315806000000,
#   'grossProfit': 238746000000,
#   'grossProfitRatio': 0.4305204922,
#   'researchAndDevelopmentExpenses': 61401000000,
#   'generalAndAdministrativeExpenses': 106696000000,
#   'sellingAndMarketingExpenses': 29229000000,
#   'sellingGeneralAndAdministrativeExpenses': 135925000000,
#   'otherExpenses': -11119000000,
#   'operatingExpenses': 124806000000,
#   'costAndExpenses': 440612000000,
#   'interestIncome': 8592000000,
#   'interestExpense': 9985000000,
#   'depreciationAndAmortization': 61216000000,
#   'ebitda': 149131000000,
#   'ebitdaratio': 0.2689215799,
#   'operatingIncome': 87915000000,
#   'operatingIncomeRatio': 0.1585333747,
#   'totalOtherIncomeExpensesNet': 122310000000,
#   'incomeBeforeTax': 210225000000,
#   'incomeBeforeTaxRatio': 0.3790897878,
#   'incomeTaxExpense': 21516000000,
#   'netIncome': 188243000000,
#   'netIncomeRatio': 0.3394505835,
#   'eps': 19.76,
#   'epsdiluted': 19.42,
#   'weightedAverageShsOut': 9528000000,
#   'weightedAverageShsOutDil': 9695000000,
#   'link': None,
#   'finalLink': None,
#   'original_name': 'Tencent Holdings'},
#  {'date': '2022-12-31',
#   'symbol': 'AMZN',
#   'reportedCurrency': 'USD',
#   'cik': '0001018724',
#   'fillingDate': '2023-02-03',
#   'acceptedDate': '2023-02-02 18:27:34',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 513983000000,
#   'costOfRevenue': 288831000000,
#   'grossProfit': 225152000000,
#   'grossProfitRatio': 0.4380533987,
#   'researchAndDevelopmentExpenses': 73213000000,
#   'generalAndAdministrativeExpenses': 11891000000,
#   'sellingAndMarketingExpenses': 42238000000,
#   'sellingGeneralAndAdministrativeExpenses': 138428000000,
#   'otherExpenses': -16806000000,
#   'operatingExpenses': 229713000000,
#   'costAndExpenses': 518544000000,
#   'interestIncome': 989000000,
#   'interestExpense': 2367000000,
#   'depreciationAndAmortization': 41921000000,
#   'ebitda': 54618000000,
#   'ebitdaratio': 0.106264215,
#   'operatingIncome': 12248000000,
#   'operatingIncomeRatio': 0.0238295819,
#   'totalOtherIncomeExpensesNet': -16806000000,
#   'incomeBeforeTax': -5936000000,
#   'incomeBeforeTaxRatio': -0.0115490201,
#   'incomeTaxExpense': -3217000000,
#   'netIncome': -2722000000,
#   'netIncomeRatio': -0.005295895,
#   'eps': -0.27,
#   'epsdiluted': -0.27,
#   'weightedAverageShsOut': 10189000000,
#   'weightedAverageShsOutDil': 10189000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/1018724/000101872423000004/0001018724-23-000004-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/1018724/000101872423000004/amzn-20221231.htm',
#   'original_name': 'Amazon'},
#  {'date': '2022-12-31',
#   'symbol': 'PFE',
#   'reportedCurrency': 'USD',
#   'cik': '0000078003',
#   'fillingDate': '2023-02-23',
#   'acceptedDate': '2023-02-23 14:12:53',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 100330000000,
#   'costOfRevenue': 34344000000,
#   'grossProfit': 65986000000,
#   'grossProfitRatio': 0.6576896242,
#   'researchAndDevelopmentExpenses': 11428000000,
#   'generalAndAdministrativeExpenses': 10877000000,
#   'sellingAndMarketingExpenses': 2800000000,
#   'sellingGeneralAndAdministrativeExpenses': 13677000000,
#   'otherExpenses': 3609000000,
#   'operatingExpenses': 28714000000,
#   'costAndExpenses': 63058000000,
#   'interestIncome': 251000000,
#   'interestExpense': 1238000000,
#   'depreciationAndAmortization': 3609000000,
#   'ebitda': 43639000000,
#   'ebitdaratio': 0.4349546497,
#   'operatingIncome': 40030000000,
#   'operatingIncomeRatio': 0.3989833549,
#   'totalOtherIncomeExpensesNet': -5301000000,
#   'incomeBeforeTax': 34729000000,
#   'incomeBeforeTaxRatio': 0.3461477125,
#   'incomeTaxExpense': 3328000000,
#   'netIncome': 31372000000,
#   'netIncomeRatio': 0.3126881292,
#   'eps': 5.59,
#   'epsdiluted': 5.47,
#   'weightedAverageShsOut': 5608000000,
#   'weightedAverageShsOutDil': 5733000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/78003/000007800323000024/0000078003-23-000024-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/78003/000007800323000024/pfe-20221231.htm',
#   'original_name': 'Pfizer'},
#  {'date': '2023-01-01',
#   'symbol': 'JNJ.SW',
#   'reportedCurrency': 'USD',
#   'cik': '0000200406',
#   'fillingDate': '2023-02-16',
#   'acceptedDate': '2023-02-16 16:01:53',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 94943000000,
#   'costOfRevenue': 31089000000,
#   'grossProfit': 63854000000,
#   'grossProfitRatio': 0.672550899,
#   'researchAndDevelopmentExpenses': 15386000000,
#   'generalAndAdministrativeExpenses': 22665000000,
#   'sellingAndMarketingExpenses': 2100000000,
#   'sellingGeneralAndAdministrativeExpenses': 24765000000,
#   'otherExpenses': -1871000000,
#   'operatingExpenses': 40151000000,
#   'costAndExpenses': 71240000000,
#   'interestIncome': 490000000,
#   'interestExpense': 276000000,
#   'depreciationAndAmortization': 6970000000,
#   'ebitda': 24024000000,
#   'ebitdaratio': 0.2530360321,
#   'operatingIncome': 23917000000,
#   'operatingIncomeRatio': 0.2519090402,
#   'totalOtherIncomeExpensesNet': -2192000000,
#   'incomeBeforeTax': 21725000000,
#   'incomeBeforeTaxRatio': 0.2288215034,
#   'incomeTaxExpense': 3784000000,
#   'netIncome': 17941000000,
#   'netIncomeRatio': 0.1889660112,
#   'eps': 6.83,
#   'epsdiluted': 6.73,
#   'weightedAverageShsOut': 2625200000,
#   'weightedAverageShsOutDil': 2663900000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/200406/000020040623000016/0000200406-23-000016-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/200406/000020040623000016/jnj-20230101.htm',
#   'original_name': 'Johnson & Johnson'},
#  {'date': '2022-12-31',
#   'symbol': 'MBGYY',
#   'reportedCurrency': 'EUR',
#   'cik': '0001067318',
#   'fillingDate': '2022-12-31',
#   'acceptedDate': '2022-12-30 19:00:00',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 150017000000,
#   'costOfRevenue': 115997000000,
#   'grossProfit': 34020000000,
#   'grossProfitRatio': 0.2267742989,
#   'researchAndDevelopmentExpenses': 5602000000,
#   'generalAndAdministrativeExpenses': 2584000000,
#   'sellingAndMarketingExpenses': 9482000000,
#   'sellingGeneralAndAdministrativeExpenses': 12066000000,
#   'otherExpenses': -1502000000,
#   'operatingExpenses': 16166000000,
#   'costAndExpenses': 132163000000,
#   'interestIncome': 273000000,
#   'interestExpense': 427000000,
#   'depreciationAndAmortization': 6521000000,
#   'ebitda': 26803000000,
#   'ebitdaratio': 0.1786664178,
#   'operatingIncome': 20282000000,
#   'operatingIncomeRatio': 0.1351980109,
#   'totalOtherIncomeExpensesNet': 22000000,
#   'incomeBeforeTax': 20304000000,
#   'incomeBeforeTaxRatio': 0.1353446609,
#   'incomeTaxExpense': 5495000000,
#   'netIncome': 14501000000,
#   'netIncomeRatio': 0.0966623783,
#   'eps': 13.55,
#   'epsdiluted': 13.55,
#   'weightedAverageShsOut': 1069800000,
#   'weightedAverageShsOutDil': 1069800000,
#   'link': '',
#   'finalLink': '',
#   'original_name': 'Mercedes-Benz Group'},
#  {'date': '2022-12-31',
#   'symbol': 'TSM',
#   'reportedCurrency': 'TWD',
#   'cik': '0001046179',
#   'fillingDate': '2023-04-20',
#   'acceptedDate': '2023-04-20 06:19:24',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 2263891292000,
#   'costOfRevenue': 915536486000,
#   'grossProfit': 1348354806000,
#   'grossProfitRatio': 0.5955916747,
#   'researchAndDevelopmentExpenses': 163262208000,
#   'generalAndAdministrativeExpenses': 53524898000,
#   'sellingAndMarketingExpenses': 9920446000,
#   'sellingGeneralAndAdministrativeExpenses': 63445344000,
#   'otherExpenses': 368403000,
#   'operatingExpenses': 227075955000,
#   'costAndExpenses': 1142612441000,
#   'interestIncome': 22422209000,
#   'interestExpense': 11749984000,
#   'depreciationAndAmortization': 468495304000,
#   'ebitda': 1589774155000,
#   'ebitdaratio': 0.7022307832,
#   'operatingIncome': 1121278851000,
#   'operatingIncomeRatio': 0.4952882919,
#   'totalOtherIncomeExpensesNet': 22911867000,
#   'incomeBeforeTax': 1144190718000,
#   'incomeBeforeTaxRatio': 0.5054088604,
#   'incomeTaxExpense': 127290203000,
#   'netIncome': 992923400000,
#   'netIncomeRatio': 0.4385914657,
#   'eps': 191.45,
#   'epsdiluted': 191.45,
#   'weightedAverageShsOut': 5185840000,
#   'weightedAverageShsOutDil': 5185880000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/1046179/000119312523107214/0001193125-23-107214-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/1046179/000119312523107214/d428519d20f.htm',
#   'original_name': 'Taiwan Semiconductor'},
#  {'date': '2023-03-31',
#   'symbol': 'RLI.VI',
#   'reportedCurrency': 'INR',
#   'cik': '0000000000',
#   'fillingDate': '2023-03-31',
#   'acceptedDate': '2023-03-30 20:00:00',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 8794680000000,
#   'costOfRevenue': 6295990000000,
#   'grossProfit': 2498690000000,
#   'grossProfitRatio': 0.2841138052,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 248720000000,
#   'otherExpenses': 118260000000,
#   'operatingExpenses': 1472800000000,
#   'costAndExpenses': 7768790000000,
#   'interestIncome': 0,
#   'interestExpense': 195710000000,
#   'depreciationAndAmortization': 403190000000,
#   'ebitda': 1546910000000,
#   'ebitdaratio': 0.1758915617,
#   'operatingIncome': 1143720000000,
#   'operatingIncomeRatio': 0.130046801,
#   'totalOtherIncomeExpensesNet': -195710000000,
#   'incomeBeforeTax': 948010000000,
#   'incomeBeforeTaxRatio': 0.1077935752,
#   'incomeTaxExpense': 207130000000,
#   'netIncome': 667020000000,
#   'netIncomeRatio': 0.0758435782,
#   'eps': 197.18,
#   'epsdiluted': 197.18,
#   'weightedAverageShsOut': 3382775483,
#   'weightedAverageShsOutDil': 3382797444,
#   'link': '',
#   'finalLink': '',
#   'original_name': 'Reliance Industries'},
#  {'date': '2022-12-31',
#   'symbol': 'SOV',
#   'reportedCurrency': 'USD',
#   'cik': '0000811830',
#   'fillingDate': '2023-03-03',
#   'acceptedDate': '2023-03-03 15:50:55',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 3729263000,
#   'costOfRevenue': 0,
#   'grossProfit': 3729263000,
#   'grossProfitRatio': 1,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 6136779000,
#   'sellingAndMarketingExpenses': 656038000,
#   'sellingGeneralAndAdministrativeExpenses': 6792817000,
#   'otherExpenses': 0,
#   'operatingExpenses': 6792817000,
#   'costAndExpenses': 6792817000,
#   'interestIncome': 3729263000,
#   'interestExpense': 720800000,
#   'depreciationAndAmortization': -1063923000,
#   'ebitda': 27134000,
#   'ebitdaratio': 0.0072759685,
#   'operatingIncome': 1091057000,
#   'operatingIncomeRatio': 0.2925663864,
#   'totalOtherIncomeExpensesNet': -1063923000,
#   'incomeBeforeTax': 27134000,
#   'incomeBeforeTaxRatio': 0.0072759685,
#   'incomeTaxExpense': 343123000,
#   'netIncome': -315989000,
#   'netIncomeRatio': -0.0847322916,
#   'eps': 0,
#   'epsdiluted': 0,
#   'weightedAverageShsOut': 0,
#   'weightedAverageShsOutDil': 0,
#   'link': 'https://www.sec.gov/Archives/edgar/data/811830/000081183023000005/0000811830-23-000005-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/811830/000081183023000005/sov-20221231.htm',
#   'original_name': 'Santander'},
#  {'date': '2022-12-31',
#   'symbol': 'NSRGY',
#   'reportedCurrency': 'CHF',
#   'cik': '0000000000',
#   'fillingDate': '2022-12-31',
#   'acceptedDate': '2022-12-30 19:00:00',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 94424000000,
#   'costOfRevenue': 51745000000,
#   'grossProfit': 42679000000,
#   'grossProfitRatio': 0.4519931373,
#   'researchAndDevelopmentExpenses': 1696000000,
#   'generalAndAdministrativeExpenses': 16850000000,
#   'sellingAndMarketingExpenses': 8386000000,
#   'sellingGeneralAndAdministrativeExpenses': 25236000000,
#   'otherExpenses': 211000000,
#   'operatingExpenses': 26721000000,
#   'costAndExpenses': 78466000000,
#   'interestIncome': 140000000,
#   'interestExpense': 1125000000,
#   'depreciationAndAmortization': 3541000000,
#   'ebitda': 19499000000,
#   'ebitdaratio': 0.2065047022,
#   'operatingIncome': 15958000000,
#   'operatingIncomeRatio': 0.1690036431,
#   'totalOtherIncomeExpensesNet': -4672000000,
#   'incomeBeforeTax': 11286000000,
#   'incomeBeforeTaxRatio': 0.1195246971,
#   'incomeTaxExpense': 2730000000,
#   'netIncome': 9270000000,
#   'netIncomeRatio': 0.098174193,
#   'eps': 3.42,
#   'epsdiluted': 3.42,
#   'weightedAverageShsOut': 2707000000,
#   'weightedAverageShsOutDil': 2709000000,
#   'link': None,
#   'finalLink': None,
#   'original_name': 'Nestlé'},
#  {'date': '2022-12-31',
#   'symbol': 'STOHF',
#   'reportedCurrency': 'USD',
#   'cik': '0001140625',
#   'fillingDate': '2023-03-23',
#   'acceptedDate': '2023-03-23 08:27:07',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 149004000000,
#   'costOfRevenue': 60197000000,
#   'grossProfit': 88807000000,
#   'grossProfitRatio': 0.5960041341,
#   'researchAndDevelopmentExpenses': 302094431,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 986000000,
#   'otherExpenses': 0,
#   'operatingExpenses': 10617000000,
#   'costAndExpenses': 70814000000,
#   'interestIncome': 1222000000,
#   'interestExpense': 1379000000,
#   'depreciationAndAmortization': 6391000000,
#   'ebitda': 86425000000,
#   'ebitdaratio': 0.5800179861,
#   'operatingIncome': 78811000000,
#   'operatingIncomeRatio': 0.5289186867,
#   'totalOtherIncomeExpensesNet': 569000000,
#   'incomeBeforeTax': 78604000000,
#   'incomeBeforeTaxRatio': 0.5275294623,
#   'incomeTaxExpense': 49861000000,
#   'netIncome': 28746000000,
#   'netIncomeRatio': 0.1929209954,
#   'eps': 8.88,
#   'epsdiluted': 8.86,
#   'weightedAverageShsOut': 3174000000,
#   'weightedAverageShsOutDil': 3183000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/1140625/000114062523000036/0001140625-23-000036-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/1140625/000114062523000036/eqnr20221231.htm',
#   'original_name': 'Equinor'},
#  {'date': '2022-03-31',
#   'symbol': 'BABA',
#   'reportedCurrency': 'CNY',
#   'cik': '0001577552',
#   'fillingDate': '2022-07-26',
#   'acceptedDate': '2022-07-26 07:49:18',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 853062000000,
#   'costOfRevenue': 539450000000,
#   'grossProfit': 313612000000,
#   'grossProfitRatio': 0.3676309577,
#   'researchAndDevelopmentExpenses': 55465000000,
#   'generalAndAdministrativeExpenses': 31922000000,
#   'sellingAndMarketingExpenses': 119799000000,
#   'sellingGeneralAndAdministrativeExpenses': 151721000000,
#   'otherExpenses': 11647000000,
#   'operatingExpenses': 218833000000,
#   'costAndExpenses': 758283000000,
#   'interestIncome': -15702000000,
#   'interestExpense': 20611000000,
#   'depreciationAndAmortization': 11647000000,
#   'ebitda': 116949000000,
#   'ebitdaratio': 0.1370932007,
#   'operatingIncome': 105302000000,
#   'operatingIncomeRatio': 0.1234400313,
#   'totalOtherIncomeExpensesNet': -45752000000,
#   'incomeBeforeTax': 59550000000,
#   'incomeBeforeTaxRatio': 0.0698073528,
#   'incomeTaxExpense': 26815000000,
#   'netIncome': 62249000000,
#   'netIncomeRatio': 0.0729712495,
#   'eps': 22.96,
#   'epsdiluted': 22.72,
#   'weightedAverageShsOut': 2694750000,
#   'weightedAverageShsOutDil': 2723375000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/1577552/000110465922082622/0001104659-22-082622-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/1577552/000110465922082622/baba-20220331x20f.htm',
#   'original_name': 'Alibaba Group'},
#  {'date': '2022-06-30',
#   'symbol': 'PG',
#   'reportedCurrency': 'USD',
#   'cik': '0000080424',
#   'fillingDate': '2022-08-05',
#   'acceptedDate': '2022-08-05 16:21:50',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 80187000000,
#   'costOfRevenue': 42157000000,
#   'grossProfit': 38030000000,
#   'grossProfitRatio': 0.4742664023,
#   'researchAndDevelopmentExpenses': 2000000000,
#   'generalAndAdministrativeExpenses': 12317000000,
#   'sellingAndMarketingExpenses': 7900000000,
#   'sellingGeneralAndAdministrativeExpenses': 20217000000,
#   'otherExpenses': 570000000,
#   'operatingExpenses': 20217000000,
#   'costAndExpenses': 62374000000,
#   'interestIncome': 51000000,
#   'interestExpense': 439000000,
#   'depreciationAndAmortization': 3428000000,
#   'ebitda': 21241000000,
#   'ebitdaratio': 0.2648933119,
#   'operatingIncome': 17813000000,
#   'operatingIncomeRatio': 0.2221432402,
#   'totalOtherIncomeExpensesNet': 182000000,
#   'incomeBeforeTax': 17995000000,
#   'incomeBeforeTaxRatio': 0.2244129348,
#   'incomeTaxExpense': 3202000000,
#   'netIncome': 14742000000,
#   'netIncomeRatio': 0.1838452617,
#   'eps': 6,
#   'epsdiluted': 5.81,
#   'weightedAverageShsOut': 2410300000,
#   'weightedAverageShsOutDil': 2539100000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/80424/000008042422000064/0000080424-22-000064-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/80424/000008042422000064/pg-20220630.htm',
#   'original_name': 'Procter & Gamble'},
#  {'date': '2022-03-31',
#   'symbol': 'NTTYY',
#   'reportedCurrency': 'JPY',
#   'cik': '0000000000',
#   'fillingDate': '2022-03-31',
#   'acceptedDate': '2022-03-30 20:00:00',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 12156447000000,
#   'costOfRevenue': 9695289000000,
#   'grossProfit': 2461158000000,
#   'grossProfitRatio': 0.2024570173,
#   'researchAndDevelopmentExpenses': 247988000000,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 0,
#   'otherExpenses': -250978000000,
#   'operatingExpenses': 498966000000,
#   'costAndExpenses': 10194255000000,
#   'interestIncome': 9310000000,
#   'interestExpense': 55383000000,
#   'depreciationAndAmortization': 1561183000000,
#   'ebitda': 3523375000000,
#   'ebitdaratio': 0.28983592,
#   'operatingIncome': 1962192000000,
#   'operatingIncomeRatio': 0.1614116361,
#   'totalOtherIncomeExpensesNet': -186378000000,
#   'incomeBeforeTax': 1775814000000,
#   'incomeBeforeTaxRatio': 0.1460800183,
#   'incomeTaxExpense': 539531000000,
#   'netIncome': 1181083000000,
#   'netIncomeRatio': 0.0971569242,
#   'eps': 13.17,
#   'epsdiluted': 13.17,
#   'weightedAverageShsOut': 89669717425,
#   'weightedAverageShsOutDil': 89669717425,
#   'link': None,
#   'finalLink': None,
#   'original_name': 'Nippon Telegraph & Tel'},
#  {'date': '2023-03-31',
#   'symbol': 'SNEJF',
#   'reportedCurrency': 'JPY',
#   'cik': '0000313838',
#   'fillingDate': '2023-06-20',
#   'acceptedDate': '2023-06-20 06:12:32',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 11539837000000,
#   'costOfRevenue': 8398931000000,
#   'grossProfit': 3140906000000,
#   'grossProfitRatio': 0.2721794077,
#   'researchAndDevelopmentExpenses': 735698000000,
#   'generalAndAdministrativeExpenses': 1578039000000,
#   'sellingAndMarketingExpenses': 391131000000,
#   'sellingGeneralAndAdministrativeExpenses': 1969170000000,
#   'otherExpenses': 0,
#   'operatingExpenses': 1957149000000,
#   'costAndExpenses': 10356080000000,
#   'interestIncome': 31058000000,
#   'interestExpense': 58951000000,
#   'depreciationAndAmortization': 1004590000000,
#   'ebitda': 2243854000000,
#   'ebitdaratio': 0.1944441676,
#   'operatingIncome': 1208206000000,
#   'operatingIncomeRatio': 0.1046987059,
#   'totalOtherIncomeExpensesNet': 24449000000,
#   'incomeBeforeTax': 1180313000000,
#   'incomeBeforeTaxRatio': 0.1022816007,
#   'incomeTaxExpense': 236691000000,
#   'netIncome': 937126000000,
#   'netIncomeRatio': 0.0812079061,
#   'eps': 758.38,
#   'epsdiluted': 754.95,
#   'weightedAverageShsOut': 1235701000,
#   'weightedAverageShsOutDil': 1241377000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/313838/000119312523169510/0001193125-23-169510-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/313838/000119312523169510/d433796d20f.htm',
#   'original_name': 'Sony'},
#  {'date': '2022-12-31',
#   'symbol': 'PBR',
#   'reportedCurrency': 'USD',
#   'cik': '0001119639',
#   'fillingDate': '2023-03-29',
#   'acceptedDate': '2023-03-29 17:27:28',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 124474000000,
#   'costOfRevenue': 59486000000,
#   'grossProfit': 64988000000,
#   'grossProfitRatio': 0.522101001,
#   'researchAndDevelopmentExpenses': 792000000,
#   'generalAndAdministrativeExpenses': 2419000000,
#   'sellingAndMarketingExpenses': 3987000000,
#   'sellingGeneralAndAdministrativeExpenses': 6406000000,
#   'otherExpenses': 2217000000,
#   'operatingExpenses': 9415000000,
#   'costAndExpenses': 68901000000,
#   'interestIncome': 673000000,
#   'interestExpense': 3311000000,
#   'depreciationAndAmortization': 16805000000,
#   'ebitda': 73919000000,
#   'ebitdaratio': 0.5938509247,
#   'operatingIncome': 57114000000,
#   'operatingIncomeRatio': 0.4588428105,
#   'totalOtherIncomeExpensesNet': -3589000000,
#   'incomeBeforeTax': 53525000000,
#   'incomeBeforeTaxRatio': 0.4300094799,
#   'incomeTaxExpense': 16770000000,
#   'netIncome': 36623000000,
#   'netIncomeRatio': 0.2942220865,
#   'eps': 5.62,
#   'epsdiluted': 5.62,
#   'weightedAverageShsOut': 6522100630,
#   'weightedAverageShsOutDil': 6522100630,
#   'link': 'https://www.sec.gov/Archives/edgar/data/1119639/000129281423001253/0001292814-23-001253-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/1119639/000129281423001253/pbrform20f_2022.htm',
#   'original_name': 'Petrobras'},
#  {'date': '2022-12-31',
#   'symbol': '024110.KS',
#   'reportedCurrency': 'KRW',
#   'cik': '0000000000',
#   'fillingDate': '2022-12-31',
#   'acceptedDate': '2022-12-30 19:00:00',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 9188512000000,
#   'costOfRevenue': 0,
#   'grossProfit': 9188512000000,
#   'grossProfitRatio': 1,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 157955000000,
#   'sellingGeneralAndAdministrativeExpenses': 157955000000,
#   'otherExpenses': 3810216000000,
#   'operatingExpenses': 3968171000000,
#   'costAndExpenses': 3968171000000,
#   'interestIncome': 12532949000000,
#   'interestExpense': 4916438000000,
#   'depreciationAndAmortization': 271388000000,
#   'ebitda': 8921562000000,
#   'ebitdaratio': 0.9709474178,
#   'operatingIncome': 8650174000000,
#   'operatingIncomeRatio': 0.9414118412,
#   'totalOtherIncomeExpensesNet': -4909404000000,
#   'incomeBeforeTax': 3740770000000,
#   'incomeBeforeTaxRatio': 0.407113796,
#   'incomeTaxExpense': 959966000000,
#   'netIncome': 2667696000000,
#   'netIncomeRatio': 0.2903294897,
#   'eps': 3179.81,
#   'epsdiluted': 3179.81,
#   'weightedAverageShsOut': 746047000,
#   'weightedAverageShsOutDil': 746047000,
#   'link': '',
#   'finalLink': '',
#   'original_name': 'Industrial Bank'},
#  {'date': '2022-12-31',
#   'symbol': 'CILJF',
#   'reportedCurrency': 'CNY',
#   'cik': '0001268896',
#   'fillingDate': '2023-04-21',
#   'acceptedDate': '2023-04-21 07:05:30',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 803975000000,
#   'costOfRevenue': 0,
#   'grossProfit': 803975000000,
#   'grossProfitRatio': 1,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 39874000000,
#   'sellingAndMarketingExpenses': 2893000000,
#   'sellingGeneralAndAdministrativeExpenses': 39874000000,
#   'otherExpenses': -830617000000,
#   'operatingExpenses': -790743000000,
#   'costAndExpenses': 779928000000,
#   'interestIncome': 0,
#   'interestExpense': 4863000000,
#   'depreciationAndAmortization': 5291000000,
#   'ebitda': 18523000000,
#   'ebitdaratio': 0.0230392736,
#   'operatingIncome': 13232000000,
#   'operatingIncomeRatio': 0.0164582232,
#   'totalOtherIncomeExpensesNet': 9383000000,
#   'incomeBeforeTax': 24047000000,
#   'incomeBeforeTaxRatio': 0.029910134,
#   'incomeTaxExpense': -9467000000,
#   'netIncome': 32082000000,
#   'netIncomeRatio': 0.0399042259,
#   'eps': 1.14,
#   'epsdiluted': 1.14,
#   'weightedAverageShsOut': 28265000000,
#   'weightedAverageShsOutDil': 28265000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/1268896/000119312523109212/0001193125-23-109212-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/1268896/000119312523109212/d389085d20f.htm',
#   'original_name': 'China Life Insurance'},
#  {'date': '2022-12-31',
#   'symbol': 'AXP',
#   'reportedCurrency': 'USD',
#   'cik': '0000004962',
#   'fillingDate': '2023-02-10',
# ...
#   'operatingIncome': 5664000000,
#   'operatingIncomeRatio': 0.1242650285,
#   'totalOtherIncomeExpensesNet': -1710000000,
#   'incomeBeforeTax': 3954000000,
#   'incomeBeforeTaxRatio': 0.0867485739,
#   'incomeTaxExpense': 1330000000,
#   'netIncome': 2237000000,
#   'netIncomeRatio': 0.0490785432,
#   'eps': 0.0783,
#   'epsdiluted': 0.078,
#   'weightedAverageShsOut': 28564423478,
#   'weightedAverageShsOutDil': 28661423478,
#   'link': 'https://www.sec.gov/Archives/edgar/data/839923/000110465922071759/0001104659-22-071759-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/839923/000110465922071759/vod-20220331x20f.htm',
#   'original_name': 'Vodafone'},
#  {'date': '2022-03-31',
#   'symbol': 'SVNBY',
#   'reportedCurrency': 'JPY',
#   'cik': '0000000000',
#   'fillingDate': '2022-03-31',
#   'acceptedDate': '2022-03-30 20:00:00',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 135742000000,
#   'costOfRevenue': 0,
#   'grossProfit': 135742000000,
#   'grossProfitRatio': 1,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 70371000000,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 70371000000,
#   'otherExpenses': -80951000000,
#   'operatingExpenses': 80951000000,
#   'costAndExpenses': 106663000000,
#   'interestIncome': 4032000000,
#   'interestExpense': 560000000,
#   'depreciationAndAmortization': 16388000000,
#   'ebitda': 16531000000,
#   'ebitdaratio': 0.1217824992,
#   'operatingIncome': 143000000,
#   'operatingIncomeRatio': 0.0010534691,
#   'totalOtherIncomeExpensesNet': 27154000000,
#   'incomeBeforeTax': 27154000000,
#   'incomeBeforeTaxRatio': 0.2000412547,
#   'incomeTaxExpense': 6471000000,
#   'netIncome': 20827000000,
#   'netIncomeRatio': 0.1534307731,
#   'eps': 17.72,
#   'epsdiluted': 17.72,
#   'weightedAverageShsOut': 1175596000,
#   'weightedAverageShsOutDil': 1175596000,
#   'link': None,
#   'finalLink': None,
#   'original_name': 'Seven & I Holdings'},
#  {'date': '2022-03-31',
#   'symbol': 'HDB',
#   'reportedCurrency': 'INR',
#   'cik': '0001144967',
#   'fillingDate': '2022-07-29',
#   'acceptedDate': '2022-07-29 16:12:09',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 1019413700000,
#   'costOfRevenue': 0,
#   'grossProfit': 1019413700000,
#   'grossProfitRatio': 1,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 320219100000,
#   'sellingAndMarketingExpenses': 2625400000,
#   'sellingGeneralAndAdministrativeExpenses': 320219100000,
#   'otherExpenses': -821073200000,
#   'operatingExpenses': -500854100000,
#   'costAndExpenses': -500854100000,
#   'interestIncome': 1333137000000,
#   'interestExpense': 584297500000,
#   'depreciationAndAmortization': 16816900000,
#   'ebitda': 535376500000,
#   'ebitdaratio': 0.5251807976,
#   'operatingIncome': 518559600000,
#   'operatingIncomeRatio': 0.5086841584,
#   'totalOtherIncomeExpensesNet': 602600000,
#   'incomeBeforeTax': 519162200000,
#   'incomeBeforeTaxRatio': 0.5092752824,
#   'incomeTaxExpense': 132559200000,
#   'netIncome': 386000400000,
#   'netIncomeRatio': 0.3786494139,
#   'eps': 209.28,
#   'epsdiluted': 208.14,
#   'weightedAverageShsOut': 1856865790,
#   'weightedAverageShsOutDil': 1856978000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/1144967/000119312522206623/0001193125-22-206623-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/1144967/000119312522206623/d249746d20f.htm',
#   'original_name': 'HDFC'},
#  {'date': '2022-12-31',
#   'symbol': 'NGLOY',
#   'reportedCurrency': 'USD',
#   'cik': '0000000000',
#   'fillingDate': '2022-12-31',
#   'acceptedDate': '2022-12-31 00:00:00',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 35118000000,
#   'costOfRevenue': 15526000000,
#   'grossProfit': 19592000000,
#   'grossProfitRatio': 0.5578905405,
#   'researchAndDevelopmentExpenses': 167000000,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 2898000000,
#   'sellingGeneralAndAdministrativeExpenses': 2898000000,
#   'otherExpenses': 21395000000,
#   'operatingExpenses': 24293000000,
#   'costAndExpenses': 24293000000,
#   'interestIncome': 215000000,
#   'interestExpense': 516000000,
#   'depreciationAndAmortization': 4989000000,
#   'ebitda': 14232000000,
#   'ebitdaratio': 0.4052622587,
#   'operatingIncome': 9243000000,
#   'operatingIncomeRatio': 0.2631983598,
#   'totalOtherIncomeExpensesNet': 237000000,
#   'incomeBeforeTax': 9480000000,
#   'incomeBeforeTaxRatio': 0.2699470357,
#   'incomeTaxExpense': 3456000000,
#   'netIncome': 6024000000,
#   'netIncomeRatio': 0.1715359645,
#   'eps': 2.48,
#   'epsdiluted': 2.46,
#   'weightedAverageShsOut': 2430000000,
#   'weightedAverageShsOutDil': 2452000000,
#   'link': None,
#   'finalLink': None,
#   'original_name': 'Anglo American'},
#  {'date': '2022-12-31',
#   'symbol': 'MA',
#   'reportedCurrency': 'USD',
#   'cik': '0001141391',
#   'fillingDate': '2023-02-14',
#   'acceptedDate': '2023-02-14 16:48:22',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 22237000000,
#   'costOfRevenue': 5263000000,
#   'grossProfit': 16974000000,
#   'grossProfitRatio': 0.7633223906,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 8078000000,
#   'sellingAndMarketingExpenses': 789000000,
#   'sellingGeneralAndAdministrativeExpenses': 8867000000,
#   'otherExpenses': 750000000,
#   'operatingExpenses': 9617000000,
#   'costAndExpenses': 9617000000,
#   'interestIncome': 61000000,
#   'interestExpense': 471000000,
#   'depreciationAndAmortization': 1129000000,
#   'ebitda': 13393000000,
#   'ebitdaratio': 0.6022844808,
#   'operatingIncome': 12264000000,
#   'operatingIncomeRatio': 0.5515132437,
#   'totalOtherIncomeExpensesNet': -532000000,
#   'incomeBeforeTax': 11732000000,
#   'incomeBeforeTaxRatio': 0.5275891532,
#   'incomeTaxExpense': 1802000000,
#   'netIncome': 9930000000,
#   'netIncomeRatio': 0.4465530422,
#   'eps': 10.26,
#   'epsdiluted': 10.23,
#   'weightedAverageShsOut': 968000000,
#   'weightedAverageShsOutDil': 971000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/1141391/000114139123000020/0001141391-23-000020-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/1141391/000114139123000020/ma-20221231.htm',
#   'original_name': 'Mastercard'},
#  {'date': '2022-12-31',
#   'symbol': 'NVO',
#   'reportedCurrency': 'DKK',
#   'cik': '0000353278',
#   'fillingDate': '2023-02-01',
#   'acceptedDate': '2023-02-01 07:53:07',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 176954000000,
#   'costOfRevenue': 28448000000,
#   'grossProfit': 148506000000,
#   'grossProfitRatio': 0.8392350554,
#   'researchAndDevelopmentExpenses': 24047000000,
#   'generalAndAdministrativeExpenses': 4467000000,
#   'sellingAndMarketingExpenses': 46217000000,
#   'sellingGeneralAndAdministrativeExpenses': 50684000000,
#   'otherExpenses': -1034000000,
#   'operatingExpenses': 73697000000,
#   'costAndExpenses': 102145000000,
#   'interestIncome': 239000000,
#   'interestExpense': 378000000,
#   'depreciationAndAmortization': 7231000000,
#   'ebitda': 82040000000,
#   'ebitdaratio': 0.4636233145,
#   'operatingIncome': 74809000000,
#   'operatingIncomeRatio': 0.4227595872,
#   'totalOtherIncomeExpensesNet': -5747000000,
#   'incomeBeforeTax': 69062000000,
#   'incomeBeforeTaxRatio': 0.3902822202,
#   'incomeTaxExpense': 13537000000,
#   'netIncome': 55525000000,
#   'netIncomeRatio': 0.3137821129,
#   'eps': 12.26,
#   'epsdiluted': 12.22,
#   'weightedAverageShsOut': 4530600000,
#   'weightedAverageShsOutDil': 4544600000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/353278/000162828023001868/0001628280-23-001868-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/353278/000162828023001868/nvo-20221231.htm',
#   'original_name': 'Novo Nordisk'},
#  {'date': '2022-12-31',
#   'symbol': 'ASML',
#   'reportedCurrency': 'EUR',
#   'cik': '0000937966',
#   'fillingDate': '2023-02-15',
#   'acceptedDate': '2023-02-15 06:05:47',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 21173400000,
#   'costOfRevenue': 10660700000,
#   'grossProfit': 10512700000,
#   'grossProfitRatio': 0.4965050488,
#   'researchAndDevelopmentExpenses': 2282100000,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 909600000,
#   'otherExpenses': 0,
#   'operatingExpenses': 3191700000,
#   'costAndExpenses': 13852400000,
#   'interestIncome': 16200000,
#   'interestExpense': 60800000,
#   'depreciationAndAmortization': 892100000,
#   'ebitda': 8213100000,
#   'ebitdaratio': 0.3878970784,
#   'operatingIncome': 7321000000,
#   'operatingIncomeRatio': 0.3457640247,
#   'totalOtherIncomeExpensesNet': -44600000,
#   'incomeBeforeTax': 7276400000,
#   'incomeBeforeTaxRatio': 0.3436576081,
#   'incomeTaxExpense': 1018600000,
#   'netIncome': 5624200000,
#   'netIncomeRatio': 0.265625738,
#   'eps': 14.14,
#   'epsdiluted': 14.13,
#   'weightedAverageShsOut': 397700000,
#   'weightedAverageShsOutDil': 398000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/937966/000093796623000014/0000937966-23-000014-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/937966/000093796623000014/asml-20221231.htm',
#   'original_name': 'ASML Holding'},
#  {'date': '2022-01-30',
#   'symbol': 'NVDA',
#   'reportedCurrency': 'USD',
#   'cik': '0001045810',
#   'fillingDate': '2022-03-18',
#   'acceptedDate': '2022-03-17 20:33:34',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 26914000000,
#   'costOfRevenue': 9439000000,
#   'grossProfit': 17475000000,
#   'grossProfitRatio': 0.6492903322,
#   'researchAndDevelopmentExpenses': 5268000000,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 2166000000,
#   'otherExpenses': 107000000,
#   'operatingExpenses': 7434000000,
#   'costAndExpenses': 16873000000,
#   'interestIncome': 29000000,
#   'interestExpense': 236000000,
#   'depreciationAndAmortization': 1310000000,
#   'ebitda': 11351000000,
#   'ebitdaratio': 0.4217507617,
#   'operatingIncome': 10041000000,
#   'operatingIncomeRatio': 0.3730772089,
#   'totalOtherIncomeExpensesNet': -100000000,
#   'incomeBeforeTax': 9941000000,
#   'incomeBeforeTaxRatio': 0.3693616705,
#   'incomeTaxExpense': 189000000,
#   'netIncome': 9752000000,
#   'netIncomeRatio': 0.362339303,
#   'eps': 0.39,
#   'epsdiluted': 0.39,
#   'weightedAverageShsOut': 24960000000,
#   'weightedAverageShsOutDil': 25350000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581022000036/0001045810-22-000036-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/1045810/000104581022000036/nvda-20220130.htm',
#   'original_name': 'NVIDIA'},
#  {'date': '2022-12-31',
#   'symbol': 'MMM',
#   'reportedCurrency': 'USD',
#   'cik': '0000066740',
#   'fillingDate': '2023-02-08',
#   'acceptedDate': '2023-02-08 12:59:49',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 34229000000,
#   'costOfRevenue': 19232000000,
#   'grossProfit': 14997000000,
#   'grossProfitRatio': 0.438137252,
#   'researchAndDevelopmentExpenses': 1862000000,
#   'generalAndAdministrativeExpenses': 8801000000,
#   'sellingAndMarketingExpenses': 248000000,
#   'sellingGeneralAndAdministrativeExpenses': 9049000000,
#   'otherExpenses': -147000000,
#   'operatingExpenses': 10911000000,
#   'costAndExpenses': 30143000000,
#   'interestIncome': 67000000,
#   'interestExpense': 462000000,
#   'depreciationAndAmortization': 1831000000,
#   'ebitda': 8370000000,
#   'ebitdaratio': 0.2445294925,
#   'operatingIncome': 6539000000,
#   'operatingIncomeRatio': 0.1910368401,
#   'totalOtherIncomeExpensesNet': -147000000,
#   'incomeBeforeTax': 6392000000,
#   'incomeBeforeTaxRatio': 0.1867422361,
#   'incomeTaxExpense': 612000000,
#   'netIncome': 5777000000,
#   'netIncomeRatio': 0.1687750153,
#   'eps': 10.21,
#   'epsdiluted': 10.18,
#   'weightedAverageShsOut': 566000000,
#   'weightedAverageShsOutDil': 567600000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/66740/000006674023000014/0000066740-23-000014-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/66740/000006674023000014/mmm-20221231.htm',
#   'original_name': '3M'},
#  {'date': '2022-12-31',
#   'symbol': 'EOG',
#   'reportedCurrency': 'USD',
#   'cik': '0000821189',
#   'fillingDate': '2023-02-23',
#   'acceptedDate': '2023-02-23 16:23:25',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 29492000000,
#   'costOfRevenue': 5494000000,
#   'grossProfit': 23998000000,
#   'grossProfitRatio': 0.8137121931,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 570000000,
#   'sellingAndMarketingExpenses': 6535000000,
#   'sellingGeneralAndAdministrativeExpenses': 7105000000,
#   'otherExpenses': 2637000000,
#   'operatingExpenses': 9742000000,
#   'costAndExpenses': 15236000000,
#   'interestIncome': 85000000,
#   'interestExpense': 179000000,
#   'depreciationAndAmortization': 910000000,
#   'ebitda': 15280000000,
#   'ebitdaratio': 0.5181066052,
#   'operatingIncome': 14370000000,
#   'operatingIncomeRatio': 0.4872507799,
#   'totalOtherIncomeExpensesNet': -4469000000,
#   'incomeBeforeTax': 9901000000,
#   'incomeBeforeTaxRatio': 0.3357181609,
#   'incomeTaxExpense': 2142000000,
#   'netIncome': 7759000000,
#   'netIncomeRatio': 0.2630882951,
#   'eps': 13.31,
#   'epsdiluted': 13.22,
#   'weightedAverageShsOut': 583000000,
#   'weightedAverageShsOutDil': 587000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/821189/000082118923000015/0000821189-23-000015-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/821189/000082118923000015/eog-20221231.htm',
#   'original_name': 'EOG Resources'},
#  {'date': '2022-03-31',
#   'symbol': 'TKPHF',
#   'reportedCurrency': 'JPY',
#   'cik': '0001395064',
#   'fillingDate': '2022-06-29',
#   'acceptedDate': '2022-06-29 06:05:31',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 3569006000000,
#   'costOfRevenue': 1106846000000,
#   'grossProfit': 2462160000000,
#   'grossProfitRatio': 0.6898727545,
#   'researchAndDevelopmentExpenses': 526087000000,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 886361000000,
#   'otherExpenses': -20723000000,
#   'operatingExpenses': 2001315000000,
#   'costAndExpenses': 3108161000000,
#   'interestIncome': 23700000000,
#   'interestExpense': 166607000000,
#   'depreciationAndAmortization': 583151000000,
#   'ebitda': 1052329000000,
#   'ebitdaratio': 0.2948521241,
#   'operatingIncome': 460844000000,
#   'operatingIncomeRatio': 0.1291239073,
#   'totalOtherIncomeExpensesNet': -15367000000,
#   'incomeBeforeTax': 302571000000,
#   'incomeBeforeTaxRatio': 0.0847773862,
#   'incomeTaxExpense': 72405000000,
#   'netIncome': 230059000000,
#   'netIncomeRatio': 0.0644602447,
#   'eps': 147.14,
#   'epsdiluted': 145.87,
#   'weightedAverageShsOut': 1563501000,
#   'weightedAverageShsOutDil': 1577169000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/1395064/000139506422000107/0001395064-22-000107-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/1395064/000139506422000107/tak-20220331.htm',
#   'original_name': 'Takeda Pharmaceutical'},
#  {'date': '2022-12-31',
#   'symbol': 'SLF',
#   'reportedCurrency': 'CAD',
#   'cik': '0001097362',
#   'fillingDate': '2022-12-31',
#   'acceptedDate': '2022-12-30 19:00:00',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'revenue': 23207000000,
#   'costOfRevenue': 0,
#   'grossProfit': 23207000000,
#   'grossProfitRatio': 1,
#   'researchAndDevelopmentExpenses': 0,
#   'generalAndAdministrativeExpenses': 5107000000,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 5107000000,
#   'otherExpenses': -24002000000,
#   'operatingExpenses': -18895000000,
#   'costAndExpenses': 19284000000,
#   'interestIncome': 5863000000,
#   'interestExpense': 445000000,
#   'depreciationAndAmortization': 528000000,
#   'ebitda': 4840000000,
#   'ebitdaratio': 0.2085577627,
#   'operatingIncome': 4312000000,
#   'operatingIncomeRatio': 0.1858060068,
#   'totalOtherIncomeExpensesNet': -389000000,
#   'incomeBeforeTax': 3923000000,
#   'incomeBeforeTaxRatio': 0.169043823,
#   'incomeTaxExpense': 621000000,
#   'netIncome': 3024000000,
#   'netIncomeRatio': 0.1303055113,
#   'eps': 4.9,
#   'epsdiluted': 4.89,
#   'weightedAverageShsOut': 586000000,
#   'weightedAverageShsOutDil': 589000000,
#   'link': '',
#   'finalLink': '',
#   'original_name': 'Sun Life Financial'}]

# %%
income_df = pd.DataFrame.from_records(filtered_income_list)
income_df
# Out:
#            date   symbol reportedCurrency         cik fillingDate  \
# 0    2022-12-31   JPM-PJ              USD  0000019617  2023-02-21
# 1    2022-12-31  CNCB.VI              CNY  0000000000  2022-12-31
# 2    2022-12-31   EK7.VI              CNY  0000000000  2022-12-31
# 3    2022-12-31   BAC-PM              USD  0000070858  2023-02-22
# 4    2022-06-30     MSFT              USD  0000789019  2022-07-28
# ..          ...      ...              ...         ...         ...
# 130  2022-01-30     NVDA              USD  0001045810  2022-03-18
# 131  2022-12-31      MMM              USD  0000066740  2023-02-08
# 132  2022-12-31      EOG              USD  0000821189  2023-02-23
# 133  2022-03-31    TKPHF              JPY  0001395064  2022-06-29
# 134  2022-12-31      SLF              CAD  0001097362  2022-12-31
#
#             acceptedDate calendarYear period        revenue  costOfRevenue  \
# 0    2023-02-21 16:13:55         2022     FY   128695000000              0
# 1    2022-12-30 19:00:00         2022     FY   821279000000              0
# 2    2022-12-30 19:00:00         2022     FY   724868000000              0
# 3    2023-02-22 16:33:50         2022     FY    94950000000              0
# 4    2022-07-28 16:06:19         2022     FY   198270000000    62650000000
# ..                   ...          ...    ...            ...            ...
# 130  2022-03-17 20:33:34         2022     FY    26914000000     9439000000
# 131  2023-02-08 12:59:49         2022     FY    34229000000    19232000000
# 132  2023-02-23 16:23:25         2022     FY    29492000000     5494000000
# 133  2022-06-29 06:05:31         2022     FY  3569006000000  1106846000000
# 134  2022-12-30 19:00:00         2022     FY    23207000000              0
#
#      ...  incomeTaxExpense     netIncome  netIncomeRatio     eps  epsdiluted  \
# 0    ...        8490000000   37676000000        0.292754   12.47       12.47
# 1    ...       58851000000  324727000000        0.395392    1.28        1.28
# 2    ...       47528000000  259232000000        0.357626    0.69        0.69
# 3    ...        3441000000   27528000000        0.289921    0.00        0.00
# 4    ...       10978000000   72738000000        0.366863    9.70        9.65
# ..   ...               ...           ...             ...     ...         ...
# 130  ...         189000000    9752000000        0.362339    0.39        0.39
# 131  ...         612000000    5777000000        0.168775   10.21       10.18
# 132  ...        2142000000    7759000000        0.263088   13.31       13.22
# 133  ...       72405000000  230059000000        0.064460  147.14      145.87
# 134  ...         621000000    3024000000        0.130306    4.90        4.89
#
#      weightedAverageShsOut  weightedAverageShsOutDil  \
# 0               2968734491                3021000000
# 1             253016406250              253016406250
# 2             349983033873              349983033873
# 3                        0                         0
# 4               7496000000                7540000000
# ..                     ...                       ...
# 130            24960000000               25350000000
# 131              566000000                 567600000
# 132              583000000                 587000000
# 133             1563501000                1577169000
# 134              586000000                 589000000
#
#                                                   link  \
# 0    https://www.sec.gov/Archives/edgar/data/19617/...
# 1
# 2
# 3    https://www.sec.gov/Archives/edgar/data/70858/...
# 4    https://www.sec.gov/Archives/edgar/data/789019...
# ..                                                 ...
# 130  https://www.sec.gov/Archives/edgar/data/104581...
# 131  https://www.sec.gov/Archives/edgar/data/66740/...
# 132  https://www.sec.gov/Archives/edgar/data/821189...
# 133  https://www.sec.gov/Archives/edgar/data/139506...
# 134
#
#                                              finalLink  \
# 0    https://www.sec.gov/Archives/edgar/data/19617/...
# 1
# 2
# 3    https://www.sec.gov/Archives/edgar/data/70858/...
# 4    https://www.sec.gov/Archives/edgar/data/789019...
# ..                                                 ...
# 130  https://www.sec.gov/Archives/edgar/data/104581...
# 131  https://www.sec.gov/Archives/edgar/data/66740/...
# 132  https://www.sec.gov/Archives/edgar/data/821189...
# 133  https://www.sec.gov/Archives/edgar/data/139506...
# 134
#
#                   original_name
# 0                JPMorgan Chase
# 1       China Construction Bank
# 2    Agricultural Bank of China
# 3               Bank of America
# 4                     Microsoft
# ..                          ...
# 130                      NVIDIA
# 131                          3M
# 132               EOG Resources
# 133       Takeda Pharmaceutical
# 134          Sun Life Financial
#
# [135 rows x 39 columns]

# %%
merged_ticker_df
# Out:
#                                  company_name     scope_1     scope_2  \
# 0                              JPMorgan Chase      88 553     783 616
# 1    Saudi Arabian Oil Company (Saudi Aramco)  55 700 000  16 100 000
# 2                                        ICBC      97 400   1 923 900
# 3                     China Construction Bank      69 497   1 613 315
# 4                  Agricultural Bank of China     222 353   1 931 555
# ..                                        ...         ...         ...
# 203                                    NVIDIA       4 612     133 569
# 204                                        3M   2 420 000   1 460 000
# 205                             EOG Resources     510 000     400 000
# 206                     Takeda Pharmaceutical     277 000     291 000
# 207                        Sun Life Financial      15 046      18 819
#
#          scope_3 sales_revenue    profit  \
# 0        156 845      $179 930   $41 800
# 1            NaN      $589 470  $156 360
# 2            NaN      $216 770   $52 470
# 3            NaN      $203 080   $48 250
# 4            NaN      $186 140   $37 920
# ..           ...           ...       ...
# 203    2 701 477       $26 970    $4 370
# 204   11 636 000       $33 430    $5 450
# 205  110 300 000       $28 430    $9 390
# 206    5 166 000       $29 990    $2 090
# 207       25 792       $31 560    $2 400
#
#                                            data_source  year         cik  \
# 0    page 1: https://www.jpmorganchase.com/content/...  2022  0000019617
# 1    page 63, https://www.aramco.com/-/media/public...  2022         NaN
# 2    page 27, https://v.icbc.com.cn/userfiles/Resou...  2022  0000917358
# 3    page 52, http://group.ccb.com/eng/attachDir/20...  2022         NaN
# 4    page 98, https://www.abchina.com/en/aboutus/cs...  2022         NaN
# ..                                                 ...   ...         ...
# 203  page no. 51, CSR 2022, https://images.nvidia.c...  2022  0001045810
# 204  page 149, https://multimedia.3m.com/mws/media/...  2022  0000066740
# 205  page no. 4, https://eogresources-com.s3.us-wes...  2022  0000821189
# 206                                                NaN  2022  0001395064
# 207                                                NaN  2022  0001097362
#
#                             name_x   symbol  \
# 0              JPMORGAN CHASE & CO   JPM-PM
# 1                              NaN      NaN
# 2    ICBC STANDARD SECURITIES INC.  9011.HK
# 3                              NaN  CNCB.VI
# 4                              NaN   EK7.VI
# ..                             ...      ...
# 203                    NVIDIA CORP    NVD.F
# 204                          3M CO   3MSF.L
# 205              EOG RESOURCES INC      EOG
# 206   TAKEDA PHARMACEUTICAL CO LTD    TKPHF
# 207         SUN LIFE FINANCIAL INC    SUNFF
#
#                                     name_y currency             stockExchange  \
# 0                     JPMorgan Chase & Co.      USD   New York Stock Exchange
# 1                                      NaN      NaN                       NaN
# 2           ICBC CICC USD Money Market ETF      USD                      HKSE
# 3      China Construction Bank Corporation      EUR                    Vienna
# 4       Agricultural Bank of China Limited      EUR                    Vienna
# ..                                     ...      ...                       ...
# 203                     NVIDIA Corporation      EUR  Frankfurt Stock Exchange
# 204       Leverage Shares 3x Microsoft ETC      GBp     London Stock Exchange
# 205                    EOG Resources, Inc.      USD   New York Stock Exchange
# 206  Takeda Pharmaceutical Company Limited      USD                 Other OTC
# 207                Sun Life Financial Inc.      USD                 Other OTC
#
#     exchangeShortName
# 0                NYSE
# 1                 NaN
# 2                HKSE
# 3                 VIE
# 4                 VIE
# ..                ...
# 203             XETRA
# 204               LSE
# 205              NYSE
# 206               PNK
# 207               PNK
#
# [208 rows x 15 columns]

# %%
income_df_clean = income_df.rename(columns={"original_name": "company_name"})
income_df_clean = income_df_clean[["company_name", "reportedCurrency", "revenue", "grossProfitRatio", "ebitda", "netIncome"]]
final_df = pd.merge(merged_ticker_df, income_df_clean, on="company_name", how="left")
final_df
# Out:
#                                  company_name     scope_1     scope_2  \
# 0                              JPMorgan Chase      88 553     783 616
# 1    Saudi Arabian Oil Company (Saudi Aramco)  55 700 000  16 100 000
# 2                                        ICBC      97 400   1 923 900
# 3                     China Construction Bank      69 497   1 613 315
# 4                  Agricultural Bank of China     222 353   1 931 555
# ..                                        ...         ...         ...
# 203                                    NVIDIA       4 612     133 569
# 204                                        3M   2 420 000   1 460 000
# 205                             EOG Resources     510 000     400 000
# 206                     Takeda Pharmaceutical     277 000     291 000
# 207                        Sun Life Financial      15 046      18 819
#
#          scope_3 sales_revenue    profit  \
# 0        156 845      $179 930   $41 800
# 1            NaN      $589 470  $156 360
# 2            NaN      $216 770   $52 470
# 3            NaN      $203 080   $48 250
# 4            NaN      $186 140   $37 920
# ..           ...           ...       ...
# 203    2 701 477       $26 970    $4 370
# 204   11 636 000       $33 430    $5 450
# 205  110 300 000       $28 430    $9 390
# 206    5 166 000       $29 990    $2 090
# 207       25 792       $31 560    $2 400
#
#                                            data_source  year         cik  \
# 0    page 1: https://www.jpmorganchase.com/content/...  2022  0000019617
# 1    page 63, https://www.aramco.com/-/media/public...  2022         NaN
# 2    page 27, https://v.icbc.com.cn/userfiles/Resou...  2022  0000917358
# 3    page 52, http://group.ccb.com/eng/attachDir/20...  2022         NaN
# 4    page 98, https://www.abchina.com/en/aboutus/cs...  2022         NaN
# ..                                                 ...   ...         ...
# 203  page no. 51, CSR 2022, https://images.nvidia.c...  2022  0001045810
# 204  page 149, https://multimedia.3m.com/mws/media/...  2022  0000066740
# 205  page no. 4, https://eogresources-com.s3.us-wes...  2022  0000821189
# 206                                                NaN  2022  0001395064
# 207                                                NaN  2022  0001097362
#
#                             name_x   symbol  \
# 0              JPMORGAN CHASE & CO   JPM-PM
# 1                              NaN      NaN
# 2    ICBC STANDARD SECURITIES INC.  9011.HK
# 3                              NaN  CNCB.VI
# 4                              NaN   EK7.VI
# ..                             ...      ...
# 203                    NVIDIA CORP    NVD.F
# 204                          3M CO   3MSF.L
# 205              EOG RESOURCES INC      EOG
# 206   TAKEDA PHARMACEUTICAL CO LTD    TKPHF
# 207         SUN LIFE FINANCIAL INC    SUNFF
#
#                                     name_y currency             stockExchange  \
# 0                     JPMorgan Chase & Co.      USD   New York Stock Exchange
# 1                                      NaN      NaN                       NaN
# 2           ICBC CICC USD Money Market ETF      USD                      HKSE
# 3      China Construction Bank Corporation      EUR                    Vienna
# 4       Agricultural Bank of China Limited      EUR                    Vienna
# ..                                     ...      ...                       ...
# 203                     NVIDIA Corporation      EUR  Frankfurt Stock Exchange
# 204       Leverage Shares 3x Microsoft ETC      GBp     London Stock Exchange
# 205                    EOG Resources, Inc.      USD   New York Stock Exchange
# 206  Takeda Pharmaceutical Company Limited      USD                 Other OTC
# 207                Sun Life Financial Inc.      USD                 Other OTC
#
#     exchangeShortName reportedCurrency       revenue  grossProfitRatio  \
# 0                NYSE              USD  1.286950e+11          1.000000
# 1                 NaN              NaN           NaN               NaN
# 2                HKSE              NaN           NaN               NaN
# 3                 VIE              CNY  8.212790e+11          1.000000
# 4                 VIE              CNY  7.248680e+11          1.000000
# ..                ...              ...           ...               ...
# 203             XETRA              USD  2.691400e+10          0.649290
# 204               LSE              USD  3.422900e+10          0.438137
# 205              NYSE              USD  2.949200e+10          0.813712
# 206               PNK              JPY  3.569006e+12          0.689873
# 207               PNK              CAD  2.320700e+10          1.000000
#
#            ebitda     netIncome
# 0    7.226300e+10  3.767600e+10
# 1             NaN           NaN
# 2             NaN           NaN
# 3    3.827120e+11  3.247270e+11
# 4    8.455800e+11  2.592320e+11
# ..            ...           ...
# 203  1.135100e+10  9.752000e+09
# 204  8.370000e+09  5.777000e+09
# 205  1.528000e+10  7.759000e+09
# 206  1.052329e+12  2.300590e+11
# 207  4.840000e+09  3.024000e+09
#
# [208 rows x 20 columns]

# %%
final_df_clean = final_df.copy(deep=True)
final_df_clean = final_df_clean[["company_name", "scope_1", "scope_2", "scope_3", "sales_revenue", "profit", "revenue", "grossProfitRatio", "ebitda", "netIncome"]]
final_df_clean
# Out:
#                                  company_name     scope_1     scope_2  \
# 0                              JPMorgan Chase      88 553     783 616
# 1    Saudi Arabian Oil Company (Saudi Aramco)  55 700 000  16 100 000
# 2                                        ICBC      97 400   1 923 900
# 3                     China Construction Bank      69 497   1 613 315
# 4                  Agricultural Bank of China     222 353   1 931 555
# ..                                        ...         ...         ...
# 203                                    NVIDIA       4 612     133 569
# 204                                        3M   2 420 000   1 460 000
# 205                             EOG Resources     510 000     400 000
# 206                     Takeda Pharmaceutical     277 000     291 000
# 207                        Sun Life Financial      15 046      18 819
#
#          scope_3 sales_revenue    profit       revenue  grossProfitRatio  \
# 0        156 845      $179 930   $41 800  1.286950e+11          1.000000
# 1            NaN      $589 470  $156 360           NaN               NaN
# 2            NaN      $216 770   $52 470           NaN               NaN
# 3            NaN      $203 080   $48 250  8.212790e+11          1.000000
# 4            NaN      $186 140   $37 920  7.248680e+11          1.000000
# ..           ...           ...       ...           ...               ...
# 203    2 701 477       $26 970    $4 370  2.691400e+10          0.649290
# 204   11 636 000       $33 430    $5 450  3.422900e+10          0.438137
# 205  110 300 000       $28 430    $9 390  2.949200e+10          0.813712
# 206    5 166 000       $29 990    $2 090  3.569006e+12          0.689873
# 207       25 792       $31 560    $2 400  2.320700e+10          1.000000
#
#            ebitda     netIncome
# 0    7.226300e+10  3.767600e+10
# 1             NaN           NaN
# 2             NaN           NaN
# 3    3.827120e+11  3.247270e+11
# 4    8.455800e+11  2.592320e+11
# ..            ...           ...
# 203  1.135100e+10  9.752000e+09
# 204  8.370000e+09  5.777000e+09
# 205  1.528000e+10  7.759000e+09
# 206  1.052329e+12  2.300590e+11
# 207  4.840000e+09  3.024000e+09
#
# [208 rows x 10 columns]

# %%
final_df_clean.to_json('../external_datasets/merged_api_data.json')

# %%
col_list = ['scope_1', 'scope_2', 'scope_3', 'sales_revenue',
       'profit']

def str_to_int(string):
    if type(string) == str:
        string = string.strip()
        string = string.strip('$')
        string = string.replace('\xa0', '')
        return int(string)

def clean_numeric_cols(col_list, df):
    df_copy = df.copy(deep=True)
    for col_name in col_list:
        df_copy[col_name] = df_copy[col_name].apply(str_to_int)
    df_copy = df_copy.fillna(0)
    return df_copy

# %%
final_df_clean = clean_numeric_cols(col_list, final_df_clean)
final_df_clean
# Out:
#                                  company_name   scope_1     scope_2  \
# 0                              JPMorgan Chase     88553    783616.0
# 1    Saudi Arabian Oil Company (Saudi Aramco)  55700000  16100000.0
# 2                                        ICBC     97400   1923900.0
# 3                     China Construction Bank     69497   1613315.0
# 4                  Agricultural Bank of China    222353   1931555.0
# ..                                        ...       ...         ...
# 203                                    NVIDIA      4612    133569.0
# 204                                        3M   2420000   1460000.0
# 205                             EOG Resources    510000    400000.0
# 206                     Takeda Pharmaceutical    277000    291000.0
# 207                        Sun Life Financial     15046     18819.0
#
#          scope_3  sales_revenue  profit       revenue  grossProfitRatio  \
# 0       156845.0         179930   41800  1.286950e+11          1.000000
# 1            0.0         589470  156360  0.000000e+00          0.000000
# 2            0.0         216770   52470  0.000000e+00          0.000000
# 3            0.0         203080   48250  8.212790e+11          1.000000
# 4            0.0         186140   37920  7.248680e+11          1.000000
# ..           ...            ...     ...           ...               ...
# 203    2701477.0          26970    4370  2.691400e+10          0.649290
# 204   11636000.0          33430    5450  3.422900e+10          0.438137
# 205  110300000.0          28430    9390  2.949200e+10          0.813712
# 206    5166000.0          29990    2090  3.569006e+12          0.689873
# 207      25792.0          31560    2400  2.320700e+10          1.000000
#
#            ebitda     netIncome
# 0    7.226300e+10  3.767600e+10
# 1    0.000000e+00  0.000000e+00
# 2    0.000000e+00  0.000000e+00
# 3    3.827120e+11  3.247270e+11
# 4    8.455800e+11  2.592320e+11
# ..            ...           ...
# 203  1.135100e+10  9.752000e+09
# 204  8.370000e+09  5.777000e+09
# 205  1.528000e+10  7.759000e+09
# 206  1.052329e+12  2.300590e+11
# 207  4.840000e+09  3.024000e+09
#
# [208 rows x 10 columns]

# %%
with pd.option_context('display.max_rows', 250, 'display.max_columns', 10):
    display(final_df_clean.head(250))
# Out:
#                                  company_name    scope_1     scope_2  \
# 0                              JPMorgan Chase      88553    783616.0
# 1    Saudi Arabian Oil Company (Saudi Aramco)   55700000  16100000.0
# 2                                        ICBC      97400   1923900.0
# 3                     China Construction Bank      69497   1613315.0
# 4                  Agricultural Bank of China     222353   1931555.0
# 5                             Bank of America      66775    634510.0
# 6                                    Alphabet      91200   8045400.0
# 7                                  ExxonMobil   96000000   7000000.0
# 8                                   Microsoft     139413   6381250.0
# 9                                       Apple      55200      3000.0
# 10                                      Shell   51000000   7000000.0
# 11                              Bank of China        575     48522.0
# 12                               Toyota Motor    2370000   2870000.0
# 13                        Samsung Electronics    5972000   9081000.0
# 14                         UnitedHealth Group     122356    383896.0
# 15                    Ping An Insurance Group       2818    285891.0
# 16                                Wells Fargo      77476    593495.0
# 17                                    Chevron   53000000   4000000.0
# 18                                 PetroChina  119680000  40880000.0
# 19                              HSBC Holdings      19000    224000.0
# 20                              TotalEnergies   37000000   2000000.0
# 21                                    Walmart    7370000   6620000.0
# 22                                  Citigroup      43912    466641.0
# 23                               China Mobile     220000  34240000.0
# 24                       China Merchants Bank      10200    247800.0
# 25        Postal Savings Bank Of China (PSBC)       4851    209166.0
# 26                                         BP   30400000   1500000.0
# 27                           Volkswagen Group    4460000   2410000.0
# 28                             Morgan Stanley      27268    196553.0
# 29                             Meta Platforms      66934       273.0
# 30                                    Sinopec  137720000  24070000.0
# 31                        Goldman Sachs Group      11980    158151.0
# 32                           Tencent Holdings     172138   2650073.0
# 33                                     Amazon   13400000   2890000.0
# 34                                    Allianz      30953    138339.0
# 35                                        RBC      22840     65577.0
# 36                                     Pfizer     650587    489611.0
# 37                          Johnson & Johnson     384622    606096.0
# 38                        Mercedes-Benz Group     569000   1121000.0
# 39                              TD Bank Group      43021     77081.0
# 40                       Taiwan Semiconductor    2018789   9539765.0
# 41                        Reliance Industries   43960000   1190000.0
# 42                                  BMW Group     694057     91300.0
# 43           LVMH Moët Hennessy Louis Vuitton      67393    190051.0
# 44                                  AXA Group      23280     61136.0
# 45                                  Santander      21967    217906.0
# 46                                     Nestlé    3240000    760000.0
# 47                                    Comcast     496938   1480893.0
# 48                                    Equinor   11400000    100000.0
# 49                              Alibaba Group     930000   4400000.0
# 50                           Procter & Gamble    2160000    156000.0
# 51                     Nippon Telegraph & Tel     100000   2430000.0
# 52                                       Sony     230000    736000.0
# 53                                  Petrobras   47700000    100000.0
# 54                     Glencore International   16600000  11400000.0
# 55                            Industrial Bank       6560     48976.0
# 193  9.647907e+06          88030    2090  1.357420e+11          1.000000
# 194  1.627000e+04          19040    3260  1.019414e+12          1.000000
# 195  6.450000e+03          23050    2780  0.000000e+00          0.000000
# 196  0.000000e+00          35050    4370  3.511800e+10          0.557891
# 197  5.065810e+05          22820    9660  2.223700e+10          0.763322
# 198  2.041000e+03          26320    8540  1.769540e+11          0.839235
# 199  0.000000e+00          37110    4780  0.000000e+00          0.000000
# 200  7.072808e+07          96000    2610  0.000000e+00          0.000000
# 201  5.070000e+05          27060    2420  0.000000e+00          0.000000
# 202  1.190000e+07          25360    7160  2.117340e+10          0.496505
# 203  2.701477e+06          26970    4370  2.691400e+10          0.649290
# 204  1.163600e+07          33430    5450  3.422900e+10          0.438137
# 205  1.103000e+08          28430    9390  2.949200e+10          0.813712
# 206  5.166000e+06          29990    2090  3.569006e+12          0.689873
# 207  2.579200e+04          31560    2400  2.320700e+10          1.000000
#
#            ebitda     netIncome
# 0    7.226300e+10  3.767600e+10
# 1    0.000000e+00  0.000000e+00
# 2    0.000000e+00  0.000000e+00
# 3    3.827120e+11  3.247270e+11
# 4    8.455800e+11  2.592320e+11
# 5    5.305000e+10  2.752800e+10
# 6    0.000000e+00  0.000000e+00
# 7    0.000000e+00  0.000000e+00
# 8    9.990500e+10  7.273800e+10
# 9    1.305410e+11  9.980300e+10
# 10   0.000000e+00  0.000000e+00
# 11   0.000000e+00  0.000000e+00
# 12   0.000000e+00  0.000000e+00
# 13   0.000000e+00  0.000000e+00
# 14   2.980500e+10  2.012000e+10
# 15   0.000000e+00  0.000000e+00
# 16   3.117500e+10  1.367700e+10
# 17   6.649000e+10  3.546500e+10
# 18   2.366490e+11  1.487380e+11
# 19   0.000000e+00  0.000000e+00
# 20   5.935200e+10  2.052600e+10
# 21   3.375800e+10  1.367300e+10
# 22   0.000000e+00  0.000000e+00
# 23   0.000000e+00  0.000000e+00
# 24   3.135820e+11  1.380120e+11
# 25   0.000000e+00  0.000000e+00
# 26   5.946700e+10 -1.357000e+09
# 27   0.000000e+00  0.000000e+00
# 28   0.000000e+00  0.000000e+00
# 29   3.763000e+10  2.320000e+10
# 30  -3.469786e+09 -2.842300e+09
# 31   3.728700e+10  1.126100e+10
# 32   1.491310e+11  1.882430e+11
# 33   5.461800e+10 -2.722000e+09
# 34   0.000000e+00  0.000000e+00
# 35   0.000000e+00  0.000000e+00
# 36   4.363900e+10  3.137200e+10
# 37   2.402400e+10  1.794100e+10
# 38   2.680300e+10  1.450100e+10
# 39   0.000000e+00  0.000000e+00
# 40   1.589774e+12  9.929234e+11
# 41   1.546910e+12  6.670200e+11
# 42   0.000000e+00  0.000000e+00
# 43   0.000000e+00  0.000000e+00
# 44   0.000000e+00  0.000000e+00
# 45   2.713400e+07 -3.159890e+08
# 46   1.949900e+10  9.270000e+09
# 47   0.000000e+00  0.000000e+00
# 48   8.642500e+10  2.874600e+10
# 49   1.169490e+11  6.224900e+10
# 50   2.124100e+10  1.474200e+10
# 51   3.523375e+12  1.181083e+12
# 52   2.243854e+12  9.371260e+11
# 53   7.391900e+10  3.662300e+10
# 54   0.000000e+00  0.000000e+00
# 55   8.921562e+12  2.667696e+12
# 56   0.000000e+00  0.000000e+00
# 57   1.852300e+10  3.208200e+10
# 58   1.397400e+10  7.514000e+09
# 59   4.760000e+09 -7.960000e+08
# 60   2.049800e+10  4.311000e+09
# 61   1.316041e+11  6.921176e+10
# 62   2.706900e+10  1.710500e+10
# 63   0.000000e+00  0.000000e+00
# 64   1.783300e+10  1.258300e+10
# 65   0.000000e+00  0.000000e+00
# 66   1.861900e+10  1.451900e+10
# 67   2.658400e+10  1.183600e+10
# 68   1.777500e+12  1.130840e+12
# 69   0.000000e+00  0.000000e+00
# 70   5.244761e+11  3.537388e+11
# 71   9.444000e+09  5.894000e+09
# 72   1.141100e+10  5.197000e+09
# 73   0.000000e+00  0.000000e+00
# 74   1.462900e+10  8.910000e+09
# 75   0.000000e+00  0.000000e+00
# 76   3.028200e+10  1.353700e+10
# 77   1.543089e+12  7.066310e+11
# 78   2.624270e+11  1.417000e+11
# 79   1.208200e+10  3.145000e+09
# 80   1.377000e+10  8.371000e+09
# 81   0.000000e+00  0.000000e+00
# 82   1.680000e+10  1.181200e+10
# 83   0.000000e+00  0.000000e+00
# 84   1.853300e+10  1.154800e+10
# 85   7.714690e+08  4.301580e+08
# 86   0.000000e+00  0.000000e+00
# 87   1.798090e+11  2.920700e+10
# 88   0.000000e+00  0.000000e+00
# 89   2.610700e+10  1.239200e+10
# 90   1.419400e+10  4.339000e+09
# 91   0.000000e+00  0.000000e+00
# 92   0.000000e+00  0.000000e+00
# 93   1.675413e+13  7.364364e+12
# 94   0.000000e+00  0.000000e+00
# 95   1.208400e+10  7.131000e+09
# 96   0.000000e+00  0.000000e+00
# 97   1.698120e+12  7.070670e+11
# 98   1.992300e+10  6.327000e+09
# 99   7.693000e+09  4.379000e+09
# 100  0.000000e+00  0.000000e+00
# 101  2.987080e+11  1.414827e+11
# 102  2.296500e+10  1.451600e+10
# 103  1.205600e+10  6.950000e+09
# 104  1.233900e+10  6.705000e+09
# 105  5.567254e+10  3.072916e+10
# 106  2.054200e+10  1.495700e+10
# 107  1.922600e+10  1.022700e+10
# 108  1.290200e+10 -1.981000e+09
# 109  0.000000e+00  0.000000e+00
# 110  9.327000e+09  3.288000e+09
# 111  8.549000e+09  4.247000e+09
# 112  5.353765e+11  3.860004e+11
# 113  1.255160e+11  6.964800e+10
# 114  7.670900e+10  6.210300e+10
# 115  0.000000e+00  0.000000e+00
# 116  1.437400e+10  1.102400e+10
# 117  0.000000e+00  0.000000e+00
# 118  2.092100e+10  5.055000e+09
# 119  2.161900e+10  1.878800e+10
# 120  0.000000e+00  0.000000e+00
# 121  0.000000e+00  0.000000e+00
# 122  1.069600e+10  6.933000e+09
# 123  0.000000e+00  0.000000e+00
# 124  1.072500e+10  7.209000e+09
# 125  0.000000e+00  0.000000e+00
# 126  1.291600e+10  5.459000e+09
# 127  0.000000e+00  0.000000e+00
# 128  6.113000e+09  4.555000e+09
# 129  2.487600e+10  5.195000e+09
# 130  0.000000e+00  0.000000e+00
